# %%
import pandas as pd
import json
import numpy as np

# %%
# @title DATA
data_list = [
  {
    "id": 336497,
    "quiz_id": 51,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-17T15:30:18.027+05:30",
    "created_at": "2025-01-17T15:30:18.044+05:30",
    "updated_at": "2025-01-17T15:30:18.044+05:30",
    "score": 108,
    "trophy_level": 2,
    "accuracy": "90 %",
    "speed": "100",
    "final_score": "105.0",
    "negative_score": "3.0",
    "correct_answers": 27,
    "incorrect_answers": 3,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-17T15:18:30.000+05:30",
    "ended_at": "2025-01-17T15:30:15.000+05:30",
    "duration": "15:00",
    "better_than": 107,
    "total_questions": 100,
    "rank_text": "Topic Rank - #-171",
    "mistakes_corrected": 9,
    "initial_mistake_count": 12,
    "response_map": {
      "2523": 10109,
      "2529": 10130,
      "2533": 10149,
      "2534": 10151,
      "2535": 10155,
      "2537": 10163,
      "2538": 10169,
      "2541": 10178,
      "2543": 10187,
      "2550": 10216,
      "2553": 10227,
      "2554": 10232,
      "2555": 10235,
      "2557": 10242,
      "2558": 10246,
      "2564": 10270,
      "2565": 10276,
      "2567": 10283,
      "2572": 10305,
      "2576": 10318,
      "2585": 10356,
      "2587": 10365,
      "2589": 10371,
      "2591": 10378,
      "2593": 10389,
      "2598": 10407,
      "2599": 10411,
      "2607": 10444,
      "2610": 10454,
      "2614": 10472
    },
    "quiz": {
      "id": 51,
      "name": "",
      "title": "Human Physiology (15)",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation",
      "time": "2024-07-12T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-12T11:17:37.658+05:30",
      "updated_at": "2024-09-23T18:43:27.373+05:30",
      "duration": 100,
      "end_time": "2024-07-13T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 100,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 336448,
    "quiz_id": 6,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-17T15:17:44.042+05:30",
    "created_at": "2025-01-17T15:17:44.056+05:30",
    "updated_at": "2025-01-17T15:17:44.056+05:30",
    "score": 92,
    "trophy_level": 1,
    "accuracy": "100 %",
    "speed": "100",
    "final_score": "92.0",
    "negative_score": "0.0",
    "correct_answers": 23,
    "incorrect_answers": 0,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-17T15:07:45.000+05:30",
    "ended_at": "2025-01-17T15:17:41.000+05:30",
    "duration": "15:00",
    "better_than": 395,
    "total_questions": 23,
    "rank_text": "Topic Rank - #-9140",
    "mistakes_corrected": 3,
    "initial_mistake_count": 3,
    "response_map": {
      "48": 192,
      "49": 197,
      "50": 199,
      "51": 203,
      "52": 208,
      "53": 212,
      "54": 217,
      "55": 221,
      "56": 224,
      "57": 229,
      "58": 232,
      "59": 235,
      "60": 239,
      "61": 245,
      "62": 250,
      "63": 253,
      "64": 256,
      "65": 261,
      "134": 538,
      "135": 543,
      "136": 546,
      "353": 1415,
      "354": 1417
    },
    "quiz": {
      "id": 6,
      "name": "",
      "title": "Human Physiology PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation ",
      "time": "2024-04-25T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-04-26T15:26:29.886+05:30",
      "updated_at": "2024-06-05T18:27:32.163+05:30",
      "duration": 23,
      "end_time": "2024-04-26T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 23,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 333330,
    "quiz_id": 51,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-16T20:13:19.682+05:30",
    "created_at": "2025-01-16T20:13:19.699+05:30",
    "updated_at": "2025-01-16T20:13:19.699+05:30",
    "score": 116,
    "trophy_level": 2,
    "accuracy": "96 %",
    "speed": "100",
    "final_score": "115.0",
    "negative_score": "1.0",
    "correct_answers": 29,
    "incorrect_answers": 1,
    "source": "live",
    "type": "topic",
    "started_at": "2025-01-16T20:01:10.000+05:30",
    "ended_at": "2025-01-16T20:13:18.000+05:30",
    "duration": "15:00",
    "better_than": 115,
    "total_questions": 100,
    "rank_text": "Topic Rank - #-418",
    "mistakes_corrected": 11,
    "initial_mistake_count": 12,
    "response_map": {
      "2523": 10109,
      "2525": 10117,
      "2528": 10127,
      "2533": 10149,
      "2539": 10170,
      "2540": 10175,
      "2548": 10208,
      "2549": 10211,
      "2550": 10216,
      "2552": 10223,
      "2554": 10232,
      "2558": 10246,
      "2560": 10257,
      "2562": 10265,
      "2564": 10270,
      "2573": 10307,
      "2574": 10313,
      "2578": 10329,
      "2580": 10337,
      "2586": 10360,
      "2590": 10377,
      "2595": 10396,
      "2599": 10411,
      "2600": 10414,
      "2602": 10422,
      "2607": 10444,
      "2608": 10447,
      "2609": 10451,
      "2612": 10464,
      "2613": 10469
    },
    "quiz": {
      "id": 51,
      "name": "",
      "title": "Human Physiology (15)",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation",
      "time": "2024-07-12T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-12T11:17:37.658+05:30",
      "updated_at": "2024-09-23T18:43:27.373+05:30",
      "duration": 100,
      "end_time": "2024-07-13T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 100,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 333242,
    "quiz_id": 6,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-16T20:00:11.562+05:30",
    "created_at": "2025-01-16T20:00:11.573+05:30",
    "updated_at": "2025-01-16T20:00:11.573+05:30",
    "score": 36,
    "trophy_level": 2,
    "accuracy": "90 %",
    "speed": "100",
    "final_score": "35.0",
    "negative_score": "1.0",
    "correct_answers": 9,
    "incorrect_answers": 1,
    "source": "live",
    "type": "topic",
    "started_at": "2025-01-16T19:52:57.000+05:30",
    "ended_at": "2025-01-16T20:00:09.000+05:30",
    "duration": "15:00",
    "better_than": 152,
    "total_questions": 23,
    "rank_text": "Topic Rank - #-1598",
    "mistakes_corrected": 1,
    "initial_mistake_count": 2,
    "response_map": {
      "49": 197,
      "52": 208,
      "53": 212,
      "54": 217,
      "55": 221,
      "60": 239,
      "64": 255,
      "136": 546,
      "353": 1415,
      "354": 1417
    },
    "quiz": {
      "id": 6,
      "name": "",
      "title": "Human Physiology PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation ",
      "time": "2024-04-25T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-04-26T15:26:29.886+05:30",
      "updated_at": "2024-06-05T18:27:32.163+05:30",
      "duration": 23,
      "end_time": "2024-04-26T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 23,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 329504,
    "quiz_id": 51,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-15T20:34:39.462+05:30",
    "created_at": "2025-01-15T20:34:39.478+05:30",
    "updated_at": "2025-01-15T20:34:39.478+05:30",
    "score": 36,
    "trophy_level": 3,
    "accuracy": "31 %",
    "speed": "96",
    "final_score": "16.0",
    "negative_score": "20.0",
    "correct_answers": 9,
    "incorrect_answers": 20,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-15T20:21:25.000+05:30",
    "ended_at": "2025-01-15T20:34:38.000+05:30",
    "duration": "15:00",
    "better_than": 35,
    "total_questions": 100,
    "rank_text": "Topic Rank - #2023",
    "mistakes_corrected": 0,
    "initial_mistake_count": 20,
    "response_map": {
      "2521": 10099,
      "2523": 10107,
      "2532": 10145,
      "2537": 10163,
      "2538": 10168,
      "2540": 10174,
      "2544": 10191,
      "2549": 10211,
      "2558": 10247,
      "2563": 10266,
      "2564": 10270,
      "2566": 10279,
      "2567": 10283,
      "2570": 10297,
      "2571": 10298,
      "2572": 10302,
      "2577": 10324,
      "2582": 10344,
      "2585": 10355,
      "2586": 10361,
      "2590": 10377,
      "2593": 10388,
      "2594": 10393,
      "2595": 10396,
      "2596": 10399,
      "2602": 10424,
      "2610": 10456,
      "2613": 10469,
      "2616": 10481
    },
    "quiz": {
      "id": 51,
      "name": "",
      "title": "Human Physiology (15)",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation",
      "time": "2024-07-12T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-12T11:17:37.658+05:30",
      "updated_at": "2024-09-23T18:43:27.373+05:30",
      "duration": 100,
      "end_time": "2024-07-13T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 100,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 328488,
    "quiz_id": 57,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-15T15:57:12.791+05:30",
    "created_at": "2025-01-15T15:57:12.800+05:30",
    "updated_at": "2025-01-15T15:57:12.800+05:30",
    "score": 40,
    "trophy_level": 3,
    "accuracy": "38 %",
    "speed": "86",
    "final_score": "24.0",
    "negative_score": "16.0",
    "correct_answers": 10,
    "incorrect_answers": 16,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-15T15:47:05.000+05:30",
    "ended_at": "2025-01-15T15:57:11.000+05:30",
    "duration": "15:00",
    "better_than": 43,
    "total_questions": 89,
    "rank_text": "Topic Rank - #1810",
    "mistakes_corrected": 0,
    "initial_mistake_count": 16,
    "response_map": {
      "3043": 12184,
      "3044": 12186,
      "3046": 12194,
      "3053": 12224,
      "3062": 12261,
      "3063": 12264,
      "3064": 12267,
      "3065": 12270,
      "3068": 12283,
      "3071": 12297,
      "3074": 12307,
      "3080": 12333,
      "3082": 12340,
      "3083": 12343,
      "3086": 12354,
      "3087": 12361,
      "3089": 12368,
      "3090": 12370,
      "3096": 12394,
      "3097": 12401,
      "3104": 12427,
      "3110": 12451,
      "3111": 12456,
      "3112": 12458,
      "3114": 12466,
      "3116": 12476
    },
    "quiz": {
      "id": 57,
      "name": "",
      "title": "Reproduction",
      "description": "",
      "difficulty_level": "",
      "topic": "Human Reproduction",
      "time": "2024-07-12T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-12T16:57:41.878+05:30",
      "updated_at": "2024-09-23T18:43:28.935+05:30",
      "duration": 89,
      "end_time": "2024-07-13T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 89,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 328414,
    "quiz_id": 6,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-15T15:36:46.410+05:30",
    "created_at": "2025-01-15T15:36:46.420+05:30",
    "updated_at": "2025-01-15T15:36:46.420+05:30",
    "score": 36,
    "trophy_level": 3,
    "accuracy": "50 %",
    "speed": "78",
    "final_score": "27.0",
    "negative_score": "9.0",
    "correct_answers": 9,
    "incorrect_answers": 9,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-15T15:23:42.000+05:30",
    "ended_at": "2025-01-15T15:36:45.000+05:30",
    "duration": "15:00",
    "better_than": 152,
    "total_questions": 23,
    "rank_text": "Topic Rank - #-1598",
    "mistakes_corrected": 0,
    "initial_mistake_count": 9,
    "response_map": {
      "48": 193,
      "49": 197,
      "50": 202,
      "51": 203,
      "52": 208,
      "53": 212,
      "54": 217,
      "55": 221,
      "56": 226,
      "57": 229,
      "58": 231,
      "59": 235,
      "60": 240,
      "61": 244,
      "62": 249,
      "64": 257,
      "65": 261,
      "134": 539
    },
    "quiz": {
      "id": 6,
      "name": "",
      "title": "Human Physiology PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "Body Fluids and Circulation ",
      "time": "2024-04-25T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-04-26T15:26:29.886+05:30",
      "updated_at": "2024-06-05T18:27:32.163+05:30",
      "duration": 23,
      "end_time": "2024-04-26T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 23,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 321514,
    "quiz_id": 20,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-13T16:10:03.743+05:30",
    "created_at": "2025-01-13T16:10:03.753+05:30",
    "updated_at": "2025-01-13T16:10:03.753+05:30",
    "score": 12,
    "trophy_level": 2,
    "accuracy": "30 %",
    "speed": "100",
    "final_score": "5.0",
    "negative_score": "7.0",
    "correct_answers": 3,
    "incorrect_answers": 7,
    "source": "live",
    "type": "topic",
    "started_at": "2025-01-13T16:05:27.000+05:30",
    "ended_at": "2025-01-13T16:10:02.000+05:30",
    "duration": "15:00",
    "better_than": 18,
    "total_questions": 59,
    "rank_text": "Topic Rank - #2556",
    "mistakes_corrected": 0,
    "initial_mistake_count": 7,
    "response_map": {
      "473": 1893,
      "474": 1898,
      "475": 1901,
      "487": 1951,
      "488": 1956,
      "492": 1972,
      "500": 2001,
      "508": 2034,
      "513": 2054,
      "521": 2085
    },
    "quiz": {
      "id": 20,
      "name": "",
      "title": "PRINCIPLES OF INHERITANCE AND VARIATION PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "principles of inheritance and variation ",
      "time": "2024-06-07T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-06-07T15:40:47.746+05:30",
      "updated_at": "2024-06-20T18:17:03.628+05:30",
      "duration": 59,
      "end_time": "2024-06-08T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 59,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 320963,
    "quiz_id": 24,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-13T13:28:12.784+05:30",
    "created_at": "2025-01-13T13:28:12.795+05:30",
    "updated_at": "2025-01-13T13:28:12.795+05:30",
    "score": 76,
    "trophy_level": 2,
    "accuracy": "100 %",
    "speed": "95",
    "final_score": "76.0",
    "negative_score": "0.0",
    "correct_answers": 19,
    "incorrect_answers": 0,
    "source": "live",
    "type": "topic",
    "started_at": "2025-01-13T13:14:17.000+05:30",
    "ended_at": "2025-01-13T13:28:11.000+05:30",
    "duration": "15:00",
    "better_than": 375,
    "total_questions": 20,
    "rank_text": "Topic Rank - #-8479",
    "mistakes_corrected": 4,
    "initial_mistake_count": 4,
    "response_map": {
      "770": 3084,
      "771": 3085,
      "772": 3091,
      "773": 3096,
      "774": 4667,
      "775": 3103,
      "776": 3107,
      "777": 3108,
      "778": 3113,
      "779": 3117,
      "780": 3120,
      "781": 3124,
      "782": 3130,
      "783": 3133,
      "784": 3139,
      "785": 3143,
      "786": 3146,
      "787": 3150,
      "788": 3153
    },
    "quiz": {
      "id": 24,
      "name": "",
      "title": "MICROBES IN HUMAN WELFARE  PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "microbes in human welfare",
      "time": "2024-06-10T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-06-10T13:19:22.991+05:30",
      "updated_at": "2024-06-24T14:01:22.154+05:30",
      "duration": 20,
      "end_time": "2024-06-11T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 20,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 320916,
    "quiz_id": 18,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-13T13:12:40.687+05:30",
    "created_at": "2025-01-13T13:12:40.695+05:30",
    "updated_at": "2025-01-13T13:12:40.695+05:30",
    "score": 40,
    "trophy_level": 1,
    "accuracy": "100 %",
    "speed": "100",
    "final_score": "40.0",
    "negative_score": "0.0",
    "correct_answers": 10,
    "incorrect_answers": 0,
    "source": "live",
    "type": "topic",
    "started_at": "2025-01-13T13:11:13.000+05:30",
    "ended_at": "2025-01-13T13:12:39.000+05:30",
    "duration": "15:00",
    "better_than": 177,
    "total_questions": 22,
    "rank_text": "Topic Rank - #-2380",
    "mistakes_corrected": 0,
    "initial_mistake_count": 0,
    "response_map": {
      "612": 2451,
      "613": 2454,
      "614": 2460,
      "619": 2481,
      "620": 2483,
      "624": 2499,
      "626": 2509,
      "628": 2516,
      "629": 2521,
      "630": 2523
    },
    "quiz": {
      "id": 18,
      "name": "",
      "title": "REPRODUCTIVE HEALTH PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "reproductive health ",
      "time": "2024-06-07T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-06-07T15:24:37.590+05:30",
      "updated_at": "2024-06-14T15:16:51.212+05:30",
      "duration": 22,
      "end_time": "2024-06-08T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 22,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 315179,
    "quiz_id": 25,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-11T21:20:08.641+05:30",
    "created_at": "2025-01-11T21:20:08.652+05:30",
    "updated_at": "2025-01-11T21:20:08.652+05:30",
    "score": 112,
    "trophy_level": 2,
    "accuracy": "93 %",
    "speed": "100",
    "final_score": "110.0",
    "negative_score": "2.0",
    "correct_answers": 28,
    "incorrect_answers": 2,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-11T21:04:22.000+05:30",
    "ended_at": "2025-01-11T21:20:07.000+05:30",
    "duration": "15:00",
    "better_than": 270,
    "total_questions": 41,
    "rank_text": "Topic Rank - #-5215",
    "mistakes_corrected": 12,
    "initial_mistake_count": 14,
    "response_map": {
      "790": 3160,
      "793": 3172,
      "794": 3177,
      "796": 3185,
      "797": 3188,
      "799": 3197,
      "800": 3200,
      "801": 3204,
      "804": 3217,
      "805": 3219,
      "806": 3226,
      "807": 3227,
      "808": 3234,
      "810": 3241,
      "811": 3243,
      "812": 3249,
      "813": 3251,
      "814": 3255,
      "815": 3259,
      "816": 3265,
      "817": 3268,
      "818": 3272,
      "820": 3280,
      "823": 3291,
      "825": 4669,
      "826": 3305,
      "827": 3309,
      "828": 3311,
      "829": 3316,
      "830": 3318
    },
    "quiz": {
      "id": 25,
      "name": "",
      "title": "HUMAN HEALTH AND DISEASE PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "human health and disease ",
      "time": "2024-06-10T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-06-10T16:08:08.817+05:30",
      "updated_at": "2024-06-24T13:12:10.743+05:30",
      "duration": 41,
      "end_time": "2024-06-11T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 41,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 315081,
    "quiz_id": 18,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2025-01-11T21:03:43.251+05:30",
    "created_at": "2025-01-11T21:03:43.262+05:30",
    "updated_at": "2025-01-11T21:03:43.262+05:30",
    "score": 64,
    "trophy_level": 3,
    "accuracy": "84 %",
    "speed": "86",
    "final_score": "61.0",
    "negative_score": "3.0",
    "correct_answers": 16,
    "incorrect_answers": 3,
    "source": "exam",
    "type": "topic",
    "started_at": "2025-01-11T20:58:07.000+05:30",
    "ended_at": "2025-01-11T21:03:42.000+05:30",
    "duration": "15:00",
    "better_than": 286,
    "total_questions": 22,
    "rank_text": "Topic Rank - #-5764",
    "mistakes_corrected": 0,
    "initial_mistake_count": 3,
    "response_map": {
      "611": 2447,
      "612": 2451,
      "613": 2454,
      "614": 2460,
      "615": 2465,
      "616": 2466,
      "617": 2470,
      "619": 2481,
      "620": 2484,
      "621": 2486,
      "622": 2490,
      "623": 2495,
      "624": 2499,
      "625": 2505,
      "626": 2509,
      "627": 2514,
      "628": 2516,
      "629": 2521,
      "630": 2523
    },
    "quiz": {
      "id": 18,
      "name": "",
      "title": "REPRODUCTIVE HEALTH PYQ",
      "description": "",
      "difficulty_level": "",
      "topic": "reproductive health ",
      "time": "2024-06-07T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-06-07T15:24:37.590+05:30",
      "updated_at": "2024-06-14T15:16:51.212+05:30",
      "duration": 22,
      "end_time": "2024-06-08T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 22,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 257774,
    "quiz_id": 58,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2024-12-28T22:58:52.969+05:30",
    "created_at": "2024-12-28T22:58:53.122+05:30",
    "updated_at": "2024-12-28T22:58:53.122+05:30",
    "score": 52,
    "trophy_level": 2,
    "accuracy": "43 %",
    "speed": "100",
    "final_score": "35.0",
    "negative_score": "17.0",
    "correct_answers": 13,
    "incorrect_answers": 17,
    "source": "exam",
    "type": "topic",
    "started_at": "2024-12-28T22:42:26.000+05:30",
    "ended_at": "2024-12-28T22:58:49.000+05:30",
    "duration": "15:00",
    "better_than": 92,
    "total_questions": 55,
    "rank_text": "Topic Rank - #301",
    "mistakes_corrected": 0,
    "initial_mistake_count": 17,
    "response_map": {
      "3132": 12542,
      "3135": 12554,
      "3137": 12561,
      "3140": 12574,
      "3142": 12581,
      "3144": 12589,
      "3145": 12593,
      "3146": 12596,
      "3147": 12600,
      "3148": 12604,
      "3149": 12610,
      "3150": 12612,
      "3156": 12637,
      "3158": 12646,
      "3160": 12653,
      "3163": 12664,
      "3165": 12674,
      "3167": 12682,
      "3168": 12686,
      "3178": 12726,
      "3181": 12735,
      "3184": 12747,
      "3185": 12751,
      "3187": 12760,
      "3188": 12764,
      "3189": 12767,
      "3190": 12771,
      "3191": 12776,
      "3193": 12786,
      "3194": 12787
    },
    "quiz": {
      "id": 58,
      "name": "",
      "title": "Reproduction",
      "description": "",
      "difficulty_level": "",
      "topic": "Reproductive Health",
      "time": "2024-07-12T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-12T17:59:03.733+05:30",
      "updated_at": "2024-09-23T18:43:29.022+05:30",
      "duration": 55,
      "end_time": "2024-07-13T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 55,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  },
  {
    "id": 195808,
    "quiz_id": 50,
    "user_id": "YcDFSO4ZukTJnnFMgRNVwZTE4j42",
    "submitted_at": "2024-12-11T20:36:44.822+05:30",
    "created_at": "2024-12-11T20:36:44.863+05:30",
    "updated_at": "2024-12-11T20:36:44.863+05:30",
    "score": 24,
    "trophy_level": 3,
    "accuracy": "66 %",
    "speed": "90",
    "final_score": "21.0",
    "negative_score": "3.0",
    "correct_answers": 6,
    "incorrect_answers": 3,
    "source": "exam",
    "type": "topic",
    "started_at": "2024-12-11T20:31:14.000+05:30",
    "ended_at": "2024-12-11T20:36:42.000+05:30",
    "duration": "15:00",
    "better_than": 23,
    "total_questions": 100,
    "rank_text": "Topic Rank - #2392",
    "mistakes_corrected": 0,
    "initial_mistake_count": 3,
    "response_map": {
      "2417": 9684,
      "2425": 9715,
      "2435": 9754,
      "2440": 9776,
      "2444": 9793,
      "2452": 9824,
      "2459": 9852,
      "2469": 9890,
      "2515": 10075
    },
    "quiz": {
      "id": 50,
      "name": "",
      "title": "Human Physiology (14)",
      "description": "",
      "difficulty_level": "",
      "topic": "Respiration and Gas Exchange",
      "time": "2024-07-11T00:00:00.000+05:30",
      "is_published": True,
      "created_at": "2024-07-11T13:44:33.409+05:30",
      "updated_at": "2024-09-23T18:43:27.666+05:30",
      "duration": 100,
      "end_time": "2024-07-12T00:00:00.000+05:30",
      "negative_marks": "1.0",
      "correct_answer_marks": "4.0",
      "shuffle": True,
      "show_answers": True,
      "lock_solutions": False,
      "is_form": False,
      "show_mastery_option": False,
      "reading_material": "",
      "quiz_type": "",
      "is_custom": False,
      "banner_id": "",
      "exam_id": "",
      "show_unanswered": False,
      "ends_at": "2025-01-18",
      "lives": "",
      "live_count": "Free Test",
      "coin_count": -1,
      "questions_count": 100,
      "daily_date": "January 17, 2025",
      "max_mistake_count": 15,
      "reading_materials": []
    }
  }
]

# %% [markdown]
# # EXTRACTING DATA AND EXPLORING TRENDS

# %%
relevant_keys = ["quiz_id", "submitted_at", "score", "trophy_level", "accuracy", "speed",
                 "final_score", "negative_score","correct_answers","incorrect_answers","type"
                 "duration" ,"better_than", "total_questions", "rank_text", "mistakes_corrected",
                 "initial_mistake_count"]


processed_rows = []
for data in data_list:

    relevant_data = {key: data[key] for key in relevant_keys if key in data}

    # REDEFINING DURATION
    end_time = pd.to_datetime(data["submitted_at"])
    start_time = pd.to_datetime(data["started_at"])
    duration = (end_time - start_time).total_seconds() // 60
    relevant_data["duration"] = duration

    # REDEFINING SPEED ( number of question soved per minute / time alloted to each question * 100  )

    time_per_q = (relevant_data["correct_answers"] +relevant_data["incorrect_answers"]) / duration

    alloted_time = data["quiz"].get("duration") / data["total_questions"]

    relevant_data["speed"] = time_per_q / alloted_time * 100

    quiz_attributes = {
        "quiz_title": data["quiz"].get("title").strip(),
        "quiz_topic": data["quiz"].get("topic").strip(),
        "difficulty_level" : data["quiz"].get("difficulty_level").strip(),
        "quiz_duration" : data["quiz"].get("duration"),
        "quiz_reading_materials": data["quiz"].get("reading_materials")
    }


    relevant_data.update(quiz_attributes)


    processed_rows.append(relevant_data)


df = pd.DataFrame(processed_rows)

df["submitted_at"] = pd.to_datetime(df["submitted_at"])
# df["submitted_at"] = df["submitted_at"].dt.date

df["accuracy"] = df["accuracy"].str.rstrip(" %").astype(float)

# %%
difficulty_levels = ["easy", "medium", "hard"]

difficulty_mapping = {quiz_id: np.random.choice(difficulty_levels) for quiz_id in df['quiz_id'].unique()}

# Update the 'difficulty_level' column in the DataFrame
df['difficulty_level'] = df['quiz_id'].map(difficulty_mapping)

# %%
df.head(14)
# Out:
#     quiz_id                     submitted_at  score  trophy_level  accuracy  \
# 0        51 2025-01-17 15:30:18.027000+05:30    108             2      90.0
# 1         6 2025-01-17 15:17:44.042000+05:30     92             1     100.0
# 2        51 2025-01-16 20:13:19.682000+05:30    116             2      96.0
# 3         6 2025-01-16 20:00:11.562000+05:30     36             2      90.0
# 4        51 2025-01-15 20:34:39.462000+05:30     36             3      31.0
# 5        57 2025-01-15 15:57:12.791000+05:30     40             3      38.0
# 6         6 2025-01-15 15:36:46.410000+05:30     36             3      50.0
# 7        20 2025-01-13 16:10:03.743000+05:30     12             2      30.0
# 8        24 2025-01-13 13:28:12.784000+05:30     76             2     100.0
# 9        18 2025-01-13 13:12:40.687000+05:30     40             1     100.0
# 10       25 2025-01-11 21:20:08.641000+05:30    112             2      93.0
# ...

# %% [markdown]
# # OVERALL ANALYSIS

# %%
# Group by quiz_topic and calculate metrics
topic_performance = df.groupby("quiz_topic").agg(
    average_score=("score", "mean"),
    average_accuracy=("accuracy", "mean"),
    average_speed = ("speed","mean"),
    completion_count=("quiz_id", "count")
).reset_index()

# %%
topic_performance.head(10)
# Out:
#                                 quiz_topic  average_score  average_accuracy  \
# 0              Body Fluids and Circulation      70.666667         76.166667
# 1                       Human Reproduction      40.000000         38.000000
# 2                      Reproductive Health      52.000000         43.000000
# 3             Respiration and Gas Exchange      24.000000         66.000000
# 4                 human health and disease     112.000000         93.000000
# 5                microbes in human welfare      76.000000        100.000000
# 6  principles of inheritance and variation      12.000000         30.000000
# 7                      reproductive health      52.000000         92.000000
#
#    average_speed  completion_count
# 0     213.779739                 6
# 1     260.000000                 1
# 2     187.500000                 1
# 3     180.000000                 1
# 4     200.000000                 1
# 5     146.153846                 1
# ...

# %%
topic2solvedQuestions = {}
for data in data_list :
  topic = data["quiz"].get("topic").strip()
  if topic not in topic2solvedQuestions:
      topic2solvedQuestions[topic] = []
  response_map = data["response_map"]
  for key, value in response_map.items():

    topic2solvedQuestions[topic].append(key)

topic2solvedQuestionCount = {}

for topic, question_ids in topic2solvedQuestions.items():
    topic2solvedQuestionCount[topic] = len(question_ids)

topic_performance["total_questions"] = topic_performance["quiz_topic"].map(topic2solvedQuestionCount)

# %%
import plotly.graph_objects as go

fig = go.Figure()

for index, row in topic_performance.iterrows():
    if row['total_questions'] > 50:
        color = 'green'
    elif 25 <= row['total_questions'] <= 50:
        color = 'yellow'
    else:
        color = 'red'
    fig.add_trace(go.Bar(x=[row['quiz_topic']], y=[row['total_questions']], marker_color=color))

fig.update_layout(
    title='Total Questions per Quiz Topic',
    xaxis_title='Quiz Topic',
    yaxis_title='Total Questions',
    showlegend=False  # Hide the legend
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
for index, row in topic_performance.iterrows():
    if row['average_accuracy'] > 80:
        color = 'green'
    elif 50 <= row['average_accuracy'] <= 80 :
        color = 'yellow'
    else:
        color = 'red'
    fig.add_trace(go.Bar(x=[row['quiz_topic']], y=[row['average_accuracy']], marker_color=color))

fig.update_layout(
    title='Average Accuracy per Quiz Topic',
    xaxis_title='Quiz Topic',
    yaxis_title='Average Accuracy',
    showlegend=False  # Hide the legend
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_performance['suggestion'] = 'good work'
topic_performance.loc[(topic_performance['average_accuracy'] < 70) | (topic_performance['total_questions'] < 25), 'suggestion'] = 'needs improvement'

# %%
topic_performance[['quiz_topic','suggestion']].head(10)
# Out:
#                                 quiz_topic         suggestion
# 0              Body Fluids and Circulation          good work
# 1                       Human Reproduction  needs improvement
# 2                      Reproductive Health  needs improvement
# 3             Respiration and Gas Exchange  needs improvement
# 4                 human health and disease          good work
# 5                microbes in human welfare  needs improvement
# 6  principles of inheritance and variation  needs improvement
# 7                      reproductive health          good work

# %% [markdown]
# # TOPIC WISE INSIGHTS

# %%
# drop down to select a single topic
from ipywidgets import widgets, interact


topic_dropdown = widgets.Dropdown(
    options=topic_performance['quiz_topic'].unique().tolist(),
    description='Select Topic:'
)

def update_topic(change):
    global topic
    topic = change.new


topic_dropdown.observe(update_topic, names='value')


display(topic_dropdown)
# Out:
# Dropdown(description='Select Topic:', options=('Body Fluids and Circulation', 'Human Reproduction', 'Reproduct…

# %%
def plot_accuracy_over_time(topic):
    topic_data = df[df["quiz_topic"] == topic]
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=topic_data["submitted_at"], y=topic_data["accuracy"], mode="lines+markers"))
    fig.update_layout(title=f"Accuracy over Time for {topic}", xaxis_title="Submitted At", yaxis_title="Accuracy")
    fig.update_yaxes(title="Accuracy (%)", type="linear")
    fig.show()

plot_accuracy_over_time(topic)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  We could have genrated the stats wrt to topic on difficulty level of the topic / questions but the value corresponding to the
# key difficulty is "" always without knowing how the difficulty is defined ( on scale of 1-10 or categorical (easy med hard ))
#  there is no point in trying to analyse wrt difficulty level based on the input data
#
#  OTHERWISE :
#  the idea is to generate a decision tree with attributes such as speed , difficulty level to show the correlation with these attributes and  accuracy of the studen to do this i have assumed random categorical valriabalae easy medium hard for the difficulty level (topic_wise) and tried to implement the decison tree

# %%
df.head(5)
# Out:
#    quiz_id                     submitted_at  score  trophy_level  accuracy  \
# 0       51 2025-01-17 15:30:18.027000+05:30    108             2      90.0
# 1        6 2025-01-17 15:17:44.042000+05:30     92             1     100.0
# 2       51 2025-01-16 20:13:19.682000+05:30    116             2      96.0
# 3        6 2025-01-16 20:00:11.562000+05:30     36             2      90.0
# 4       51 2025-01-15 20:34:39.462000+05:30     36             3      31.0
#
#         speed final_score negative_score  correct_answers  incorrect_answers  \
# 0  272.727273       105.0            3.0               27                  3
# 1  255.555556        92.0            0.0               23                  0
# 2  250.000000       115.0            1.0               29                  1
# 3  142.857143        35.0            1.0                9                  1
# 4  223.076923        16.0           20.0                9                 20
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns


# Extract relevant columns
features = ['speed']
target = 'accuracy'

df['better_than'] = pd.to_numeric(df['better_than'], errors='coerce')
df.dropna(inplace=True)
df['better_than'] = df['better_than'].astype(int)


df = pd.get_dummies(df, columns=['difficulty_level'], prefix='difficulty')

# %%
X = df[features + ['difficulty_easy', 'difficulty_hard', 'difficulty_medium']]
y = df[target]



rf_model = RandomForestRegressor( n_estimators=50, random_state=42)
rf_model.fit(X, y)

y_pred = rf_model.predict(X)

mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 149.8390285714286

# %%
# Feature Importance
feature_importances = rf_model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# As we have dummy data for the difficulty part the feature importance is not really a true deption of the student but is shown only to picth the idea of using random forests to see where the student is lagging

# %% [markdown]
# # Current quiz data

# %%
# @title QUIZ DATA
quiz_data = {
  "quiz": {
    "id": 43,
    "name": "",
    "title": "Structural Organisation in Animals and Plants (7)",
    "description": "",
    "difficulty_level": "",
    "topic": "Structural Organisation in Animals",
    "time": "2024-07-03T00:00:00.000+05:30",
    "is_published": True,
    "created_at": "2024-07-03T11:00:08.958+05:30",
    "updated_at": "2024-09-23T18:43:27.751+05:30",
    "duration": 128,
    "end_time": "2024-07-04T00:00:00.000+05:30",
    "negative_marks": "1.0",
    "correct_answer_marks": "4.0",
    "shuffle": True,
    "show_answers": True,
    "lock_solutions": False,
    "is_form": False,
    "show_mastery_option": False,
    "quiz_type": "",
    "is_custom": False,
    "banner_id": "",
    "exam_id": "",
    "show_unanswered": False,
    "ends_at": "2025-01-18",
    "lives": "",
    "live_count": "Free Test",
    "coin_count": -1,
    "questions_count": 128,
    "daily_date": "January 17, 2025",
    "max_mistake_count": 15,
    "questions": [
      {
        "id": 1827,
        "description": "The tissue which has free surface that faces either a body fluid or the outside environment is called characteristics of the",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T12:43:34.360+05:30",
        "updated_at": "2024-11-30T18:39:20.587+05:30",
        "detailed_solution": "**Explanation:**\n\nThe tissue that has a free surface is called **epithelial tissue**. This free surface may face either a body fluid (such as blood, lymph, or mucus) or the outside environment.\n\n**Characteristics of Epithelial Tissue:**\n\n* **Free Surface:** The cells have an exposed surface that faces either a body fluid or the external environment.\n* **Apical Surface:** The surface facing the external environment or body cavity.\n* **Basal Surface:** The surface attached to the connective tissue below.\n* **Closely Packed:** The cells are closely packed together with minimal intercellular space.\n* **Polarized Cells:** They are generally polarized, with different apical and basal surfaces and functions.\n* **Basement Membrane:** The basal surface is supported by a basement membrane, which separates the epithelium from the underlying connective tissue.\n* **Avascular:** Epithelial cells are avascular, meaning they lack blood vessels. They receive nutrients from the underlying connective tissue through diffusion.\n\n**Functions of Epithelial Tissue:**\n\n* **Protection:** Forms a physical barrier against pathogens, chemicals, and physical damage.\n* **Secretion:** Secretes various substances, such as mucus, enzymes, and hormones.\n* **Absorption:** Facilitates the uptake of substances from the external environment or body fluids.\n* **Excretion:** Helps eliminate waste products from the body.\n* **Sensory:** Contains specialized cells that detect changes in the environment and transmit sensory information.\n\n**Additional Context:**\n\nEpithelial tissue is classified into different types based on its structure and function. Some of the common types include:\n\n* **Simple Epithelium:** Consists of a single layer of cells.\n* **Stratified Epithelium:** Consists of multiple layers of cells.\n* **Glandular Epithelium:** Specialized for secretion of substances.\n* **Sensory Epithelium:** Contains specialized sensory cells.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2016,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7321,
            "description": "Muscular tissue",
            "question_id": 1827,
            "is_correct": False,
            "created_at": "2024-07-02T12:43:34.365+05:30",
            "updated_at": "2024-07-02T12:43:34.365+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7322,
            "description": "Fluid connective tissue",
            "question_id": 1827,
            "is_correct": False,
            "created_at": "2024-07-02T12:43:34.369+05:30",
            "updated_at": "2024-07-02T12:43:34.369+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7323,
            "description": "Epithelial tissue",
            "question_id": 1827,
            "is_correct": True,
            "created_at": "2024-07-02T12:43:34.372+05:30",
            "updated_at": "2024-07-02T12:43:34.372+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7324,
            "description": "Nervous tissue",
            "question_id": 1827,
            "is_correct": False,
            "created_at": "2024-07-02T12:43:34.376+05:30",
            "updated_at": "2024-07-02T12:43:34.376+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1828,
        "description": "Epithelial tissue is distinguished from connective tissue, muscular, or nervous tissue by its",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T12:50:56.100+05:30",
        "updated_at": "2024-11-30T18:39:20.788+05:30",
        "detailed_solution": "**Epithelial Tissue**\n\n* Epithelial tissue is a continuous sheet of cells that covers the body and lines its internal cavities.\n* It serves as a barrier between the internal environment of the body and the external environment.\n\n**Distinguishing Features of Epithelial Tissue**\n\nEpithelial tissue is distinguished from connective tissue, muscular tissue, and nervous tissue by its:\n\n**1. Basement Membrane:**\n\n* Epithelial tissue rests on a thin layer called the basement membrane.\n* The basement membrane is a non-cellular layer secreted by the epithelial cells.\n* It anchors the epithelial tissue to the underlying connective tissue and provides structural support.\n\n**2. Cell Junctions:**\n\n* Epithelial cells are closely packed together and have tight junctions between them.\n* These junctions create a barrier that prevents substances from leaking out of the body or entering it.\n\n**3. Avascularity:**\n\n* Epithelial tissue is avascular, meaning it does not have blood vessels.\n* It receives nutrients from the underlying connective tissue through diffusion.\n\n**Additional Context:**\n\n* Epithelial tissue is classified into various types based on:\n    * Number of cell layers (simple, stratified)\n    * Shape of cells (squamous, cuboidal, columnar)\n    * Presence of specializations (goblet cells, cilia)\n\n* Epithelial tissue performs a wide range of functions, including:\n    * Protection\n    * Absorption\n    * Secretion\n    * Exchange of gases\n    * Sensory reception",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2017,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7325,
            "description": "large extracellular matrix",
            "question_id": 1828,
            "is_correct": False,
            "created_at": "2024-07-02T12:50:56.110+05:30",
            "updated_at": "2024-07-02T12:50:56.110+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7326,
            "description": "contractibility",
            "question_id": 1828,
            "is_correct": False,
            "created_at": "2024-07-02T12:50:56.114+05:30",
            "updated_at": "2024-07-02T12:50:56.114+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7327,
            "description": "ability to carry action potentials",
            "question_id": 1828,
            "is_correct": False,
            "created_at": "2024-07-02T12:50:56.116+05:30",
            "updated_at": "2024-07-02T12:50:56.116+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7328,
            "description": "basement membrane",
            "question_id": 1828,
            "is_correct": True,
            "created_at": "2024-07-02T12:50:56.119+05:30",
            "updated_at": "2024-07-02T12:50:56.119+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1829,
        "description": "The ciliated columnar epithelial cells in humans occur in",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T12:54:25.824+05:30",
        "updated_at": "2024-11-30T18:39:20.990+05:30",
        "detailed_solution": "**Explanation:**\n\nCiliated columnar epithelial cells are found in areas where movement of substances or particles is required.\n\n* **Bronchioles:** These are the smallest branches of the respiratory system, and they carry air to the alveoli. The ciliated cells in the bronchioles help to move mucus and foreign particles out of the lungs.\n* **Fallopian tubes:** These are the tubes that connect the ovaries to the uterus. The ciliated cells in the fallopian tubes help to move the egg from the ovary to the uterus.\n\nIn addition to the bronchioles and fallopian tubes, ciliated columnar epithelial cells are also found in the trachea, nasal cavity, paranasal sinuses, and middle ear.\n\n**Additional Context:**\n\n* Ciliated columnar epithelial cells are characterized by the presence of cilia, which are small, hair-like extensions of the cell membrane.\n* Cilia beat in a coordinated manner, which helps to move substances or particles along the surface of the epithelium.\n* The movement of substances or particles by ciliated columnar epithelial cells is essential for a variety of functions in the body, including respiration, reproduction, and the removal of foreign particles from the respiratory system.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2018,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7329,
            "description": "Eustachian tube and stomach lining",
            "question_id": 1829,
            "is_correct": False,
            "created_at": "2024-07-02T12:54:25.831+05:30",
            "updated_at": "2024-07-02T12:54:25.831+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7330,
            "description": "bronchioles and fallopian tubes",
            "question_id": 1829,
            "is_correct": True,
            "created_at": "2024-07-02T12:54:25.836+05:30",
            "updated_at": "2024-07-02T12:54:25.836+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7331,
            "description": "bile duct and oesophagus",
            "question_id": 1829,
            "is_correct": False,
            "created_at": "2024-07-02T12:54:25.839+05:30",
            "updated_at": "2024-07-02T12:54:25.839+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7332,
            "description": "fallopian tubes and urethra",
            "question_id": 1829,
            "is_correct": False,
            "created_at": "2024-07-02T12:54:25.843+05:30",
            "updated_at": "2024-07-02T12:54:25.843+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1830,
        "description": "The squamous epithelium is found in",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T12:56:48.204+05:30",
        "updated_at": "2024-11-30T18:39:21.192+05:30",
        "detailed_solution": "**Explanation:**\n\nSquamous epithelium is a type of simple epithelium characterized by thin, flattened cells. It is found in areas where exchange of materials occurs, such as the lining of blood vessels, alveoli in the lungs, and the lining of Bowman's capsule in the kidneys.\n\nIn the lungs, the squamous epithelium is found in the air sacs, also known as alveoli. The alveoli are small, thin-walled sacs that allow for the exchange of oxygen and carbon dioxide between the blood and the air we breathe. The squamous epithelium lining the alveoli is only one cell thick, which facilitates the efficient diffusion of gases.\n\nTherefore, the correct answer is: air sacs of lungs.\n\n**Additional Context:**\n\n* Squamous epithelium is also found in:\n    * Lining of blood vessels (endothelium)\n    * Lining of serosal cavities (e.g., pleura, peritoneum)\n    * Lining of Bowman's capsule in kidneys\n* Its main function is to regulate the movement of substances across membranes.\n* It has a low permeability and high resistance to the movement of molecules.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2019,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7333,
            "description": "stomach",
            "question_id": 1830,
            "is_correct": False,
            "created_at": "2024-07-02T12:56:48.207+05:30",
            "updated_at": "2024-07-02T12:56:48.207+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7334,
            "description": "intestine",
            "question_id": 1830,
            "is_correct": False,
            "created_at": "2024-07-02T12:56:48.210+05:30",
            "updated_at": "2024-07-02T12:56:48.210+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7335,
            "description": "trachea",
            "question_id": 1830,
            "is_correct": False,
            "created_at": "2024-07-02T12:56:48.212+05:30",
            "updated_at": "2024-07-02T12:56:48.212+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7336,
            "description": "air sacs of lungs",
            "question_id": 1830,
            "is_correct": True,
            "created_at": "2024-07-02T12:56:48.214+05:30",
            "updated_at": "2024-07-02T12:56:48.214+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1831,
        "description": "The kind of epithelium which forms the inner walls of blood vessels is",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T12:58:51.241+05:30",
        "updated_at": "2024-11-30T18:39:21.398+05:30",
        "detailed_solution": "**Answer is correct because:**\n\nSquamous epithelium is a thin, flattened layer of cells that line the inner walls of blood vessels, as well as the alveoli of the lungs and the lining of the heart. It is composed of a single layer of cells that are closely packed together, and the cells are thin and flattened in shape. This type of epithelium is well-suited for lining the inner walls of blood vessels because it is very thin and allows for the easy exchange of substances between the blood and the surrounding tissues.\n\n**Additional context:**\n\n* **Simple squamous epithelium:** This is the simplest type of squamous epithelium, and it consists of a single layer of thin, flattened cells. It is found in the lining of blood vessels, the alveoli of the lungs, and the lining of the heart.\n* **Stratified squamous epithelium:** This type of squamous epithelium is composed of multiple layers of cells, and the cells are flattened in shape. It is found in the skin, the esophagus, and the vagina.\n\n**Functions of squamous epithelium:**\n\n* Protection: Squamous epithelium helps to protect the underlying tissues from damage.\n* Exchange of substances: Squamous epithelium allows for the easy exchange of substances between the blood and the surrounding tissues.\n* Secretion: Squamous epithelium can secrete substances, such as mucus, to help protect the underlying tissues.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2020,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7337,
            "description": "cuboidal epithelium",
            "question_id": 1831,
            "is_correct": False,
            "created_at": "2024-07-02T12:58:51.250+05:30",
            "updated_at": "2024-07-02T12:58:51.250+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7338,
            "description": "columnar epithelium",
            "question_id": 1831,
            "is_correct": False,
            "created_at": "2024-07-02T12:58:51.256+05:30",
            "updated_at": "2024-07-02T12:58:51.256+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7339,
            "description": "ciliated columnar epithelium",
            "question_id": 1831,
            "is_correct": False,
            "created_at": "2024-07-02T12:58:51.260+05:30",
            "updated_at": "2024-07-02T12:58:51.260+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7340,
            "description": "squamous epithelium",
            "question_id": 1831,
            "is_correct": True,
            "created_at": "2024-07-02T12:58:51.265+05:30",
            "updated_at": "2024-07-02T12:58:51.265+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1832,
        "description": "Which of the following type of cell junction is not found in animal tissues?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:12:19.723+05:30",
        "updated_at": "2024-11-30T18:39:21.601+05:30",
        "detailed_solution": "**Explanation:**\n\nAnimal tissues do not have plasmodesmata, which are specialized cell junctions found in plant tissues. Plasmodesmata are channels that connect the cytoplasm of adjacent plant cells, allowing for the exchange of molecules and ions.\n\n**Additional context:**\n\n* **Cell junctions:**\n    * Plasmodesmata are found in plant tissues, allowing for direct cytoplasmic communication between adjacent cells.\n    * Animal tissues have various types of cell junctions, including tight junctions, adherens junctions, gap junctions, and desmosomes.\n* **NEET exam:**\n    * The National Eligibility cum Entrance Test (NEET) is an entrance exam for admission to undergraduate medical and dental programs in India.\n    * Biology, including structural organization in animals, is a significant portion of the NEET syllabus.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2021,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7341,
            "description": "Adhering junction",
            "question_id": 1832,
            "is_correct": False,
            "created_at": "2024-07-02T13:12:19.727+05:30",
            "updated_at": "2024-07-02T13:12:19.727+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7342,
            "description": "Tight junction",
            "question_id": 1832,
            "is_correct": False,
            "created_at": "2024-07-02T13:12:19.729+05:30",
            "updated_at": "2024-07-02T13:12:19.729+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7343,
            "description": "Gap junction",
            "question_id": 1832,
            "is_correct": False,
            "created_at": "2024-07-02T13:12:19.731+05:30",
            "updated_at": "2024-07-02T13:12:19.731+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7344,
            "description": "Plasmodesmata",
            "question_id": 1832,
            "is_correct": True,
            "created_at": "2024-07-02T13:12:19.734+05:30",
            "updated_at": "2024-07-02T13:12:19.734+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1833,
        "description": "Which of the following statement is incorrect regarding cuboidal epithelium?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:13:36.531+05:30",
        "updated_at": "2024-11-30T18:39:21.807+05:30",
        "detailed_solution": "**Explanation:**\n\nCuboidal epithelium is composed of cube-shaped cells. They are found in many parts of the body, including the **walls of blood vessels** and the **air sacs of lungs**. However, they are **NOT** found in the walls of air sacs of lungs. The walls of air sacs of lungs are lined by **squamous epithelium**, which is composed of thin, flat cells.\n\n**Additional context:**\n\n* **Epithelium** is a type of tissue that lines the surfaces of the body and its internal organs.\n* There are three main types of epithelium: squamous, cuboidal, and columnar.\n* **Squamous epithelium** is composed of thin, flat cells. It is found in the lining of blood vessels and the air sacs of lungs.\n* **Cuboidal epithelium** is composed of cube-shaped cells. It is found in the lining of the kidneys, the pancreas, and the salivary glands.\n* **Columnar epithelium** is composed of tall, column-shaped cells. It is found in the lining of the stomach and intestines.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2022,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7345,
            "description": "It is an epithelial tissue",
            "question_id": 1833,
            "is_correct": False,
            "created_at": "2024-07-02T13:13:36.539+05:30",
            "updated_at": "2024-07-02T13:13:36.539+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7346,
            "description": "It is composed of a single layer of cube-like cells.",
            "question_id": 1833,
            "is_correct": False,
            "created_at": "2024-07-02T13:13:36.548+05:30",
            "updated_at": "2024-07-02T13:13:36.548+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7347,
            "description": "They are found in the walls of blood vessels and air sacs of lungs.",
            "question_id": 1833,
            "is_correct": True,
            "created_at": "2024-07-02T13:13:36.554+05:30",
            "updated_at": "2024-07-02T13:13:36.554+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7348,
            "description": "Secretion and absorption are the main functions of these tissue.",
            "question_id": 1833,
            "is_correct": False,
            "created_at": "2024-07-02T13:13:36.556+05:30",
            "updated_at": "2024-07-02T13:13:36.556+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1834,
        "description": "Which of the following statement(s) is/are correct  regarding compound epithelium?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:14:55.480+05:30",
        "updated_at": "2024-11-30T18:39:22.015+05:30",
        "detailed_solution": "**Explanation:**\n\nCompound epithelium refers to an epithelium that consists of more than one layer of cells. \n\n**The correct statements regarding compound epithelium are:**\n\n1. **It provides strength and support:** Compound epithelium offers physical stability and protection to the underlying tissues.\n2. **It can have multiple functions:** Different layers of compound epithelium may have specialized functions, such as secretion, absorption, or protection.\n3. **It is found in areas subjected to wear and tear:** Compound epithelium is found in locations that experience friction or abrasion, such as the skin, mouth, and esophagus.\n\n**Additional context:**\n\n* Simple epithelium consists of only one layer of cells.\n* Stratified epithelium has multiple layers of cells.\n* Compound epithelium is a type of stratified epithelium in which the topmost layer is specialized.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2023,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7349,
            "description": "It is made of more than one layer of cells and thus has a limited role in secretion and absorption.",
            "question_id": 1834,
            "is_correct": False,
            "created_at": "2024-07-02T13:14:55.484+05:30",
            "updated_at": "2024-07-02T13:14:55.484+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7350,
            "description": "Their main function is to provide protection against chemical and mechanical stresses.",
            "question_id": 1834,
            "is_correct": False,
            "created_at": "2024-07-02T13:14:55.486+05:30",
            "updated_at": "2024-07-02T13:14:55.486+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7351,
            "description": "They cover the dry surface of the skin, moist surface of buccal cavity, pharynx, inner lining of ducts of salivary glands and pancreatic ducts.",
            "question_id": 1834,
            "is_correct": False,
            "created_at": "2024-07-02T13:14:55.490+05:30",
            "updated_at": "2024-07-02T13:14:55.490+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7352,
            "description": "All of the above",
            "question_id": 1834,
            "is_correct": True,
            "created_at": "2024-07-02T13:14:55.506+05:30",
            "updated_at": "2024-07-02T13:14:55.506+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1835,
        "description": "Ciliated simple columnar epithelium often contains _________,which increase the surface area for secretion and absorption.",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:16:21.469+05:30",
        "updated_at": "2024-11-30T18:39:22.223+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2024,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7353,
            "description": "flagella",
            "question_id": 1835,
            "is_correct": False,
            "created_at": "2024-07-02T13:16:21.473+05:30",
            "updated_at": "2024-07-02T13:16:21.473+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7354,
            "description": "collagen fibres",
            "question_id": 1835,
            "is_correct": False,
            "created_at": "2024-07-02T13:16:21.476+05:30",
            "updated_at": "2024-07-02T13:16:21.476+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7355,
            "description": "microvilli",
            "question_id": 1835,
            "is_correct": True,
            "created_at": "2024-07-02T13:16:21.480+05:30",
            "updated_at": "2024-07-02T13:16:21.480+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7356,
            "description": "all of these",
            "question_id": 1835,
            "is_correct": False,
            "created_at": "2024-07-02T13:16:21.482+05:30",
            "updated_at": "2024-07-02T13:16:21.482+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1836,
        "description": "A student was given a sample of two tissues. He observes the tissues under the microscope and draws their figures (1 and 2) as shown below. Identify the tissues (1 and 2).",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:19:19.118+05:30",
        "updated_at": "2024-12-31T23:57:10.149+05:30",
        "detailed_solution": "**Detailed explanation:**\r\n\r\n**Tissue 1: Columnar cells bearing cilia**\r\n\r\n* **Cell shape:** Tall and column-shaped.\r\n* **Arrangement:** Arranged in a single layer.\r\n* **Surface membrane:** Cilia (short, hair-like projections) present on the apical surface.\r\n* **Function:** Cilia beat in a coordinated manner to move substances (e.g., mucus) along the surface of the tissue.\r\n\r\n**Tissue 2: Multicellular glandular epithelium**\r\n\r\n* **Cell shape:** Cube-shaped or oval.\r\n* **Arrangement:** Arranged in a single layer.\r\n* **Surface membrane:** No cilia or microvilli present.\r\n* **Function:** Secrete substances that are stored in the cells in the form of granules or droplets.\r\n\r\n**Additional context:**\r\n\r\n* Epithelial tissues are thin layers of cells that cover the surfaces of the body and line its cavities.\r\n* They are classified based on their shape, arrangement, and function.\r\n* Columnar epithelium is found in the lining of the respiratory tract, fallopian tubes, and small intestine.\r\n* Glandular epithelium is found in glands, which are organs that produce and secrete substances.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2025,
        "fixed_at": "2024-12-31T00:00:00.000+05:30",
        "fix_summary": "Both the question and answer are correct. No correction needed.",
        "created_by": "",
        "updated_by": "kanza@testline.in",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "https://tlpl-docs.s3.ap-south-1.amazonaws.com/tlpl_neet/svvhbvu4kmd9llj6xsdixoftyg6y?response-content-disposition=inline%3B%20filename%3D%221401.jpg%22%3B%20filename%2A%3DUTF-8%27%271401.jpg&response-content-type=image%2Fjpeg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA4RXKHO4ST4B5MOBS%2F20250117%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20250117T102950Z&X-Amz-Expires=10800&X-Amz-SignedHeaders=host&X-Amz-Signature=a7d3ce1bbc0b6bbeaf5bd92bfbf7d21cbfb64f0cc0969fd1131aa39d2cca3e19",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7357,
            "description": "1: Columnar cells bearing cilia: 2: Unicellular glandular epithelium",
            "question_id": 1836,
            "is_correct": False,
            "created_at": "2024-07-02T13:19:19.122+05:30",
            "updated_at": "2024-07-02T13:19:19.122+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7358,
            "description": "1: Cuboidal cells bearing cilia: 2: Multicellular glandular epithelium",
            "question_id": 1836,
            "is_correct": False,
            "created_at": "2024-07-02T13:19:19.125+05:30",
            "updated_at": "2024-07-02T13:19:19.125+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7359,
            "description": "1: Compound cells bearing cilia; 2: Unicellular glandular epithelium",
            "question_id": 1836,
            "is_correct": False,
            "created_at": "2024-07-02T13:19:19.127+05:30",
            "updated_at": "2024-07-03T19:14:00.223+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7360,
            "description": "1. Columnar cells bearing cilia; 2: Multicellular glandular epithelium",
            "question_id": 1836,
            "is_correct": True,
            "created_at": "2024-07-02T13:19:19.130+05:30",
            "updated_at": "2024-07-02T13:19:25.384+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1837,
        "description": "Which of the following statement(s) regarding cell junctions is/are correct?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:21:54.610+05:30",
        "updated_at": "2024-11-30T18:39:22.627+05:30",
        "detailed_solution": "**Detailed Explanation:**\n\nThe question asks about cell junctions, which are structures that connect adjacent cells in multicellular organisms. The answer given is \"All of the above,\" which refers to the three statements provided as options:\n\na) Cell junctions are sites of material exchange between adjacent cells.\nb) Tight junctions prevent the leakage of materials between the cells.\nc) Gap junctions provide channels for direct cytoplasmic connections between adjacent cells.\n\n**All three statements are correct:**\n\na) **Cell junctions are sites of material exchange between adjacent cells:** This is a crucial function of cell junctions. Cells can exchange nutrients, ions, and other molecules directly with their neighbors through these junctions.\n\nb) **Tight junctions prevent the leakage of materials between the cells:** Tight junctions are specialized cell junctions that create a tight seal between adjacent cells. This prevents the uncontrolled movement of substances between the cells, maintaining the integrity of the tissues and organs.\n\nc) **Gap junctions provide channels for direct cytoplasmic connections between adjacent cells:** Gap junctions are another type of cell junction that forms direct channels between the cytoplasm of adjacent cells. These channels allow the rapid exchange of ions, nutrients, and small molecules, facilitating cell-to-cell communication and the coordination of cellular activities.\n\nTherefore, the answer \"All of the above\" is correct because all three statements accurately describe the functions of cell junctions in multicellular organisms.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2026,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7361,
            "description": "Tight junctions help to stop substances from leaking across a tissue.",
            "question_id": 1837,
            "is_correct": False,
            "created_at": "2024-07-02T13:21:54.614+05:30",
            "updated_at": "2024-07-02T13:21:54.614+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7362,
            "description": "Adhering junctions perform cementing to keen neighbouring cells together.",
            "question_id": 1837,
            "is_correct": False,
            "created_at": "2024-07-02T13:21:54.616+05:30",
            "updated_at": "2024-07-02T13:21:54.616+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7363,
            "description": "All of the above",
            "question_id": 1837,
            "is_correct": True,
            "created_at": "2024-07-02T13:21:54.618+05:30",
            "updated_at": "2024-07-03T16:51:16.545+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7364,
            "description": "Gap junctions facilitate the cells to communicate With each other by connecting the cytoplasm adjoining cells, for rapid transfer of ions small molecules and sometimes big molecules",
            "question_id": 1837,
            "is_correct": False,
            "created_at": "2024-07-02T13:21:54.619+05:30",
            "updated_at": "2024-07-03T16:51:16.542+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1838,
        "description": "Choose the correctly matched pair",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:43:37.422+05:30",
        "updated_at": "2024-11-30T18:39:22.828+05:30",
        "detailed_solution": "**Explanation:**\n\nThe tubular parts of nephrons are lined by cuboidal epithelium. This epithelium is involved in the processes of filtration, reabsorption, and secretion. Cuboidal cells are cube-shaped and have a centrally located nucleus. They are tightly packed together and form a single layer of epithelium.\n\n**Additional Context:**\n\n* Nephrons are the structural and functional units of the kidneys.\n* They are responsible for filtering waste products from the blood and producing urine.\n* The tubular parts of nephrons include the proximal convoluted tubule, the loop of Henle, the distal convoluted tubule, and the collecting duct.\n* These tubular parts are responsible for the reabsorption of water, ions, and nutrients from the urine.\n\n**Significance for NEET Exam:**\n\nUnderstanding the structure and function of the tubular parts of nephrons is important for the NEET exam. This topic is covered in the Biology syllabus for the exam. Students should be able to identify the different tubular parts of nephrons and their functions. They should also be able to explain the role of cuboidal epithelium in these tubular parts.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2027,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7365,
            "description": "Inner lining of salivary ducts - Ciliated epithelium",
            "question_id": 1838,
            "is_correct": False,
            "created_at": "2024-07-02T13:43:37.426+05:30",
            "updated_at": "2024-07-03T16:53:43.177+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7366,
            "description": "Moist surface of buccal cavity - Glandular epithelium",
            "question_id": 1838,
            "is_correct": False,
            "created_at": "2024-07-02T13:43:37.429+05:30",
            "updated_at": "2024-07-02T13:43:37.429+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7367,
            "description": "Tubular parts of nephrons - Cuboidal epithelium",
            "question_id": 1838,
            "is_correct": True,
            "created_at": "2024-07-02T13:43:37.432+05:30",
            "updated_at": "2024-07-02T13:43:37.432+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7368,
            "description": "Inner surface of bronchioles - Squamous epithelium",
            "question_id": 1838,
            "is_correct": False,
            "created_at": "2024-07-02T13:43:37.435+05:30",
            "updated_at": "2024-07-03T16:56:22.637+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1839,
        "description": "The function of the gap junction is to:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:46:13.187+05:30",
        "updated_at": "2024-11-30T18:39:23.040+05:30",
        "detailed_solution": "**Explanation:**\n\nGap junctions are specialised cell-cell junctions that allow direct communication between adjoining cells. They are composed of channels that span the plasma membranes of adjacent cells, creating a cytoplasmic bridge between them. These channels are large enough to allow the passage of ions, small molecules (\u003C1,000 Da), and even some larger molecules, such as ATP and glucose.\n\nThe primary function of gap junctions is to facilitate rapid intercellular communication. They allow the exchange of ions, nutrients, and other molecules between cells, which is essential for coordinated tissue function. Gap junctions also play a role in electrical signalling, allowing the spread of electrical impulses between cells.\n\n**Additional Context on Gap Junctions:**\n\n* Gap junctions are found in a wide variety of tissues, including cardiac muscle, smooth muscle, and the nervous system.\n* They are essential for the synchronous contraction of cardiac muscle cells, the coordinated activity of smooth muscle cells, and the rapid transmission of nerve impulses.\n* Gap junction formation is regulated by a variety of factors, including hormonal signals and cell-cell interactions.\n* Disruption of gap junction function can lead to a variety of diseases, such as heart arrhythmias and neurological disorders.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2028,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7369,
            "description": "separate two cells from each other",
            "question_id": 1839,
            "is_correct": False,
            "created_at": "2024-07-02T13:46:13.194+05:30",
            "updated_at": "2024-07-02T13:46:13.194+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7370,
            "description": "stop substance from leaking across a tissue",
            "question_id": 1839,
            "is_correct": False,
            "created_at": "2024-07-02T13:46:13.198+05:30",
            "updated_at": "2024-07-02T13:46:13.198+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7371,
            "description": "performing cementing to keep neighbouring cells together",
            "question_id": 1839,
            "is_correct": False,
            "created_at": "2024-07-02T13:46:13.202+05:30",
            "updated_at": "2024-07-02T13:46:13.202+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7372,
            "description": "facilitate communication between adjoining cells by connecting the cytoplasm for rapid transfer of ions, small molecules and some large molecules",
            "question_id": 1839,
            "is_correct": True,
            "created_at": "2024-07-02T13:46:13.206+05:30",
            "updated_at": "2024-07-02T13:46:13.206+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1840,
        "description": "The only type of cell seen in a tendon is",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:47:38.668+05:30",
        "updated_at": "2024-11-30T18:39:23.241+05:30",
        "detailed_solution": "**Explanation:**\n\nTendons are fibrous connective tissues that attach muscles to bones. They are composed of specialized cells called fibroblasts, which are the only type of cell seen in a tendon. Fibroblasts produce collagen fibers, which are the main structural components of tendons. These fibers are arranged in parallel bundles, giving tendons their characteristic strength and flexibility.\n\n**Additional Context:**\n\n* Tendons are composed of three main layers: the epitenon, the endotenon, and the peritendon.\n* The epitenon is the outermost layer of the tendon and is composed of loose connective tissue.\n* The endotenon is the innermost layer of the tendon and surrounds the individual collagen fibers.\n* The peritendon is a thin layer of connective tissue that surrounds the entire tendon.\n* Tendons are essential for movement as they transmit the force from muscles to bones.\n\n**Conclusion:**\n\nTherefore, the only type of cell seen in a tendon is fibroblasts, which are responsible for producing the collagen fibers that give tendons their strength and flexibility.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2029,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7373,
            "description": "muscle fibres",
            "question_id": 1840,
            "is_correct": False,
            "created_at": "2024-07-02T13:47:38.673+05:30",
            "updated_at": "2024-07-02T13:47:38.673+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7374,
            "description": "reticular cells",
            "question_id": 1840,
            "is_correct": False,
            "created_at": "2024-07-02T13:47:38.676+05:30",
            "updated_at": "2024-07-02T13:47:38.676+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7375,
            "description": "collagenous cells",
            "question_id": 1840,
            "is_correct": False,
            "created_at": "2024-07-02T13:47:38.679+05:30",
            "updated_at": "2024-07-02T13:47:38.679+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7376,
            "description": "fibroblasts",
            "question_id": 1840,
            "is_correct": True,
            "created_at": "2024-07-02T13:47:38.683+05:30",
            "updated_at": "2024-07-02T13:47:38.683+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1841,
        "description": "Tendons and ligaments are the examples of",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:48:37.762+05:30",
        "updated_at": "2024-11-30T18:39:23.445+05:30",
        "detailed_solution": "**Explanation:**\n\nTendons and ligaments are examples of dense regular connective tissue because they contain densely packed collagen fibers that are arranged in parallel rows.\n\n**Additional context:**\n\n* Dense regular connective tissue is one of the most common types of connective tissue in the body.\n* It provides strength and support to structures like tendons, ligaments, and bones.\n* Collagen is the main protein found in dense regular connective tissue.\n* Collagen fibers are tough and resistant to stretching, which makes dense regular connective tissue well-suited for its role in providing support.\n\n**How to apply this content to answer similar questions:**\n\n1. Understand the different types of connective tissue and their functions.\n2. Identify the tissue type based on its structure and function.\n3. Remember that tendons and ligaments are examples of dense regular connective tissue.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2030,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7377,
            "description": "areolar connective tissue",
            "question_id": 1841,
            "is_correct": False,
            "created_at": "2024-07-02T13:48:37.771+05:30",
            "updated_at": "2024-07-02T13:48:37.771+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7378,
            "description": "adipose tissue",
            "question_id": 1841,
            "is_correct": False,
            "created_at": "2024-07-02T13:48:37.777+05:30",
            "updated_at": "2024-07-02T13:48:37.777+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7379,
            "description": "dense regular connective tissue",
            "question_id": 1841,
            "is_correct": True,
            "created_at": "2024-07-02T13:48:37.783+05:30",
            "updated_at": "2024-07-02T13:48:37.783+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7380,
            "description": "loose connective tissue",
            "question_id": 1841,
            "is_correct": False,
            "created_at": "2024-07-02T13:48:37.786+05:30",
            "updated_at": "2024-07-02T13:48:37.786+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1842,
        "description": "Which of the following statement is incorrect regarding cuboidal epithelium?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:51:47.891+05:30",
        "updated_at": "2024-11-30T18:39:23.648+05:30",
        "detailed_solution": "## **Explanation:**\n\nCuboidal epithelium is a type of simple epithelium in which the cells are cube-shaped or cuboidal. They are found in many parts of the body, including the walls of blood vessels and the air sacs of the lungs. However, they are not found in the walls of blood vessels and air sacs of the lungs. These structures are lined with squamous epithelium, which is composed of thin, flattened cells.\n\nTherefore, the statement \"They are found in the walls of blood vessels and air sacs of lungs\" is incorrect regarding cuboidal epithelium.\n\n## **Additional context:**\n\n* **Cuboidal epithelium** is a type of simple epithelium that is composed of cube-shaped or cuboidal cells.\n* **Squamous epithelium** is a type of simple epithelium that is composed of thin, flattened cells.\n* **Simple epithelium** is a type of epithelium that is composed of a single layer of cells.\n* **Epithelium** is a type of tissue that lines the surfaces of the body and its organs.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2031,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7381,
            "description": "It is an epithelial tissue.",
            "question_id": 1842,
            "is_correct": False,
            "created_at": "2024-07-02T13:51:47.898+05:30",
            "updated_at": "2024-07-02T13:51:47.898+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7382,
            "description": "It is Composed of a single layer of cube-like cells",
            "question_id": 1842,
            "is_correct": False,
            "created_at": "2024-07-02T13:51:47.901+05:30",
            "updated_at": "2024-07-02T13:51:47.901+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7383,
            "description": "They are found in the walls of blood vessels and air sacs of lungs",
            "question_id": 1842,
            "is_correct": True,
            "created_at": "2024-07-02T13:51:47.903+05:30",
            "updated_at": "2024-07-03T17:06:41.637+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7384,
            "description": "Secretion and absorption are the main functions of these tissue",
            "question_id": 1842,
            "is_correct": False,
            "created_at": "2024-07-02T13:51:47.906+05:30",
            "updated_at": "2024-07-02T13:51:47.906+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1843,
        "description": "What are the three basic components of connective tissues ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:54:26.210+05:30",
        "updated_at": "2024-11-30T18:39:23.852+05:30",
        "detailed_solution": "**Explanation:**\n\nConnective tissues are a type of tissue that connects, supports, and protects other tissues and organs in the body. They are composed of three basic components:\n\n1. **Cells:** Connective tissues contain specialized cells called fibroblasts, which are responsible for producing and secreting the protein fibers and ground substance.\n\n2. **Protein fibers:** These fibers provide strength and support to the connective tissue. The most common types of protein fibers are collagen, elastin, and reticular fibers.\n\n3. **Ground substance:** The ground substance is a gel-like substance that fills the space between the cells and protein fibers. It contains a variety of proteins, proteoglycans, and glycosaminoglycans that provide hydration, support, and protection to the tissue.\n\nEach type of connective tissue has a different combination and arrangement of these three components to suit its specific function. For example, tendons, which connect muscles to bones, have a high proportion of collagen fibers for strength and flexibility, while cartilage, which lines the joints, has a high proportion of ground substance for lubrication and shock absorption.\n\n**Additional context:**\n\n* Connective tissues are classified into six main types based on their structure and function: loose connective tissue, dense connective tissue, cartilage, bone, blood, and lymph.\n* Connective tissues are found throughout the body, providing support for organs, cushioning joints, protecting against infection, and transporting nutrients and oxygen.\n* Some common diseases that affect connective tissues include arthritis, osteoporosis, and scurvy.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2032,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7385,
            "description": "Ground substance, cells and basement membrane",
            "question_id": 1843,
            "is_correct": False,
            "created_at": "2024-07-02T13:54:26.214+05:30",
            "updated_at": "2024-07-02T13:54:26.214+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7386,
            "description": "Cartilage, intercellular matrix and serum",
            "question_id": 1843,
            "is_correct": False,
            "created_at": "2024-07-02T13:54:26.218+05:30",
            "updated_at": "2024-07-02T13:54:26.218+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7387,
            "description": "Cells, protein fibers and ground substance",
            "question_id": 1843,
            "is_correct": True,
            "created_at": "2024-07-02T13:54:26.221+05:30",
            "updated_at": "2024-07-02T13:54:26.221+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7388,
            "description": "Collagen, elastin and reticular fibers",
            "question_id": 1843,
            "is_correct": False,
            "created_at": "2024-07-02T13:54:26.224+05:30",
            "updated_at": "2024-07-02T13:54:26.224+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1844,
        "description": "The major functions of loose connective tissue include",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T13:58:11.110+05:30",
        "updated_at": "2024-11-30T18:39:24.063+05:30",
        "detailed_solution": "**Explanation:**\n\nLoose connective tissue is a type of connective tissue that is characterized by its loose arrangement of cells and fibers, which allows for greater flexibility and movement. It is found in a variety of locations throughout the body, including the dermis of the skin, the lining of the digestive tract, and the walls of blood vessels.\n\nThe major functions of loose connective tissue include:\n\n* **Support:** Loose connective tissue provides support and cushioning for the organs and tissues it surrounds.\n* **Protection:** Loose connective tissue can protect the underlying structures from injury or damage.\n* **Storage:** Loose connective tissue can store water, ions, and other nutrients.\n* **Communication:** Loose connective tissue contains blood vessels and nerves that allow for communication between different parts of the body.\n\nTherefore, the answer to the question \"The major functions of loose connective tissue include\" is \"All of the above.\"\n\n**Additional context:**\n\nLoose connective tissue is classified into two main types:\n\n* **Areolar connective tissue:** Areolar connective tissue is the most common type of loose connective tissue. It is found throughout the body and is characterized by its loose arrangement of cells and fibers.\n* **Adipose tissue:** Adipose tissue is a type of loose connective tissue that is specialized for the storage of fat. It is found beneath the skin, around the internal organs, and in the marrow of bones.\n\nLoose connective tissue is an important component of the body's structural organization. It provides support, protection, storage, and communication for the organs and tissues it surrounds.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2033,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7389,
            "description": "occupying spaces between organs and supporting epithelia",
            "question_id": 1844,
            "is_correct": False,
            "created_at": "2024-07-02T13:58:11.116+05:30",
            "updated_at": "2024-07-02T13:58:11.116+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7390,
            "description": "supporting and surrounding blood vessels and nerves",
            "question_id": 1844,
            "is_correct": False,
            "created_at": "2024-07-02T13:58:11.120+05:30",
            "updated_at": "2024-07-02T13:58:11.120+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7391,
            "description": "cushioning organs, storing lipids and facilitating diffusion",
            "question_id": 1844,
            "is_correct": False,
            "created_at": "2024-07-02T13:58:11.122+05:30",
            "updated_at": "2024-07-02T13:58:11.122+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7392,
            "description": "All of the above",
            "question_id": 1844,
            "is_correct": True,
            "created_at": "2024-07-02T13:58:11.125+05:30",
            "updated_at": "2024-07-02T13:58:11.125+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1845,
        "description": "Which one is the characteristic of epithelial tissue?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:03:03.248+05:30",
        "updated_at": "2024-11-30T18:39:24.278+05:30",
        "detailed_solution": "**Explanation:**\n\nEpithelial tissue is characterized by cells that tightly adhere to each other, forming a continuous sheet. This tissue lines the surfaces of the body and internal organs, acting as a protective barrier against external factors.\n\nThe cells in epithelial tissue do not have a rapid rate of cell division. In fact, they are relatively stable and do not divide frequently. This is because the primary function of epithelial tissue is to provide protection and support, rather than growth and development.\n\n**Additional Context:**\n\n* Epithelial tissue is composed of closely packed cells with little intercellular space.\n* The cells are usually arranged in a single layer (simple epithelium) or multiple layers (stratified epithelium).\n* The cells are attached to each other by cell junctions, including tight junctions, desmosomes, and gap junctions.\n* Epithelial tissue can be classified based on the shape of the cells, such as squamous, cuboidal, and columnar epithelium.\n* Epithelial tissue plays a crucial role in functions such as absorption, secretion, filtration, and protection.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2034,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7393,
            "description": "Tissues are highly vascularised.",
            "question_id": 1845,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:03.252+05:30",
            "updated_at": "2024-07-02T14:03:03.252+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7394,
            "description": "These cells never produce glands.",
            "question_id": 1845,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:03.254+05:30",
            "updated_at": "2024-07-02T14:03:03.254+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7395,
            "description": "The cells will have a rapid rate of cell division.",
            "question_id": 1845,
            "is_correct": True,
            "created_at": "2024-07-02T14:03:03.257+05:30",
            "updated_at": "2024-07-03T17:14:59.618+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7396,
            "description": "Large intercellular spaces are seen between cells.",
            "question_id": 1845,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:03.259+05:30",
            "updated_at": "2024-07-02T14:03:03.259+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1846,
        "description": "What will happen if ligaments are cut or broken?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:03:57.636+05:30",
        "updated_at": "2024-11-30T18:39:24.488+05:30",
        "detailed_solution": "**Ligaments** are strong, fibrous bands of connective tissue that connect bones to other bones, providing stability to joints. They play a crucial role in holding bones together and preventing excessive movement.\n\nIf ligaments are cut or broken, the bones they connect will become **unfixed**. This means that the bones will no longer be held in place and will be able to move independently of each other. This can lead to instability and pain in the joint, as well as an increased risk of dislocation or other injuries.\n\nIn severe cases, a torn ligament can completely disrupt the function of a joint, making it difficult or impossible to use. Depending on the severity of the tear, treatment may involve surgery to repair the ligament and restore stability to the joint.\n\n**Additional context:**\n\n* Ligaments are composed of collagen fibers, which are arranged in a parallel fashion to provide strength and flexibility.\n* Ligaments are not elastic and cannot stretch or recoil to their original length once they have been stretched or torn.\n* Ligaments are important for maintaining joint stability and preventing excessive movement, which can lead to injury.\n* Injuries to ligaments are common in sports and other physical activities.\n* Treatment for torn ligaments depends on the severity of the tear and may involve surgery, physical therapy, or rest and immobilization.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2035,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7397,
            "description": "No movements at joints.",
            "question_id": 1846,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:57.640+05:30",
            "updated_at": "2024-07-02T14:03:57.640+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7398,
            "description": "Bones will become fixed",
            "question_id": 1846,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:57.642+05:30",
            "updated_at": "2024-07-02T14:03:57.642+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7399,
            "description": "Bones will become unfixed.",
            "question_id": 1846,
            "is_correct": True,
            "created_at": "2024-07-02T14:03:57.644+05:30",
            "updated_at": "2024-07-02T14:03:57.644+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7400,
            "description": "Bone will move freely at joints.",
            "question_id": 1846,
            "is_correct": False,
            "created_at": "2024-07-02T14:03:57.646+05:30",
            "updated_at": "2024-07-02T14:03:57.646+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1847,
        "description": "The supportive skeletal structures in the human external ears and in the nose tip are examples of",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:05:46.187+05:30",
        "updated_at": "2024-11-30T18:39:24.711+05:30",
        "detailed_solution": "**Assistant**\n\n**Explanation:**\n\nThe supportive skeletal structures in the human external ears and in the nose tip are examples of cartilage. Cartilage is a type of connective tissue that is found throughout the body. It is composed of specialized cells called chondrocytes, which are embedded in a matrix of collagen and other proteins.\n\nCartilage is a strong and flexible tissue that provides support and protection to the body. It is also found in the joints, where it helps to reduce friction and wear. Cartilage is not as hard as bone, but it is more flexible and elastic. This makes it ideal for use in areas where flexibility is important.\n\nHere is a more detailed explanation of the role of cartilage in the human external ears and nose tip:\n\n* **External ears:** The external ears are made up of a thin layer of skin that is supported by a framework of cartilage. This cartilage gives the external ears their shape and allows them to move.\n* **Nose tip:** The nose tip is also made up of a thin layer of skin that is supported by a framework of cartilage. This cartilage gives the nose tip its shape and allows it to move.\n\nCartilage is an important tissue that plays a vital role in the structure and function of the human body. It is a strong and flexible tissue that provides support, protection, and flexibility.\n\n**Additional context:**\n\n* Cartilage is classified into three types: hyaline cartilage, elastic cartilage, and fibrocartilage.\n* Hyaline cartilage is the most common type of cartilage. It is found in the joints, nose tip, and external ears.\n* Elastic cartilage is found in the ears and epiglottis. It is more flexible than hyaline cartilage.\n* Fibrocartilage is the strongest type of cartilage. It is found in the intervertebral discs and menisci of the knee.\n\n**Conclusion:**\n\nThe supportive skeletal structures in the human external ears and in the nose tip are examples of cartilage. Cartilage is a strong and flexible tissue that provides support, protection, and flexibility.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2036,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7401,
            "description": "ligament",
            "question_id": 1847,
            "is_correct": False,
            "created_at": "2024-07-02T14:05:46.190+05:30",
            "updated_at": "2024-07-02T14:05:46.190+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7402,
            "description": "areolar tissue",
            "question_id": 1847,
            "is_correct": False,
            "created_at": "2024-07-02T14:05:46.193+05:30",
            "updated_at": "2024-07-02T14:05:46.193+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7403,
            "description": "bone",
            "question_id": 1847,
            "is_correct": False,
            "created_at": "2024-07-02T14:05:46.195+05:30",
            "updated_at": "2024-07-02T14:05:46.195+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7404,
            "description": "cartilage",
            "question_id": 1847,
            "is_correct": True,
            "created_at": "2024-07-02T14:05:46.198+05:30",
            "updated_at": "2024-07-02T14:05:46.198+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1848,
        "description": "Which of the following types of connective tissue is mismatched with its matrix?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:06:55.970+05:30",
        "updated_at": "2024-11-30T18:39:24.922+05:30",
        "detailed_solution": "**Explanation:**\n\nConnective tissues are classified based on the nature of their extracellular matrix (ECM). Cartilage is a type of connective tissue that has a solid, flexible matrix composed primarily of collagen fibers and a gel-like substance called chondroitin sulfate. This matrix is avascular, meaning it does not contain blood vessels. Therefore, the answer given in the question, \"Cartilage - Highly vascular matrix,\" is incorrect.\n\n**Additional Context:**\n\n* **Connective tissues:** Connect and support other tissues and organs in the body.\n* **Extracellular matrix (ECM):** A complex network of molecules that forms the structural framework of connective tissues and allows for cell adhesion and communication.\n* **Cartilage:** A type of connective tissue found in joints, where it provides support, cushioning, and flexibility.\n* **Types of cartilage based on ECM:**\n    * Hyaline cartilage: Found in joints, nose, and trachea; contains fine collagen fibers and chondroitin sulfate.\n    * Elastic cartilage: Found in the ear and epiglottis; contains elastic fibers and chondroitin sulfate.\n    * Fibrocartilage: Found in intervertebral discs and menisci; contains thick collagen fibers and chondroitin sulfate.\n* **Avascularity of cartilage:** Due to lack of blood vessels, cartilage relies on diffusion for nutrient supply and waste removal.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2037,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7405,
            "description": "Areolar - Loosely packed matrix of protein fibres",
            "question_id": 1848,
            "is_correct": False,
            "created_at": "2024-07-02T14:06:55.973+05:30",
            "updated_at": "2024-07-02T14:06:55.973+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7406,
            "description": "Bone - Mineralized matrix",
            "question_id": 1848,
            "is_correct": False,
            "created_at": "2024-07-02T14:06:55.975+05:30",
            "updated_at": "2024-07-02T14:06:55.975+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7407,
            "description": "Cartilage - Highly vascular matrix",
            "question_id": 1848,
            "is_correct": True,
            "created_at": "2024-07-02T14:06:55.977+05:30",
            "updated_at": "2024-07-02T14:06:55.977+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7408,
            "description": "Blood - Liquid matrix",
            "question_id": 1848,
            "is_correct": False,
            "created_at": "2024-07-02T14:06:55.979+05:30",
            "updated_at": "2024-07-08T10:32:47.323+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1849,
        "description": "The protein present in the matrix of cartilage is",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:08:32.283+05:30",
        "updated_at": "2024-11-30T18:39:25.123+05:30",
        "detailed_solution": "**Explanation:**\n\nCartilage is a type of connective tissue that provides support and flexibility to various parts of the body, such as the joints, ears, and nose. It is composed of specialized cells called chondrocytes, which are embedded in a matrix of extracellular material.\n\nThe matrix of cartilage consists primarily of water, collagen fibers, and a protein called chondrin. Chondrin is a type of glycosaminoglycan, which is a complex sugar molecule that contributes to the elasticity and compressibility of the cartilage.\n\nChondrin is responsible for providing the structural support and resilience to cartilage. It interacts with collagen fibers to form a reinforcing network that can withstand compression and tensile forces. This network allows cartilage to protect and cushion underlying tissues, such as bones and joints, while also providing flexibility for movement.\n\nTherefore, the protein present in the matrix of cartilage is **chondrin**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2038,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7409,
            "description": "Chitin",
            "question_id": 1849,
            "is_correct": False,
            "created_at": "2024-07-02T14:08:32.288+05:30",
            "updated_at": "2024-07-02T14:08:32.288+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7410,
            "description": "Chondrin",
            "question_id": 1849,
            "is_correct": True,
            "created_at": "2024-07-02T14:08:32.294+05:30",
            "updated_at": "2024-07-02T14:08:32.294+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7411,
            "description": "Ossein",
            "question_id": 1849,
            "is_correct": False,
            "created_at": "2024-07-02T14:08:32.297+05:30",
            "updated_at": "2024-07-02T14:08:32.297+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7412,
            "description": "Chondriotin",
            "question_id": 1849,
            "is_correct": False,
            "created_at": "2024-07-02T14:08:32.300+05:30",
            "updated_at": "2024-07-02T14:08:32.300+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1850,
        "description": "The camel's hump is composed of a tissue which provides water when oxidized. It is:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:10:01.432+05:30",
        "updated_at": "2024-11-30T18:39:25.325+05:30",
        "detailed_solution": "**Explanation:**\n\nThe primary function of a camel's hump is to store adipose tissue, not water. Adipose tissue is composed of fat cells, which are specialized cells that store triglycerides, a form of energy storage.\n\nWhen the camel needs additional energy, such as during food shortages or long journeys, it can access the triglycerides stored in its hump. This process involves breaking down the triglycerides and releasing fatty acids, which are then oxidized to produce energy.\n\n**Additional Context:**\n\nThe camel's hump is a unique adaptation that allows it to survive in harsh desert environments where water and food are scarce. It is located on the back and can weigh up to 80 pounds.\n\nIn addition to storing adipose tissue, the camel's hump also acts as an insulator, helping to regulate the animal's body temperature.\n\nThe hump also provides structural support for the camel's body, enabling it to carry heavy loads.\n\n**NEET Exam Relevance:**\n\nThis question is relevant to the NEET exam because it tests the student's understanding of the structural organization of animals. The hump of a camel is a specific example of an adaptation that allows animals to survive in different environments.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2039,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7413,
            "description": "Skeletal tissue",
            "question_id": 1850,
            "is_correct": False,
            "created_at": "2024-07-02T14:10:01.439+05:30",
            "updated_at": "2024-07-02T14:10:01.439+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7414,
            "description": "Areolar tissue",
            "question_id": 1850,
            "is_correct": False,
            "created_at": "2024-07-02T14:10:01.443+05:30",
            "updated_at": "2024-07-02T14:10:01.443+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7415,
            "description": "Adipose tissue",
            "question_id": 1850,
            "is_correct": True,
            "created_at": "2024-07-02T14:10:01.446+05:30",
            "updated_at": "2024-07-02T14:10:01.446+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7416,
            "description": "Muscular tissue",
            "question_id": 1850,
            "is_correct": False,
            "created_at": "2024-07-02T14:10:01.449+05:30",
            "updated_at": "2024-07-02T14:10:01.449+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1851,
        "description": "The function of the gap junction is to",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:13:15.516+05:30",
        "updated_at": "2024-11-30T18:39:25.525+05:30",
        "detailed_solution": "**Explanation:**\n\nGap junctions are specialized intercellular connections that allow direct communication between adjacent cells. They are channels that span the plasma membranes of adjoining cells, creating a cytoplasmic connection between them.\n\nThe primary function of gap junctions is to facilitate rapid and efficient transfer of small molecules, ions, and signaling molecules between cells. This allows for the coordinated and synchronized activity of cells within a tissue or organ. Gap junctions are present in various tissues, including the heart, brain, and liver, where intercellular communication is crucial.\n\n**Additional context:**\n\n* Gap junctions are typically 8-10 nm wide and are formed by the docking of two connexons, each consisting of six connexin proteins.\n* Connexons align to form a central pore that allows the passage of small molecules (up to 1.2 kDa).\n* Gap junctions can be regulated by various factors, including voltage, calcium concentration, and phosphorylation, which can alter their permeability and communication efficiency.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2040,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7417,
            "description": "separate two cells from each other",
            "question_id": 1851,
            "is_correct": False,
            "created_at": "2024-07-02T14:13:15.533+05:30",
            "updated_at": "2024-07-02T14:13:15.533+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7418,
            "description": "stop substance from leaking across a tissue.",
            "question_id": 1851,
            "is_correct": False,
            "created_at": "2024-07-02T14:13:15.537+05:30",
            "updated_at": "2024-07-02T14:13:15.537+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7419,
            "description": "performing cementing to keep neighbouring cells together",
            "question_id": 1851,
            "is_correct": False,
            "created_at": "2024-07-02T14:13:15.540+05:30",
            "updated_at": "2024-07-02T14:13:15.540+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7420,
            "description": "facilitate communication between adjoining cells by connecting the cytoplasm for rapid transfer of ions, small molecules and some large molecules",
            "question_id": 1851,
            "is_correct": True,
            "created_at": "2024-07-02T14:13:15.543+05:30",
            "updated_at": "2024-07-02T14:13:15.543+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1852,
        "description": "Choose the correctly matched pair.",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:14:40.254+05:30",
        "updated_at": "2024-11-30T18:39:25.738+05:30",
        "detailed_solution": "**Explanation:**\n\nAreolar tissue is a type of loose connective tissue that is widely distributed throughout the body. It is characterized by its loose arrangement of cells and fibers, and its ability to change its shape easily. Areolar tissue fills the spaces between organs and provides support and cushioning for the surrounding tissues. It also contains blood vessels and nerves that supply the tissues with nutrients and oxygen.\n\n**Additional context:**\n\n* Loose connective tissue is a type of connective tissue that is characterized by its loose arrangement of cells and fibers. It is found in many parts of the body, including the skin, subcutaneous tissue, and around organs.\n* Loose connective tissue is made up of three main components: cells, fibers, and ground substance. The cells are typically fibroblasts, which are responsible for producing the fibers and ground substance. The fibers are made of collagen and elastin, which provide strength and elasticity to the tissue. The ground substance is a gel-like substance that fills the spaces between the cells and fibers.\n* Loose connective tissue has a variety of functions, including:\n    * Providing support and cushioning for the surrounding tissues\n    * Transporting nutrients and oxygen to the tissues\n    * Removing waste products from the tissues\n    * Providing a reservoir of stem cells that can differentiate into other types of cells",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2041,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7421,
            "description": "Tendon-Specialized connective tissue",
            "question_id": 1852,
            "is_correct": False,
            "created_at": "2024-07-02T14:14:40.262+05:30",
            "updated_at": "2024-07-02T14:14:40.262+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7422,
            "description": "Adipose tissue - Dense connective tissue",
            "question_id": 1852,
            "is_correct": False,
            "created_at": "2024-07-02T14:14:40.266+05:30",
            "updated_at": "2024-07-02T14:14:40.266+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7423,
            "description": "Areolar tissue - Loose connective tissue",
            "question_id": 1852,
            "is_correct": True,
            "created_at": "2024-07-02T14:14:40.269+05:30",
            "updated_at": "2024-07-02T14:14:40.269+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7424,
            "description": "Cartilage-Loose connective tissue",
            "question_id": 1852,
            "is_correct": False,
            "created_at": "2024-07-02T14:14:40.271+05:30",
            "updated_at": "2024-07-02T14:14:40.271+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1853,
        "description": "Muscle tissue cells are contractile, which means they",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:16:16.633+05:30",
        "updated_at": "2024-11-30T18:39:25.941+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2042,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7425,
            "description": "are responsible for the production and secretion of enzymes.",
            "question_id": 1853,
            "is_correct": False,
            "created_at": "2024-07-02T14:16:16.637+05:30",
            "updated_at": "2024-07-02T14:16:16.637+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7426,
            "description": "are specialized in contraction and relaxation",
            "question_id": 1853,
            "is_correct": True,
            "created_at": "2024-07-02T14:16:16.640+05:30",
            "updated_at": "2024-07-02T14:16:16.640+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7427,
            "description": "help in the movement of involuntary organs only.",
            "question_id": 1853,
            "is_correct": False,
            "created_at": "2024-07-02T14:16:16.642+05:30",
            "updated_at": "2024-07-02T14:16:16.642+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7428,
            "description": "all of the above",
            "question_id": 1853,
            "is_correct": False,
            "created_at": "2024-07-02T14:16:16.645+05:30",
            "updated_at": "2024-07-02T14:16:16.645+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1854,
        "description": "The fibres of which of the following muscles are fusiform and do not show striations",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:18:01.820+05:30",
        "updated_at": "2024-11-30T18:39:26.152+05:30",
        "detailed_solution": "**Explanation:**\n\n* **Fusiform fibers:** Muscle fibers that are tapered at both ends.\n* **Non-striated (smooth) muscles:** Muscles that lack visible cross-striations under the microscope.\n\nSmooth muscles are characterized by fusiform fibers and the absence of striations. These muscles are found in the walls of internal organs, such as the digestive tract, blood vessels, and bladder, where they control involuntary movements.\n\nIn contrast, skeletal and cardiac muscles have striated fibers and are under voluntary and involuntary control, respectively.\n\n**Additional context:**\n\n* **Muscle tissue:** A type of tissue that specializes in contraction and movement.\n* **Muscle fibers:** The individual cells that make up muscle tissue.\n* **Cross-striations:** The distinctive banding pattern seen under the microscope in skeletal and cardiac muscles.\n\n**Significance for NEET exam:**\n\nUnderstanding the different types of muscle tissue, including their structural features and functions, is essential for NEET exam preparation. This knowledge helps students:\n\n* Distinguish between different types of muscles based on their appearance and properties.\n* Grasp the relationship between muscle structure and function.\n* Apply this knowledge to answer questions on muscle biology in the NEET exam.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2043,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7429,
            "description": "Skeletal muscles",
            "question_id": 1854,
            "is_correct": False,
            "created_at": "2024-07-02T14:18:01.824+05:30",
            "updated_at": "2024-07-02T14:18:01.824+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7430,
            "description": "Cardiac muscles",
            "question_id": 1854,
            "is_correct": False,
            "created_at": "2024-07-02T14:18:01.827+05:30",
            "updated_at": "2024-07-02T14:18:01.827+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7431,
            "description": "Both (a) and (b)",
            "question_id": 1854,
            "is_correct": False,
            "created_at": "2024-07-02T14:18:01.829+05:30",
            "updated_at": "2024-07-02T14:18:01.829+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7432,
            "description": "Smooth muscles",
            "question_id": 1854,
            "is_correct": True,
            "created_at": "2024-07-02T14:18:01.831+05:30",
            "updated_at": "2024-07-02T14:18:01.831+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1855,
        "description": "Intercalated discs are the communication junctions between the cells of",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:19:04.789+05:30",
        "updated_at": "2024-11-30T18:39:26.363+05:30",
        "detailed_solution": "**Intercalated discs** are the communication junctions between the cells of cardiac muscles. They allow for the rapid and coordinated contraction of the heart.\n\n* **Structure:** Intercalated discs are complex structures that consist of several different types of junctions, including gap junctions, desmosomes, and fascia adherens. Gap junctions allow for the electrical coupling of adjacent cells, while desmosomes and fascia adherens provide mechanical support and prevent the cells from pulling apart.\n* **Function:** The main function of intercalated discs is to allow for the rapid and coordinated contraction of the heart. When an electrical impulse reaches a cardiac muscle cell, it travels through the intercalated discs to adjacent cells. This causes all of the cells in the heart to contract at the same time, which pumps blood out of the heart and into the body.\n\n**Additional context:**\n\n* Intercalated discs are only found in cardiac muscle cells.\n* The structure of intercalated discs is unique to cardiac muscle cells and is essential for the proper function of the heart.\n* Intercalated discs are a target for a number of drugs, including calcium channel blockers and beta-blockers. These drugs can affect the function of intercalated discs and can therefore be used to treat a variety of heart conditions.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2044,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7433,
            "description": "cardiac muscles",
            "question_id": 1855,
            "is_correct": True,
            "created_at": "2024-07-02T14:19:04.796+05:30",
            "updated_at": "2024-07-02T14:19:04.796+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7434,
            "description": "striped muscles",
            "question_id": 1855,
            "is_correct": False,
            "created_at": "2024-07-02T14:19:04.804+05:30",
            "updated_at": "2024-07-02T14:19:04.804+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7435,
            "description": "adipose tissue",
            "question_id": 1855,
            "is_correct": False,
            "created_at": "2024-07-02T14:19:04.809+05:30",
            "updated_at": "2024-07-02T14:19:04.809+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7436,
            "description": "nerve and striated muscles",
            "question_id": 1855,
            "is_correct": False,
            "created_at": "2024-07-02T14:19:04.811+05:30",
            "updated_at": "2024-07-02T14:19:04.811+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1856,
        "description": "Smooth muscles are _______.",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:23:22.049+05:30",
        "updated_at": "2024-11-30T18:39:26.576+05:30",
        "detailed_solution": "**Explanation:**\n\nSmooth muscles are involuntary muscles, meaning they are not under conscious control. They are found in the walls of internal organs, such as the stomach, intestines, and blood vessels. Smooth muscles are spindle-shaped, uninucleated, and tapering.\n\n**Additional Context:**\n\n* Smooth muscles contract slowly and rhythmically.\n* They are responsible for involuntary movements, such as digestion, blood flow regulation, and childbirth.\n* Smooth muscles are innervated by the autonomic nervous system.\n\n**How to Use This Information to Answer Similar Questions:**\n\nTo answer similar questions, students should remember the key characteristics of smooth muscles:\n\n* Involuntary\n* Spindle-shaped\n* Uninucleated\n* Tapering\n\nThese characteristics can be used to differentiate smooth muscles from other types of muscles, such as skeletal and cardiac muscles.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2045,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7437,
            "description": "voluntary, branched, uninucleate",
            "question_id": 1856,
            "is_correct": False,
            "created_at": "2024-07-02T14:23:22.054+05:30",
            "updated_at": "2024-07-02T14:23:22.054+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7438,
            "description": "voluntary, multinucleate, cylindrical",
            "question_id": 1856,
            "is_correct": False,
            "created_at": "2024-07-02T14:23:22.059+05:30",
            "updated_at": "2024-07-02T14:23:22.059+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7439,
            "description": "involuntary, cylindrical, multinucleate",
            "question_id": 1856,
            "is_correct": False,
            "created_at": "2024-07-02T14:23:22.062+05:30",
            "updated_at": "2024-07-02T14:23:22.062+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7440,
            "description": "involuntary, spindle shaped, uninucleated, tapering",
            "question_id": 1856,
            "is_correct": True,
            "created_at": "2024-07-02T14:23:22.064+05:30",
            "updated_at": "2024-07-03T18:13:11.213+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1857,
        "description": "Which of the following statement(s) is/are correct about muscle tissue?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:27:12.164+05:30",
        "updated_at": "2024-11-30T18:39:26.781+05:30",
        "detailed_solution": "**Explanation:**\n\nMuscle tissue is one of the four primary tissue types in animals. It is responsible for movement and maintaining posture. There are three types of muscle tissue:\n\n**1. Skeletal muscle:**\n* Attached to bones and responsible for voluntary movement.\n* Striated, meaning it has visible bands of actin and myosin filaments.\n* Multinucleated, with many nuclei per cell.\n\n**2. Smooth muscle:**\n* Found in internal organs, blood vessels, and airways.\n* Not striated, appearing smooth under the microscope.\n* Mononucleated, with a single nucleus per cell.\n\n**3. Cardiac muscle:**\n* Found only in the heart.\n* Striated, but with unique intercalated discs that connect cells and allow for synchronized contractions.\n* Mononucleated, with a single nucleus per cell.\n\n**All of the given statements are correct about muscle tissue:**\n\n* **Striations:** Skeletal and cardiac muscle are striated, while smooth muscle is not.\n* **Multinucleation:** Skeletal muscle is multinucleated, while smooth and cardiac muscle are mononucleated.\n* **Controlled movement:** Skeletal muscle allows for voluntary movement, while smooth and cardiac muscle control involuntary movements.\n* **Excitability:** Muscle tissue is excitable, meaning it can respond to stimuli and contract.\n* **Contractility:** Muscle tissue has the ability to shorten or contract in response to a stimulus.\n\nTherefore, the correct answer is \"All of the above.\"",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2046,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7441,
            "description": "Each muscle is made of many long, cylindrical fibres arranged in parallel arrays.",
            "question_id": 1857,
            "is_correct": False,
            "created_at": "2024-07-02T14:27:12.172+05:30",
            "updated_at": "2024-07-02T14:27:12.172+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7442,
            "description": "Muscle fibres contract (shorten) in response to stimulation, then relax (lengthen) and return to their uncontracted state in a coordinated fashion",
            "question_id": 1857,
            "is_correct": False,
            "created_at": "2024-07-02T14:27:12.174+05:30",
            "updated_at": "2024-07-02T14:27:12.174+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7443,
            "description": "Muscles play an active role in all movements of the body",
            "question_id": 1857,
            "is_correct": False,
            "created_at": "2024-07-02T14:27:12.177+05:30",
            "updated_at": "2024-07-02T14:27:12.177+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7444,
            "description": "All of the above",
            "question_id": 1857,
            "is_correct": True,
            "created_at": "2024-07-02T14:27:12.179+05:30",
            "updated_at": "2024-07-02T14:27:12.179+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1858,
        "description": "Three essential components of most neurons are",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:28:14.229+05:30",
        "updated_at": "2024-11-30T18:39:26.994+05:30",
        "detailed_solution": "**Explanation:**\n\nNeurons are the basic functional units of the nervous system. They are composed of three main components:\n\n1. **Cell body (Soma):** The cell body is the metabolic center of the neuron. It contains the nucleus, which carries the cell's genetic material, and organelles like mitochondria, Golgi apparatus, and endoplasmic reticulum.\n\n2. **Dendrites:** Dendrites are branched extensions of the cell body that receive signals from other neurons. They are responsible for collecting information from the environment and transmitting it to the cell body.\n\n3. **Axon:** The axon is a long, thin projection of the cell body that carries signals away from the neuron. It is covered by a myelin sheath, which insulates the axon and speeds up the transmission of signals.\n\nAdditional context:\n\n* Neurons are specialized cells that communicate with each other through electrical and chemical signals.\n* The structure of a neuron is adapted to its function.\n* The cell body integrates incoming signals and initiates the output signal.\n* Dendrites increase the surface area of the neuron, allowing it to receive a large number of signals.\n* The axon ensures rapid and efficient transmission of signals over long distances.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2047,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7445,
            "description": "simple epithelium, extracellular matrix and nerves.",
            "question_id": 1858,
            "is_correct": False,
            "created_at": "2024-07-02T14:28:14.233+05:30",
            "updated_at": "2024-07-02T14:28:14.233+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7446,
            "description": "axon, dendrites and cell body.",
            "question_id": 1858,
            "is_correct": True,
            "created_at": "2024-07-02T14:28:14.237+05:30",
            "updated_at": "2024-07-02T14:28:14.237+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7447,
            "description": "nerve cells, synapse and neuroglia.",
            "question_id": 1858,
            "is_correct": False,
            "created_at": "2024-07-02T14:28:14.241+05:30",
            "updated_at": "2024-07-02T14:28:14.241+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7448,
            "description": "mylein sheeth, node of Ranvier and Schwann cells",
            "question_id": 1858,
            "is_correct": False,
            "created_at": "2024-07-02T14:28:14.245+05:30",
            "updated_at": "2024-07-02T14:28:14.245+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1859,
        "description": "Neuroglia are",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:30:13.983+05:30",
        "updated_at": "2024-11-30T18:39:27.201+05:30",
        "detailed_solution": "**Explanation:**\n\nNeuroglia are supporting cells of neural tissue. They do not participate in the transmission of nerve impulses. They provide structural support and protection to neurons. They also help in the maintenance of the neural environment.\n\n**Additional context:**\n\n* Neuroglia are also known as glial cells.\n* They are divided into two main types:\n    * Macroglia: These include astrocytes, oligodendrocytes, and ependymal cells.\n    * Microglia: These are phagocytic cells that remove debris and pathogens from the neural tissue.\n* Neuroglia play a crucial role in the development, function, and repair of the nervous system.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2048,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7449,
            "description": "excitable cells of neural tissue.",
            "question_id": 1859,
            "is_correct": False,
            "created_at": "2024-07-02T14:30:13.987+05:30",
            "updated_at": "2024-07-02T14:30:13.987+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7450,
            "description": "supporting and non-protecting cells of neural tissue",
            "question_id": 1859,
            "is_correct": True,
            "created_at": "2024-07-02T14:30:13.990+05:30",
            "updated_at": "2024-07-02T14:30:13.990+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7451,
            "description": "two to three times in volume of neural tissue",
            "question_id": 1859,
            "is_correct": False,
            "created_at": "2024-07-02T14:30:13.993+05:30",
            "updated_at": "2024-07-02T14:30:13.993+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7452,
            "description": "protective and excitable cells of neural tissue",
            "question_id": 1859,
            "is_correct": False,
            "created_at": "2024-07-02T14:30:14.006+05:30",
            "updated_at": "2024-07-02T14:30:14.006+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1860,
        "description": "Nervous tissue cells that play several supporting roles but do not transmit impulses are called",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:32:03.449+05:30",
        "updated_at": "2024-11-30T18:39:27.409+05:30",
        "detailed_solution": "**Explanation:**\n\n**Nervous tissue** is composed of two main types of cells: neurons and neuroglia.\n\n* **Neurons** are the functional units of the nervous system and transmit electrical impulses.\n\n* **Neuroglia** (also called glial cells) are supporting cells that play several important roles but do not transmit impulses themselves.\n\n**Functions of Neuroglia:**\n\n* **Support and insulation:** Glial cells provide structural support and insulation to neurons, allowing them to function properly.\n* **Nutrient supply:** Glial cells help in the transport of nutrients and oxygen to neurons.\n* **Waste removal:** Glial cells remove waste products from the nervous tissue.\n* **Myelination:** Schwann cells and oligodendrocytes form myelin sheaths around the axons of neurons, which speeds up the transmission of electrical impulses.\n* **Phagocytosis:** Microglial cells act as phagocytes, removing damaged or dead neurons and debris from the nervous tissue.\n\nTherefore, the correct answer is **glial cells**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2049,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7453,
            "description": "glial cells",
            "question_id": 1860,
            "is_correct": True,
            "created_at": "2024-07-02T14:32:03.452+05:30",
            "updated_at": "2024-07-02T14:32:03.452+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7454,
            "description": "dendrites",
            "question_id": 1860,
            "is_correct": False,
            "created_at": "2024-07-02T14:32:03.454+05:30",
            "updated_at": "2024-07-02T14:32:03.454+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7455,
            "description": "nerve cells",
            "question_id": 1860,
            "is_correct": False,
            "created_at": "2024-07-02T14:32:03.456+05:30",
            "updated_at": "2024-07-02T14:32:03.456+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7456,
            "description": "neurons",
            "question_id": 1860,
            "is_correct": False,
            "created_at": "2024-07-02T14:32:03.458+05:30",
            "updated_at": "2024-07-02T14:32:03.458+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1861,
        "description": "Which of the following statements Is not correct regarding neural tissue ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:40:26.660+05:30",
        "updated_at": "2024-11-30T18:39:27.615+05:30",
        "detailed_solution": "The statement \"Chondrocytes, the unit of neural system are excitable cells\" is not True. \n\n**Explanation**\n\nNeural tissue is a type of tissue that makes up the nervous system. The unit of neural tissue is the neuron, which is a specialized cell that is capable of transmitting electrical signals throughout the body. Chondrocytes, on the other hand, are cells that make up cartilage, which is a type of connective tissue. Chondrocytes are not excitable cells, and they do not play a role in the transmission of electrical signals.\n\nHere is a breakdown of the other statements in the question:\n\n**A). Neurons are the structural and functional unit of the nervous system**\n- This is True. Neurons are the basic building blocks of the nervous system, and they are responsible for transmitting electrical signals throughout the body.\n**B). Neuroglia provide structural and nutritional support to the neurons**\n- This is also True. Neuroglia are cells that provide support and protection to the neurons. They help to keep the neurons in place, and they also provide them with nutrients and oxygen.\n**C). Nervous tissue is found only in the brain and spinal cord**\n- This is not True. Nervous tissue is found throughout the body, including in the peripheral nerves, which are responsible for transmitting signals to and from the brain and spinal cord.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2050,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7457,
            "description": "it exerts the greatest control over the body's responsiveness to changing conditions.",
            "question_id": 1861,
            "is_correct": False,
            "created_at": "2024-07-02T14:40:26.686+05:30",
            "updated_at": "2024-07-02T14:40:26.686+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7458,
            "description": "Chondrocytes, the unit of neural system are excitable cells.",
            "question_id": 1861,
            "is_correct": True,
            "created_at": "2024-07-02T14:40:26.694+05:30",
            "updated_at": "2024-07-02T14:40:26.694+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7459,
            "description": "Neuroglial cells protect and support neurons.",
            "question_id": 1861,
            "is_correct": False,
            "created_at": "2024-07-02T14:40:26.703+05:30",
            "updated_at": "2024-07-02T14:40:26.703+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7460,
            "description": "When a neuron is suitably stimulated, an electrical disturbance is generated.",
            "question_id": 1861,
            "is_correct": False,
            "created_at": "2024-07-02T14:40:26.709+05:30",
            "updated_at": "2024-07-02T14:40:26.709+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1862,
        "description": "The secretions of endocrine glands are released directly",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:44:43.870+05:30",
        "updated_at": "2024-11-30T18:39:27.820+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2051,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7461,
            "description": "into the skin surface",
            "question_id": 1862,
            "is_correct": False,
            "created_at": "2024-07-02T14:44:43.876+05:30",
            "updated_at": "2024-07-02T14:44:43.876+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7462,
            "description": "into the blood stream",
            "question_id": 1862,
            "is_correct": True,
            "created_at": "2024-07-02T14:44:43.880+05:30",
            "updated_at": "2024-07-02T14:44:43.880+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7463,
            "description": "into a gland duct",
            "question_id": 1862,
            "is_correct": False,
            "created_at": "2024-07-02T14:44:43.882+05:30",
            "updated_at": "2024-07-02T14:44:43.882+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7464,
            "description": "into the brain tissue",
            "question_id": 1862,
            "is_correct": False,
            "created_at": "2024-07-02T14:44:43.884+05:30",
            "updated_at": "2024-07-02T14:44:43.884+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1863,
        "description": "Mast cells are associated with",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:45:40.377+05:30",
        "updated_at": "2024-11-30T18:39:28.026+05:30",
        "detailed_solution": "**Mast cells** are a type of white blood cell that is found in connective tissue. They are associated with **areolar connective tissue**, which is a loose, irregularly arranged type of connective tissue that is found in many parts of the body, such as the dermis of the skin and the submucosa of the digestive tract. Mast cells are important for the body's immune response, as they release histamine and other inflammatory mediators when they are activated.\n\nHere are some additional details about mast cells and areolar connective tissue:\n\n* Mast cells are derived from stem cells in the bone marrow. They circulate in the blood and then migrate to tissues where they are needed.\n* Areolar connective tissue is a type of loose connective tissue that is characterized by its loose, irregular arrangement of collagen fibers. It is found in many parts of the body, such as the dermis of the skin, the submucosa of the digestive tract, and the stroma of organs.\n* Mast cells are activated by a variety of stimuli, including allergens, cytokines, and physical trauma. When they are activated, they release histamine and other inflammatory mediators, which cause blood vessels to dilate and become more permeable. This leads to increased blood flow and the accumulation of fluid and white blood cells in the affected area.\n* Mast cells play an important role in the body's immune response. They are involved in both innate immunity and adaptive immunity. In innate immunity, mast cells release histamine and other inflammatory mediators that help to recruit other immune cells to the site of infection. In adaptive immunity, mast cells present antigens to T cells, which helps to activate the adaptive immune response.\n\nOverall, mast cells are important cells that play a key role in the body's immune response. They are associated with areolar connective tissue, which is a type of loose connective tissue that is found in many parts of the body.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2052,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7465,
            "description": "exocrine glands",
            "question_id": 1863,
            "is_correct": False,
            "created_at": "2024-07-02T14:45:40.381+05:30",
            "updated_at": "2024-07-02T14:45:40.381+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7466,
            "description": "endocrine glands",
            "question_id": 1863,
            "is_correct": False,
            "created_at": "2024-07-02T14:45:40.385+05:30",
            "updated_at": "2024-07-02T14:45:40.385+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7467,
            "description": "areolar connective tissue",
            "question_id": 1863,
            "is_correct": True,
            "created_at": "2024-07-02T14:45:40.388+05:30",
            "updated_at": "2024-07-02T14:45:40.388+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7468,
            "description": "neural tissue",
            "question_id": 1863,
            "is_correct": False,
            "created_at": "2024-07-02T14:45:40.392+05:30",
            "updated_at": "2024-07-02T14:45:40.392+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1864,
        "description": "Which of the following is involved in the production of new blood cells?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:49:01.268+05:30",
        "updated_at": "2024-11-30T18:39:28.232+05:30",
        "detailed_solution": "**Explanation:**\n\nBone marrow is a soft, jelly-like tissue found inside the cavities of bones. It is responsible for the production of new blood cells through a process called hematopoiesis.\n\nHematopoiesis involves the differentiation of stem cells into various types of blood cells, including:\n\n* Red blood cells (erythrocytes)\n* White blood cells (leukocytes)\n* Platelets (thrombocytes)\n\nThese blood cells play crucial roles in maintaining the body's health and functioning:\n\n* **Red blood cells:** Carry oxygen from the lungs to various tissues and organs.\n* **White blood cells:** Defend the body against infections and foreign substances.\n* **Platelets:** Help stop bleeding by forming clots.\n\nTherefore, bone marrow is essential for maintaining a constant supply of new blood cells and ensuring the proper functioning of the circulatory system.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2053,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7469,
            "description": "Adipose cell",
            "question_id": 1864,
            "is_correct": False,
            "created_at": "2024-07-02T14:49:01.272+05:30",
            "updated_at": "2024-07-02T14:49:01.272+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7470,
            "description": "Bone marrow",
            "question_id": 1864,
            "is_correct": True,
            "created_at": "2024-07-02T14:49:01.276+05:30",
            "updated_at": "2024-07-02T14:49:01.276+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7471,
            "description": "Liver",
            "question_id": 1864,
            "is_correct": False,
            "created_at": "2024-07-02T14:49:01.281+05:30",
            "updated_at": "2024-07-02T14:49:01.281+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7472,
            "description": "Matrix",
            "question_id": 1864,
            "is_correct": False,
            "created_at": "2024-07-02T14:49:01.284+05:30",
            "updated_at": "2024-07-02T14:49:01.284+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1865,
        "description": "Which of the following vertebrate tissues would be an excellent source of collagen?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:52:00.494+05:30",
        "updated_at": "2024-11-30T18:39:28.444+05:30",
        "detailed_solution": "**Explanation:**\n\nCollagen is a fibrous protein found abundantly in connective tissues. **Tendons** are composed primarily of dense connective tissue, which is rich in collagen fibers. These fibers provide strength and flexibility to tendons, enabling them to withstand the forces of muscle contractions and transmit forces to bones.\n\n**Other vertebrate tissues that contain collagen include:**\n\n* **Bones:** Collagen is found within the organic matrix of bones, providing strength and rigidity.\n* **Cartilage:** Collagen is a major component of the extracellular matrix of cartilage, giving it resilience and resistance to compression.\n* **Skin:** Collagen is found in the dermis layer of the skin, contributing to its elasticity and strength.\n\nHowever, tendons are considered an excellent source of collagen due to their high concentration of tightly packed collagen fibers. These fibers can be easily extracted and purified for use in various medical and industrial applications, such as wound healing, tissue engineering, and cosmetics.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2054,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7473,
            "description": "Liver",
            "question_id": 1865,
            "is_correct": False,
            "created_at": "2024-07-02T14:52:00.498+05:30",
            "updated_at": "2024-07-02T14:52:00.498+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7474,
            "description": "Nerve",
            "question_id": 1865,
            "is_correct": False,
            "created_at": "2024-07-02T14:52:00.500+05:30",
            "updated_at": "2024-07-02T14:52:00.500+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7475,
            "description": "Muscle",
            "question_id": 1865,
            "is_correct": False,
            "created_at": "2024-07-02T14:52:00.504+05:30",
            "updated_at": "2024-07-02T14:52:00.504+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7476,
            "description": "Tendon",
            "question_id": 1865,
            "is_correct": True,
            "created_at": "2024-07-02T14:52:00.508+05:30",
            "updated_at": "2024-07-02T14:52:00.508+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1866,
        "description": "The complexity in organ and organ systems displays certain discernable trend. This discernable trend is known as",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:53:37.810+05:30",
        "updated_at": "2024-11-30T18:39:28.648+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2055,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7477,
            "description": "Evolutionary trend",
            "question_id": 1866,
            "is_correct": True,
            "created_at": "2024-07-02T14:53:37.813+05:30",
            "updated_at": "2024-07-02T14:53:37.813+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7478,
            "description": "Morphological trend",
            "question_id": 1866,
            "is_correct": False,
            "created_at": "2024-07-02T14:53:37.824+05:30",
            "updated_at": "2024-07-02T14:53:37.824+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7479,
            "description": "Complexity trend",
            "question_id": 1866,
            "is_correct": False,
            "created_at": "2024-07-02T14:53:37.827+05:30",
            "updated_at": "2024-07-02T14:53:37.827+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7480,
            "description": "Anatomical trend",
            "question_id": 1866,
            "is_correct": False,
            "created_at": "2024-07-02T14:53:37.830+05:30",
            "updated_at": "2024-07-02T14:53:37.830+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1867,
        "description": "Which of the following statement is correct about anatomy",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T14:56:41.711+05:30",
        "updated_at": "2024-11-30T18:39:28.846+05:30",
        "detailed_solution": "**Answer: Study of morphology of internal organs in the animal**\n\n**Explanation:**\n\nAnatomy is a branch of biology that deals with the structure and organization of living things. It is divided into two main branches:\n\n* **Gross anatomy** - studies the structure of organs and body systems as seen with the naked eye\n* **Microscopic anatomy** - studies the structure of cells and tissues using microscopes\n\nThe study of the morphology of internal organs in animals falls under the branch of gross anatomy. It involves examining the shape, size, and arrangement of organs within the body. This knowledge is essential for understanding how the body functions and how diseases can affect it.\n\n**Additional context:**\n\n* Anatomy is often divided into several subspecialties, including:\n    * **Human anatomy** - the study of the structure of the human body\n    * **Comparative anatomy** - the study of the structure of different animal species\n    * **Developmental anatomy** - the study of how the body develops from an embryo to an adult\n    * **Pathological anatomy** - the study of how diseases affect the body's structure\n* Anatomy is closely related to physiology, which studies the function of living things. Together, anatomy and physiology provide a comprehensive understanding of how our bodies work.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2056,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7481,
            "description": "Study of form or externally visible features",
            "question_id": 1867,
            "is_correct": False,
            "created_at": "2024-07-02T14:56:41.716+05:30",
            "updated_at": "2024-07-02T14:56:41.716+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7482,
            "description": "Study of internal as well as external features.",
            "question_id": 1867,
            "is_correct": False,
            "created_at": "2024-07-02T14:56:41.722+05:30",
            "updated_at": "2024-07-02T14:56:41.722+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7483,
            "description": "Study of morphology of internal organs in the animal",
            "question_id": 1867,
            "is_correct": True,
            "created_at": "2024-07-02T14:56:41.725+05:30",
            "updated_at": "2024-07-02T14:56:41.725+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7484,
            "description": "None of the above statements",
            "question_id": 1867,
            "is_correct": False,
            "created_at": "2024-07-02T14:56:41.728+05:30",
            "updated_at": "2024-07-02T14:56:41.728+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1868,
        "description": "General function of gland is to",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:04:19.702+05:30",
        "updated_at": "2024-11-30T18:39:29.056+05:30",
        "detailed_solution": "**Explanation:**\n\nGlands are specialized structures in animals that produce and secrete chemicals known as hormones, enzymes, or other substances. These substances play crucial roles in regulating and maintaining various body functions and processes.\n\n**Additional Context:**\n\n* **Types of glands:**\n    * Endocrine glands: Secrete hormones directly into the bloodstream.\n    * Exocrine glands: Secrete enzymes or other fluids into ducts or cavities within the body.\n\n* **Functions of glands:**\n    * Regulating metabolism and growth\n    * Maintaining homeostasis (stable internal environment)\n    * Facilitating digestion, reproduction, and lactation\n    * Controlling blood sugar levels\n    * Regulating blood pressure and heart rate\n    * Triggering immune responses",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2057,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7485,
            "description": "protect the body",
            "question_id": 1868,
            "is_correct": False,
            "created_at": "2024-07-02T15:04:19.709+05:30",
            "updated_at": "2024-07-02T15:04:19.709+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7486,
            "description": "control the function of epithelial tissues",
            "question_id": 1868,
            "is_correct": False,
            "created_at": "2024-07-02T15:04:19.713+05:30",
            "updated_at": "2024-07-02T15:04:19.713+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7487,
            "description": "produce and secrete specialized compounds to control and maintain different body functions",
            "question_id": 1868,
            "is_correct": True,
            "created_at": "2024-07-02T15:04:19.717+05:30",
            "updated_at": "2024-07-02T15:04:19.717+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7488,
            "description": "help to maintain blood pressure and nerve actions",
            "question_id": 1868,
            "is_correct": False,
            "created_at": "2024-07-02T15:04:19.722+05:30",
            "updated_at": "2024-07-02T15:04:19.722+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1869,
        "description": "Which one of the following pair of structures distinguish a nerve cell from other types of cell ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:08:38.358+05:30",
        "updated_at": "2024-11-30T18:39:29.257+05:30",
        "detailed_solution": "**Explanation:**\n\nNerve cells, also known as neurons, are specialized cells that transmit information within the nervous system. They have a unique morphology that distinguishes them from other cell types.\n\n**Cell Body:**\n\n* The cell body, also called the soma, is the main part of the nerve cell.\n* It contains the nucleus, which houses the genetic material.\n* The cell body is responsible for integrating and processing information received from other neurons.\n\n**Dendrites:**\n\n* Dendrites are branched extensions of the cell body that receive signals from other neurons.\n* They increase the surface area of the cell, allowing it to receive signals from multiple sources.\n\nThese two structures are unique to nerve cells and play crucial roles in their function. The cell body integrates information, while the dendrites receive signals. Together, they allow nerve cells to communicate with each other and transmit information within the nervous system.\n\n**Additional Context:**\n\n* Neurons also have an axon, which is a long, slender extension that transmits signals away from the cell body.\n* Different types of neurons have varying numbers of dendrites and axons, depending on their specific function.\n* The structural organization of nerve cells is essential for understanding how the nervous system functions and processes information.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2058,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7489,
            "description": "Vacuoles and Fibres",
            "question_id": 1869,
            "is_correct": False,
            "created_at": "2024-07-02T15:08:38.362+05:30",
            "updated_at": "2024-07-02T15:08:38.362+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7490,
            "description": "Flagellum and Medullary sheath",
            "question_id": 1869,
            "is_correct": False,
            "created_at": "2024-07-02T15:08:38.365+05:30",
            "updated_at": "2024-07-02T15:08:38.365+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7491,
            "description": "Nucleus and Mitochondria",
            "question_id": 1869,
            "is_correct": False,
            "created_at": "2024-07-02T15:08:38.368+05:30",
            "updated_at": "2024-07-03T18:44:22.831+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7492,
            "description": "Cell body and Dendrites",
            "question_id": 1869,
            "is_correct": True,
            "created_at": "2024-07-02T15:08:38.370+05:30",
            "updated_at": "2024-07-03T18:44:22.834+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1870,
        "description": "Frogs are:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:09:54.371+05:30",
        "updated_at": "2024-11-30T18:39:29.470+05:30",
        "detailed_solution": "**Explanation:**\n\nFrogs belong to the class Amphibia, which means \"double life.\" Amphibians are vertebrates that can live both in water and on land. Frogs have characteristics of both:\n\n**(a) Poikilothermic (Cold-blooded):**\nFrogs cannot regulate their body temperature internally. Instead, they rely on external heat sources to warm up or cool down.\n\n**(c) Smooth and moist skin:**\nFrogs have thin, smooth, and moist skin that lacks scales or hair. This allows them to absorb oxygen through their skin for respiration.\n\n**Additional Context:**\n\n* Frogs have a three-chambered heart, which is a characteristic of amphibians.\n* They undergo metamorphosis, where they hatch as tadpoles and later develop into adult frogs.\n* Frogs play an important role in aquatic ecosystems as predators and food sources.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2059,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7494,
            "description": "Ureotelic",
            "question_id": 1870,
            "is_correct": False,
            "created_at": "2024-07-02T15:09:54.375+05:30",
            "updated_at": "2024-07-02T15:09:54.375+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7495,
            "description": "Stenothermal",
            "question_id": 1870,
            "is_correct": False,
            "created_at": "2024-07-02T15:09:54.378+05:30",
            "updated_at": "2024-07-02T15:09:54.378+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7496,
            "description": "Poikilothermal",
            "question_id": 1870,
            "is_correct": False,
            "created_at": "2024-07-02T15:09:54.381+05:30",
            "updated_at": "2024-07-02T15:09:54.381+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7497,
            "description": "Both (a) and (c)",
            "question_id": 1870,
            "is_correct": True,
            "created_at": "2024-07-02T15:09:54.383+05:30",
            "updated_at": "2024-07-02T15:09:54.383+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1871,
        "description": "Frog takes water through which of the following organs?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:11:15.669+05:30",
        "updated_at": "2024-11-30T18:39:29.681+05:30",
        "detailed_solution": "**Answer is correct because:**\n\nFrogs have a semi-permeable skin that allows water and oxygen to pass through it. This is because frogs lack lungs and rely on their skin for respiration. The skin is also used for osmoregulation.\n\n**Additional context:** \n\n* The skin of a frog is moist and slimy, which helps to keep it hydrated.\n* The skin is also covered in tiny blood vessels, which helps to absorb oxygen from the water.\n* Frogs also have a lymphatic system, which helps to remove excess water from the body.\n\n**NEET exam relevance:** \n\nThe NEET exam is a national level entrance exam for admission to medical and dental colleges in India. The exam covers a wide range of topics in biology, including structural organisation in animals. Students who are preparing for the NEET exam should be familiar with the different organs and their functions in animals.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2060,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7498,
            "description": "Eyes",
            "question_id": 1871,
            "is_correct": False,
            "created_at": "2024-07-02T15:11:15.674+05:30",
            "updated_at": "2024-07-02T15:11:15.674+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7499,
            "description": "Skin",
            "question_id": 1871,
            "is_correct": True,
            "created_at": "2024-07-02T15:11:15.676+05:30",
            "updated_at": "2024-07-02T15:11:15.676+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7500,
            "description": "Mouth",
            "question_id": 1871,
            "is_correct": False,
            "created_at": "2024-07-02T15:11:15.678+05:30",
            "updated_at": "2024-07-02T15:11:15.678+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7501,
            "description": "Gills",
            "question_id": 1871,
            "is_correct": False,
            "created_at": "2024-07-02T15:11:15.682+05:30",
            "updated_at": "2024-07-02T15:11:15.682+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1872,
        "description": "Mesorchium in frogs is associated with",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:12:51.670+05:30",
        "updated_at": "2024-11-30T18:39:29.881+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2061,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7502,
            "description": "Testes",
            "question_id": 1872,
            "is_correct": False,
            "created_at": "2024-07-02T15:12:51.674+05:30",
            "updated_at": "2024-07-02T15:12:51.674+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7503,
            "description": "Kidney",
            "question_id": 1872,
            "is_correct": False,
            "created_at": "2024-07-02T15:12:51.677+05:30",
            "updated_at": "2024-07-02T15:12:51.677+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7504,
            "description": "Brain",
            "question_id": 1872,
            "is_correct": False,
            "created_at": "2024-07-02T15:12:51.679+05:30",
            "updated_at": "2024-07-02T15:12:51.679+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7505,
            "description": "Both (a) & (b)",
            "question_id": 1872,
            "is_correct": True,
            "created_at": "2024-07-02T15:12:51.681+05:30",
            "updated_at": "2024-07-02T15:12:51.681+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1873,
        "description": "In frogs, the cloaca is used to pass",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:14:07.001+05:30",
        "updated_at": "2024-11-30T18:39:30.099+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2062,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7506,
            "description": "Sperms",
            "question_id": 1873,
            "is_correct": False,
            "created_at": "2024-07-02T15:14:07.007+05:30",
            "updated_at": "2024-07-02T15:14:07.007+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7507,
            "description": "Urine",
            "question_id": 1873,
            "is_correct": False,
            "created_at": "2024-07-02T15:14:07.010+05:30",
            "updated_at": "2024-07-02T15:14:07.010+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7508,
            "description": "Fecal matter",
            "question_id": 1873,
            "is_correct": False,
            "created_at": "2024-07-02T15:14:07.013+05:30",
            "updated_at": "2024-07-02T15:14:07.013+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7509,
            "description": "All of the them",
            "question_id": 1873,
            "is_correct": True,
            "created_at": "2024-07-02T15:14:07.016+05:30",
            "updated_at": "2024-07-02T15:14:07.016+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1874,
        "description": "In a frog, if a hole is punched in the floor of its buccal cavity, then the frog will not die as",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:18:26.151+05:30",
        "updated_at": "2024-11-30T18:39:30.306+05:30",
        "detailed_solution": "**Explanation:**\n\n* In frogs, the buccal cavity is the first part of the digestive system. It is lined by a moist epithelium that helps in respiration.\n* When a hole is punched in the floor of the buccal cavity, it creates an opening between the buccal cavity and the lungs.\n* This allows air to enter the lungs directly, bypassing the nose and mouth.\n* As a result, the frog can still breathe and will not die.\n\n**Additional Context:**\n\n* Frogs have three main modes of respiration: cutaneous (through the skin), buccal (through the buccal cavity), and pulmonary (through the lungs).\n* Pulmonary respiration is the most efficient and is the primary mode of respiration in adult frogs.\n* The lungs are located in the thoracic cavity and are lined by capillaries that allow for the exchange of gases.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2063,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7510,
            "description": "buccal respiration does not stop",
            "question_id": 1874,
            "is_correct": False,
            "created_at": "2024-07-02T15:18:26.156+05:30",
            "updated_at": "2024-07-02T15:18:26.156+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7511,
            "description": "respiration other than lungs will continue",
            "question_id": 1874,
            "is_correct": False,
            "created_at": "2024-07-02T15:18:26.159+05:30",
            "updated_at": "2024-07-02T15:18:26.159+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7512,
            "description": "it can store oxygen for future use",
            "question_id": 1874,
            "is_correct": False,
            "created_at": "2024-07-02T15:18:26.162+05:30",
            "updated_at": "2024-07-02T15:18:26.162+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7513,
            "description": "pulmonary respiratory occurs",
            "question_id": 1874,
            "is_correct": True,
            "created_at": "2024-07-02T15:18:26.169+05:30",
            "updated_at": "2024-07-02T15:18:26.169+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1875,
        "description": "Identify the incorrect statement about frog.",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:23:53.821+05:30",
        "updated_at": "2025-01-14T20:28:17.183+05:30",
        "detailed_solution": "There are 10 pairs of cranial nerves that extend between the brain and various head regions and certain viscera.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2064,
        "fixed_at": "2025-01-14T00:00:00.000+05:30",
        "fix_summary": "Explanation was missing.",
        "created_by": "",
        "updated_by": "kanza@testline.in",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7514,
            "description": "Parathyroid and pineal body are present",
            "question_id": 1875,
            "is_correct": False,
            "created_at": "2024-07-02T15:23:53.826+05:30",
            "updated_at": "2024-07-02T15:23:53.826+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7515,
            "description": "Optic lobes are situated in the mid brain",
            "question_id": 1875,
            "is_correct": False,
            "created_at": "2024-07-02T15:23:53.830+05:30",
            "updated_at": "2024-07-10T11:13:33.053+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7516,
            "description": "There are ten cranial nerves only",
            "question_id": 1875,
            "is_correct": True,
            "created_at": "2024-07-02T15:23:53.833+05:30",
            "updated_at": "2024-07-02T15:23:53.833+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7517,
            "description": "The ventricle opens into the conus arteriousus",
            "question_id": 1875,
            "is_correct": False,
            "created_at": "2024-07-02T15:23:53.835+05:30",
            "updated_at": "2024-07-02T15:23:53.835+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1876,
        "description": "In frog mesorchium is a thin fold of membrane extending between",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:28:25.054+05:30",
        "updated_at": "2024-11-30T18:39:30.716+05:30",
        "detailed_solution": "**Explanation:**\n\nMesorchium is a thin fold of membrane that extends between the kidneys and testes in male frogs. It provides structural support to the testes and helps in their attachment to the kidneys.\n\n**Additional Context:**\n\n* The mesorchium is part of the reproductive system of male frogs.\n* It is analogous to the mesentery, which supports the intestines in humans.\n* The testes in frogs are located in the abdominal cavity, close to the kidneys.\n* The mesorchium helps to protect the testes from damage and provides a pathway for blood vessels and nerves to reach the testes.\n\n**Significance for NEET Exam:**\n\nUnderstanding the structure and function of the mesorchium is important for NEET exam as it is a key component of the reproductive system of male frogs. This topic falls under the \"Structural Organization in Animals\" unit of NEET syllabus, which focuses on the anatomy and histology of various animal groups.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2065,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7518,
            "description": "two testes",
            "question_id": 1876,
            "is_correct": False,
            "created_at": "2024-07-02T15:28:25.060+05:30",
            "updated_at": "2024-07-02T15:28:25.060+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7519,
            "description": "kidneys and testes",
            "question_id": 1876,
            "is_correct": True,
            "created_at": "2024-07-02T15:28:25.064+05:30",
            "updated_at": "2024-07-02T15:28:25.064+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7520,
            "description": "two kidneys",
            "question_id": 1876,
            "is_correct": False,
            "created_at": "2024-07-02T15:28:25.066+05:30",
            "updated_at": "2024-07-02T15:28:25.066+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7521,
            "description": "liver and kidneys",
            "question_id": 1876,
            "is_correct": False,
            "created_at": "2024-07-02T15:28:25.071+05:30",
            "updated_at": "2024-07-02T15:28:25.071+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1877,
        "description": "Frog's heart is",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:31:52.148+05:30",
        "updated_at": "2024-11-30T18:39:30.918+05:30",
        "detailed_solution": "**Explanation:**\n\n**Myogenic Heart:**\n\n* The heart of a frog is myogenic, which means it can initiate and conduct electrical impulses on its own, without external stimulation.\n* The generation of electrical impulses in the heart is regulated by a special group of cells called the sinoatrial node (SA node), which acts as the natural pacemaker of the heart.\n\n**3-Chambered Heart:**\n\n* The frog's heart consists of three chambers:\n    * Two atria (right and left)\n    * One ventricle\n\n**Additional Context:**\n\n* The frog's heart is a double circulatory system, meaning blood passes through the heart twice in one complete circuit of the body.\n* The first circuit carries deoxygenated blood from the heart to the lungs for gas exchange, and the second circuit carries oxygenated blood from the lungs to the rest of the body.\n* The heart receives deoxygenated blood from the body through the right atrium and pumps it to the lungs through the pulmonary artery.\n* After gas exchange in the lungs, oxygenated blood returns to the heart through the left atrium and is pumped to the rest of the body through the aorta.\n* The ventricle of the frog's heart is muscular and responsible for pumping blood to the lungs and the body.\n* The atria are thinner-walled chambers that receive blood from the body and lungs, respectively.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2066,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7522,
            "description": "neurogenic and 4 chambered",
            "question_id": 1877,
            "is_correct": False,
            "created_at": "2024-07-02T15:31:52.152+05:30",
            "updated_at": "2024-07-02T15:31:52.152+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7523,
            "description": "myogenic and 2 chambered",
            "question_id": 1877,
            "is_correct": False,
            "created_at": "2024-07-02T15:31:52.155+05:30",
            "updated_at": "2024-07-02T15:31:52.155+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7524,
            "description": "neurogenic and 3 chambered",
            "question_id": 1877,
            "is_correct": False,
            "created_at": "2024-07-02T15:31:52.157+05:30",
            "updated_at": "2024-07-02T15:31:52.157+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7525,
            "description": "myogenic and 3 chambered",
            "question_id": 1877,
            "is_correct": True,
            "created_at": "2024-07-02T15:31:52.159+05:30",
            "updated_at": "2024-07-02T15:31:52.159+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1878,
        "description": "Vasa efferentia in male frog, enter the kidney and open into",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:33:57.050+05:30",
        "updated_at": "2024-11-30T18:39:31.142+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2067,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7526,
            "description": "Bidder's canal",
            "question_id": 1878,
            "is_correct": True,
            "created_at": "2024-07-02T15:33:57.055+05:30",
            "updated_at": "2024-07-02T15:33:57.055+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7527,
            "description": "Ureter",
            "question_id": 1878,
            "is_correct": False,
            "created_at": "2024-07-02T15:33:57.060+05:30",
            "updated_at": "2024-07-02T15:33:57.060+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7528,
            "description": "Vacuole",
            "question_id": 1878,
            "is_correct": False,
            "created_at": "2024-07-02T15:33:57.062+05:30",
            "updated_at": "2024-07-02T15:33:57.062+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7529,
            "description": "Urinogenital duct",
            "question_id": 1878,
            "is_correct": False,
            "created_at": "2024-07-02T15:33:57.065+05:30",
            "updated_at": "2024-07-02T15:33:57.065+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1879,
        "description": "Incorrect options from the following with respect to frog.",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:37:33.548+05:30",
        "updated_at": "2024-11-30T18:39:31.364+05:30",
        "detailed_solution": "**Explanation:**\n\nThe outer covering of the kidney is called the **renal capsule** or tunica fibrosa, not mesorchium.\n\n**Additional Context:**\n\n* **Renal Capsule:** A thin, fibrous membrane that surrounds the kidney and helps maintain its shape.\n* **Mesorchium:** A membrane that supports the testes in male frogs.\n\n**NEET Preparation Tips:**\n\n* Pay close attention to the precise terminology used in biology.\n* Understand the functions and relationships between different structures.\n* Utilize diagrams and labeled illustrations to visualize and remember these relationships.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2068,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7530,
            "description": "Frogs are devoid of internal ear",
            "question_id": 1879,
            "is_correct": False,
            "created_at": "2024-07-02T15:37:33.552+05:30",
            "updated_at": "2024-07-02T15:37:33.552+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7531,
            "description": "Vasa efferentia enters into bidder's canal",
            "question_id": 1879,
            "is_correct": False,
            "created_at": "2024-07-02T15:37:33.556+05:30",
            "updated_at": "2024-07-02T15:37:33.556+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7532,
            "description": "A mature female frog can lay 2500 to 3000 ova at a time",
            "question_id": 1879,
            "is_correct": False,
            "created_at": "2024-07-02T15:37:33.560+05:30",
            "updated_at": "2024-07-02T15:37:33.560+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7533,
            "description": "The outer covering of kidney is called mesorchium",
            "question_id": 1879,
            "is_correct": True,
            "created_at": "2024-07-02T15:37:33.562+05:30",
            "updated_at": "2024-07-02T15:37:33.562+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1880,
        "description": "The ability to change colour and hide from the enemies in frog is called",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:39:57.893+05:30",
        "updated_at": "2024-11-30T18:39:31.568+05:30",
        "detailed_solution": "**Camouflage** is the ability of an organism to change its color or appearance to match its surroundings. This adaptation helps the organism to hide from predators or prey. Frogs have specialized cells called chromatophores that contain pigments. These pigments can be dispersed or concentrated to change the frog's color. Frogs use camouflage to hide from predators such as snakes and birds. They also use camouflage to stalk prey such as insects.\n\n**Additional information**\n\nCamouflage is a widespread adaptation in the animal kingdom. It is found in a variety of animals, including insects, fish, reptiles, birds, and mammals. Camouflage can take many different forms, including color change, pattern change, and shape change.\n\nThe ability to camouflage is a valuable asset for animals. It helps them to survive in a variety of habitats and to avoid predators. Camouflage is a fascinating example of the power of natural selection.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2069,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7534,
            "description": "Ammensalism",
            "question_id": 1880,
            "is_correct": False,
            "created_at": "2024-07-02T15:39:57.901+05:30",
            "updated_at": "2024-07-02T15:39:57.901+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7535,
            "description": "Camouflage",
            "question_id": 1880,
            "is_correct": True,
            "created_at": "2024-07-02T15:39:57.907+05:30",
            "updated_at": "2024-07-02T15:39:57.907+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7536,
            "description": "Aestivation",
            "question_id": 1880,
            "is_correct": False,
            "created_at": "2024-07-02T15:39:57.917+05:30",
            "updated_at": "2024-07-02T15:39:57.917+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7537,
            "description": "Moulting",
            "question_id": 1880,
            "is_correct": False,
            "created_at": "2024-07-02T15:39:57.923+05:30",
            "updated_at": "2024-07-02T15:39:57.923+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1881,
        "description": "Special venous connection between kidney and lower parts of body in a  frog is called",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:42:03.133+05:30",
        "updated_at": "2024-11-30T18:39:31.775+05:30",
        "detailed_solution": "**Special venous connection between kidney and lower parts of body in a frog is called Renal portal system.**\n\n* The renal portal system is a special venous system that transports blood from the hind limbs and tail of a frog to its kidneys. \n* The renal portal vein collects blood from the hind limbs and tail and carries it to the kidneys, where it is filtered. \n* The filtered blood is then returned to the body through the renal veins. \n* The renal portal system helps to ensure that the kidneys receive a constant supply of blood that is rich in oxygen and nutrients.\n\n**Additional context:**\n\nThe renal portal system is found in all vertebrates, but it is most developed in amphibians and reptiles. \nThe renal portal system is a type of circulatory system that is designed to increase the amount of blood that is filtered by the kidneys. \nThis is important because the kidneys play a vital role in removing waste products from the blood.\n\n**How the renal portal system works:**\n\n1. Blood from the hind limbs and tail enters the renal portal vein.\n\n\n2. The renal portal vein carries the blood to the kidneys.\n\n\n3. The kidneys filter the blood and remove waste products.\n\n\n4. The filtered blood is returned to the body through the renal veins.\n\n**Additional notes:**\n\n* The renal portal system is a very important part of the circulatory system in frogs. \n* It helps to ensure that the kidneys receive a constant supply of blood that is rich in oxygen and nutrients. \n* The renal portal system also helps to remove waste products from the blood.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2070,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7538,
            "description": "Hepatic portal system",
            "question_id": 1881,
            "is_correct": False,
            "created_at": "2024-07-02T15:42:03.137+05:30",
            "updated_at": "2024-07-02T15:42:03.137+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7539,
            "description": "Renal portal system",
            "question_id": 1881,
            "is_correct": True,
            "created_at": "2024-07-02T15:42:03.140+05:30",
            "updated_at": "2024-07-02T15:42:03.140+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7540,
            "description": "Atrial hepatic system",
            "question_id": 1881,
            "is_correct": False,
            "created_at": "2024-07-02T15:42:03.143+05:30",
            "updated_at": "2024-07-02T15:42:03.143+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7541,
            "description": "Both (a) and (b)",
            "question_id": 1881,
            "is_correct": False,
            "created_at": "2024-07-02T15:42:03.145+05:30",
            "updated_at": "2024-07-02T15:42:03.145+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1882,
        "description": "Through which of the following structure the medulla oblongata passes out and continues into spinal cord ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:44:45.625+05:30",
        "updated_at": "2024-11-30T18:39:31.972+05:30",
        "detailed_solution": "**Explanation:**\n\nThe medulla oblongata is the most inferior part of the brainstem. It connects the cerebrum and cerebellum to the spinal cord.\n\nThe medulla oblongata passes through the foramen magnum, which is a large opening in the occipital bone at the base of the skull. The foramen magnum allows for the passage of the medulla oblongata and other structures such as the vertebral arteries and the spinal cord.\n\nThe spinal cord is a long, cylindrical bundle of nerve tissue that extends from the medulla oblongata down the vertebral canal. The spinal cord transmits nerve impulses between the brain and the rest of the body.\n\n**Additional context:**\n\n* The medulla oblongata is responsible for controlling vital life functions such as breathing, heart rate, and blood pressure.\n* The foramen magnum is a foramen in the occipital bone of the skull that allows the spinal cord to pass through.\n* The spinal cord is protected by the vertebrae of the vertebral column.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2071,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7542,
            "description": "Formenovale",
            "question_id": 1882,
            "is_correct": False,
            "created_at": "2024-07-02T15:44:45.630+05:30",
            "updated_at": "2024-07-02T15:44:45.630+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7543,
            "description": "Fossa ovalis",
            "question_id": 1882,
            "is_correct": False,
            "created_at": "2024-07-02T15:44:45.634+05:30",
            "updated_at": "2024-07-02T15:44:45.634+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7544,
            "description": "Foramen magnum",
            "question_id": 1882,
            "is_correct": True,
            "created_at": "2024-07-02T15:44:45.637+05:30",
            "updated_at": "2024-07-02T15:44:45.637+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7545,
            "description": "None of these",
            "question_id": 1882,
            "is_correct": False,
            "created_at": "2024-07-02T15:44:45.642+05:30",
            "updated_at": "2024-07-02T15:44:45.642+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1883,
        "description": "The figure given here shows a diagrammatic representation of internal organs of the frog digestive system. Identify A to D and select the correct option. \r\n \r\nA, B, C,D",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T15:50:57.508+05:30",
        "updated_at": "2025-01-09T15:52:52.794+05:30",
        "detailed_solution": "**A is Gall bladder:** It is a small, sac-like organ located on the ventral side of the liver. It stores and concentrates bile, which helps in the digestion and absorption of fats.\r\n\r\n**B is Lung:** They are two elongated, sac-like organs located in the thoracic cavity. They are responsible for the exchange of gases between the blood and the environment.\r\n\r\n**C is Fat bodies:** They are yellowish, irregular masses of fat tissue located on either side of the kidneys. They store energy and help in the regulation of body temperature.\r\n\r\n**D is Kidney:** They are two bean-shaped organs located in the abdominal cavity. They are responsible for the filtration of blood, the production of urine, and the regulation of blood pressure.\r\n\r\n**Additional context:**\r\n\r\nThe digestive system of a frog consists of a mouth, esophagus, stomach, small intestine, large intestine, and cloaca. The respiratory system consists of lungs and skin. The circulatory system consists of a heart, arteries, veins, and capillaries. The excretory system consists of kidneys and ureters. The nervous system consists of a brain, spinal cord, and nerves.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2072,
        "fixed_at": "2025-01-09T00:00:00.000+05:30",
        "fix_summary": "Both the question and answer are correct. No correction needed.",
        "created_by": "",
        "updated_by": "kanza@testline.in",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "https://tlpl-docs.s3.ap-south-1.amazonaws.com/tlpl_neet/saz6v46hr6ryfi5h8yvp6caj0fyo?response-content-disposition=inline%3B%20filename%3D%221400.jpg%22%3B%20filename%2A%3DUTF-8%27%271400.jpg&response-content-type=image%2Fjpeg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA4RXKHO4ST4B5MOBS%2F20250117%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20250117T102951Z&X-Amz-Expires=10800&X-Amz-SignedHeaders=host&X-Amz-Signature=b7c8f8ae2bb08aff989aa882d022a0c1b6551c7e5b400648d3d7588bc604bc7e",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7546,
            "description": "Gall bladder, Liver, Testis, Rectum",
            "question_id": 1883,
            "is_correct": False,
            "created_at": "2024-07-02T15:50:57.511+05:30",
            "updated_at": "2024-07-02T15:50:57.511+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7547,
            "description": "Gall bladder, Lung, Fat bodies, Kidney",
            "question_id": 1883,
            "is_correct": True,
            "created_at": "2024-07-02T15:50:57.514+05:30",
            "updated_at": "2024-07-02T15:50:57.514+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7548,
            "description": "Pancreas, Lungs, Testis, Liver",
            "question_id": 1883,
            "is_correct": False,
            "created_at": "2024-07-02T15:50:57.517+05:30",
            "updated_at": "2024-07-02T15:50:57.517+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7549,
            "description": "Liver, Pancreas, Fat bodies, Gall bladder",
            "question_id": 1883,
            "is_correct": False,
            "created_at": "2024-07-02T15:50:57.521+05:30",
            "updated_at": "2024-07-02T15:50:57.521+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1884,
        "description": "In the given diagram of areolar connective tissue, the different cells and parts have been marked by alphabets (A, B, C& D). Choose the answer in which these alphabets correctly match with the parts and",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T16:17:44.573+05:30",
        "updated_at": "2025-01-14T20:26:27.803+05:30",
        "detailed_solution": "**Explanation:**\r\nThe given diagram shows areolar connective tissue, which is a type of loose connective tissue that fills the spaces between organs and provides support and cushioning.\r\n\r\n**A-Macrophage:**\r\nMacrophages are large phagocytic cells that engulf and destroy foreign particles, debris, and dead cells. They are found in connective tissue and other tissues throughout the body.\r\n\r\n**B-Fibroblast:**\r\nFibroblasts are the most common cells in connective tissue. They secrete collagen fibers, which provide strength and support to the tissue.\r\n\r\n**C-Collagen fibers:**\r\nCollagen fibers are strong, flexible proteins that form the main structural component of connective tissue. They are secreted by fibroblasts and arranged in bundles to provide support and strength.\r\n\r\n**D-Mast cells:**\r\nMast cells are immune cells that release histamine and other mediators in response to allergens or other triggers. They are found in connective tissue and other tissues throughout the body.\r\n\r\n**Therefore, the correct matching of alphabets with parts is:**\r\n* A-Macrophage\r\n* B-Fibroblast\r\n* C-Collagen fibers\r\n* D-Mast cells\r\n\r\n**Additional Context:**\r\n* Areolar connective tissue is found in many parts of the body, including the subcutaneous layer of the skin, around blood vessels, and in the lining of body cavities.\r\n* It provides support, cushioning, and allows for the passage of nutrients and waste products to and from cells.\r\n* The composition of areolar connective tissue can vary depending on its location and function. For example, it may contain more fat cells in the subcutaneous layer or more elastic fibers in areas where flexibility is required.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2073,
        "fixed_at": "2025-01-14T00:00:00.000+05:30",
        "fix_summary": "Both the question and answer are correct. No correction needed.",
        "created_by": "",
        "updated_by": "kanza@testline.in",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "https://tlpl-docs.s3.ap-south-1.amazonaws.com/tlpl_neet/fuxy1hznl37qabl1r5lcjexrbs46?response-content-disposition=inline%3B%20filename%3D%221404.jpg%22%3B%20filename%2A%3DUTF-8%27%271404.jpg&response-content-type=image%2Fjpeg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA4RXKHO4ST4B5MOBS%2F20250117%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20250117T102951Z&X-Amz-Expires=10800&X-Amz-SignedHeaders=host&X-Amz-Signature=4b8cab96d3dc9da7b23da1960b20af8d98bbae40a31bc8d72c00898aaa395239",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7550,
            "description": "A-Adipocyte, B-Collagen fibres, C-Microfilament, D-Mast cells",
            "question_id": 1884,
            "is_correct": False,
            "created_at": "2024-07-02T16:17:44.577+05:30",
            "updated_at": "2024-07-02T16:17:44.577+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7551,
            "description": "A-Macrophage, B-Collagen fibres, C-Microfilament, D-Mast cells",
            "question_id": 1884,
            "is_correct": False,
            "created_at": "2024-07-02T16:17:44.580+05:30",
            "updated_at": "2024-07-02T16:17:44.580+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7552,
            "description": "A-Macrophage, B-Collagen fibres, C-Microtubule, D-RBC",
            "question_id": 1884,
            "is_correct": False,
            "created_at": "2024-07-02T16:17:44.582+05:30",
            "updated_at": "2024-07-02T16:17:44.582+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7553,
            "description": "A-Macrophage, B-Fibroblast, C-Collagen fibres,  D-Mast cells",
            "question_id": 1884,
            "is_correct": True,
            "created_at": "2024-07-02T16:17:44.585+05:30",
            "updated_at": "2024-07-02T16:17:44.585+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1895,
        "description": "Which of the following statements is incorrect for simple epithelium?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.738+05:30",
        "updated_at": "2024-11-30T18:39:32.585+05:30",
        "detailed_solution": "**Answer:** They are vascularized\n\n**Explanation:**\n\nSimple epithelium is a thin layer of cells that covers the surface of the body or lines the cavities of internal organs. It is composed of a single layer of cells that are closely packed together. Simple epithelium is not vascularized, meaning it does not contain blood vessels. This is because the cells of simple epithelium are so thin that they can receive nutrients and oxygen from the underlying connective tissue by diffusion.\n\nVascularization is the process of supplying blood to a tissue or organ. It is essential for providing nutrients and oxygen to the cells of the tissue or organ. Simple epithelium does not require vascularization because its cells are so thin that they can receive nutrients and oxygen from the underlying connective tissue by diffusion.\n\nThe other statements about simple epithelium are correct. Simple epithelium is avascular, meaning it does not contain blood vessels. It is composed of a single layer of cells that are closely packed together. Simple epithelium is found in a variety of locations in the body, including the lining of the blood vessels, the lining of the digestive tract, and the lining of the respiratory tract.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2074,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7594,
            "description": "They are derived from any of the embryonic germ layers",
            "question_id": 1895,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.742+05:30",
            "updated_at": "2024-07-02T17:11:45.742+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7595,
            "description": "They are vascularized",
            "question_id": 1895,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.745+05:30",
            "updated_at": "2024-07-02T17:11:45.745+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7596,
            "description": "The cells have a rapid rate of cell division",
            "question_id": 1895,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.748+05:30",
            "updated_at": "2024-07-02T17:11:45.748+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7597,
            "description": "Cemented to one another to form a single layer",
            "question_id": 1895,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.752+05:30",
            "updated_at": "2024-07-02T17:11:45.752+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1896,
        "description": "The main function of simple cuboidal epithelium is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.759+05:30",
        "updated_at": "2024-11-30T18:39:32.792+05:30",
        "detailed_solution": "**Explanation:**\n\nSimple cuboidal epithelium is a single layer of cube-shaped cells that line ducts, glands, and small vessels. Its main function is to regulate the movement of substances across the membrane, which involves both **secretion** and **absorption**.\n\n* **Secretion:** Simple cuboidal cells can release substances into the lumen or space below the epithelium. For example, in the salivary glands, these cells secrete saliva into the salivary ducts.\n\n* **Absorption:** Simple cuboidal cells can also absorb substances from the lumen or space below the epithelium. For example, in the proximal convoluted tubules of the kidneys, these cells absorb glucose and other nutrients from the filtrate.\n\n**Additional Context:**\n\n* Simple cuboidal epithelium is also found in the linings of the ovaries, thyroid glands, and pancreas.\n* In some cases, simple cuboidal epithelium can have microvilli or cilia on its apical surface to increase the surface area for absorption or aid in fluid movement, respectively.\n* The shape of the cuboidal cells allows for efficient exchange of substances due to their increased surface area.\n\n**Conclusion:**\n\nTherefore, the main function of simple cuboidal epithelium is both secretion and absorption, which are essential processes for maintaining homeostasis and regulating the movement of substances in various parts of the body.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2075,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7598,
            "description": "Diffusion",
            "question_id": 1896,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.763+05:30",
            "updated_at": "2024-07-02T17:11:45.763+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7599,
            "description": "Secretion and absorption",
            "question_id": 1896,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.768+05:30",
            "updated_at": "2024-07-02T17:11:45.768+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7600,
            "description": "Protection",
            "question_id": 1896,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.771+05:30",
            "updated_at": "2024-07-02T17:11:45.771+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7601,
            "description": "Diffusion and protection",
            "question_id": 1896,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.773+05:30",
            "updated_at": "2024-07-02T17:11:45.773+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1897,
        "description": "Epithelial cells of the intestine involved in food absorption have on their surface :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.780+05:30",
        "updated_at": "2024-11-30T18:39:32.991+05:30",
        "detailed_solution": "**Explanation:**\n\nEpithelial cells of the intestine involved in food absorption have microvilli on their surface. Microvilli are tiny, finger-like projections that increase the surface area of the cells, allowing for more efficient absorption of nutrients from the food. This increased surface area is important for the intestine to effectively absorb the nutrients from the food we eat.\n\n**Additional Context:**\n\n* The intestine is a long, coiled tube that is responsible for absorbing nutrients from food.\n* The small intestine is the longest part of the intestine and is responsible for most of the absorption of nutrients.\n* The large intestine is responsible for absorbing water and electrolytes from the food.\n* Epithelial cells are the cells that line the inner surface of the intestine.\n* Microvilli are small, finger-like projections that extend from the surface of epithelial cells.\n* The microvilli increase the surface area of the epithelial cells, allowing for more efficient absorption of nutrients.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2076,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7602,
            "description": "Pinocytic vesicles",
            "question_id": 1897,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.786+05:30",
            "updated_at": "2024-07-02T17:11:45.786+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7603,
            "description": "Phagocytic vesicles",
            "question_id": 1897,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.788+05:30",
            "updated_at": "2024-07-02T17:11:45.788+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7604,
            "description": "Zymogen granules",
            "question_id": 1897,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.791+05:30",
            "updated_at": "2024-07-02T17:11:45.791+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7605,
            "description": "Micro-villi",
            "question_id": 1897,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.793+05:30",
            "updated_at": "2024-07-02T17:11:45.793+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1898,
        "description": "Brush border epithelium occurs in :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.806+05:30",
        "updated_at": "2024-11-30T18:39:33.196+05:30",
        "detailed_solution": "**Explanation:**\n\nThe brush border epithelium is a specialized type of epithelium that lines the small intestine. It is characterized by the presence of numerous microvilli, which are small finger-like protrusions. These microvilli increase the surface area of the epithelium, which allows for the efficient absorption of nutrients from the digested food.\n\nThe small intestine is the primary site of nutrient absorption in the human body. It is divided into three regions: the duodenum, the jejunum, and the ileum. The brush border epithelium is present in all three regions, but it is most prominent in the jejunum and ileum.\n\nThe brush border epithelium is composed of a single layer of tall columnar cells. The cells are connected by tight junctions, which prevent the passage of materials between the cells. The apical surface of the cells is covered in microvilli. The microvilli are lined with glycoproteins, which provide a sticky surface for the absorption of nutrients.\n\nThe brush border epithelium also contains a number of goblet cells, which secrete mucus. The mucus helps to protect the epithelium from damage by digestive enzymes.\n\n**Additional Context:**\n\n* The brush border epithelium is also found in the proximal convoluted tubules of the kidney.\n* The brush border epithelium is a highly dynamic structure that is constantly being renewed. The cells of the epithelium are shed every few days and replaced by new cells.\n* The brush border epithelium is essential for the absorption of nutrients from the small intestine. Without the brush border epithelium, the body would not be able to absorb the nutrients it needs to function properly.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2077,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7606,
            "description": "Trachea",
            "question_id": 1898,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.809+05:30",
            "updated_at": "2024-07-02T17:11:45.809+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7607,
            "description": "Stomach",
            "question_id": 1898,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.812+05:30",
            "updated_at": "2024-07-02T17:11:45.812+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7608,
            "description": "Small intestine",
            "question_id": 1898,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.814+05:30",
            "updated_at": "2024-07-02T17:11:45.814+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7609,
            "description": "Oesophagus",
            "question_id": 1898,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.815+05:30",
            "updated_at": "2024-07-02T17:11:45.815+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1899,
        "description": "The tissue which has power of division and regeneration, throughout life, is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.821+05:30",
        "updated_at": "2024-11-30T18:39:33.401+05:30",
        "detailed_solution": "**Detailed Explanation:**\n\nEpithelial tissue is a type of animal tissue that covers the body's surfaces and lines internal organs. It is characterized by its close-fitting, tightly packed cells and its ability to divide and regenerate throughout life.\n\n**Reasons why Epithelial Tissue has Power of Division and Regeneration:**\n\n* **Basal Cells:** Epithelial tissue typically contains a layer of basal cells at its base. These basal cells are actively dividing and producing new cells.\n* **Stem Cells:** Epithelial tissue often contains stem cells, which are unspecialized cells that can differentiate into different types of specialized cells. These stem cells contribute to the tissue's ability to regenerate and repair itself.\n* **Rapid Turnover:** Epithelial cells are constantly exposed to wear and tear, so they need to be replaced regularly. The rapid turnover of epithelial cells allows the tissue to maintain its integrity and function.\n\n**Examples of Epithelial Tissue Regeneration:**\n\n* Skin: Skin cells are constantly dividing and replacing damaged or dead cells. This process keeps the skin healthy and protected.\n* Digestive Tract: The epithelial lining of the digestive tract is constantly renewed to protect against digestive enzymes and other harsh chemicals.\n* Respiratory Tract: The epithelial lining of the respiratory tract traps foreign particles and protects the lungs. It regenerates regularly to maintain its protective function.\n\n**Importance of Epithelial Tissue Regeneration:**\n\nThe ability of epithelial tissue to divide and regenerate is essential for maintaining the health and function of the body. It allows for:\n\n* Tissue repair after injury\n* Replacement of worn-out or damaged cells\n* Protection against infection and environmental factors\n\n**Additional Context:**\n\nEpithelial tissue is classified into different types based on its structure and function:\n\n* **Simple Epithelium:** Composed of a single layer of cells.\n* **Stratified Epithelium:** Composed of multiple layers of cells.\n* **Glandular Epithelium:** Secretes substances into the body.\n\nEpithelial tissue also plays a role in absorption, secretion, protection, and sensation. Understanding the structure and function of epithelial tissue is crucial for comprehending the biology of animals.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2078,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7610,
            "description": "Epithelial tissue",
            "question_id": 1899,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.834+05:30",
            "updated_at": "2024-07-02T17:11:45.834+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7611,
            "description": "Muscular tissue",
            "question_id": 1899,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.836+05:30",
            "updated_at": "2024-07-02T17:11:45.836+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7612,
            "description": "Connective tissue",
            "question_id": 1899,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.838+05:30",
            "updated_at": "2024-07-02T17:11:45.838+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7613,
            "description": "Nervous tissue",
            "question_id": 1899,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.840+05:30",
            "updated_at": "2024-07-02T17:11:45.840+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1900,
        "description": "Gland which is both exocrine and endocrine is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.845+05:30",
        "updated_at": "2024-11-30T18:39:33.603+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2079,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7614,
            "description": "Tubular glands",
            "question_id": 1900,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.848+05:30",
            "updated_at": "2024-07-02T17:11:45.848+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7615,
            "description": "Saccular glands",
            "question_id": 1900,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.850+05:30",
            "updated_at": "2024-07-02T17:11:45.850+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7616,
            "description": "Apocrine glands",
            "question_id": 1900,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.851+05:30",
            "updated_at": "2024-07-02T17:11:45.851+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7617,
            "description": "Heterocrine glands",
            "question_id": 1900,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.853+05:30",
            "updated_at": "2024-07-02T17:11:45.853+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1901,
        "description": "This epithelium is made up of a single thin layer of flattened cells and is involved in diffusion, it is found in:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.859+05:30",
        "updated_at": "2024-11-30T18:39:33.808+05:30",
        "detailed_solution": "**Explanation:**\n\nThe epithelium referred to in the question is called **simple squamous epithelium**. It is characterized by the following features:\n\n* **Structure:** Consists of a single layer of thin, flattened cells.\n* **Function:** Facilitates diffusion of gases and nutrients.\n* **Location:** Found in areas where rapid diffusion is required, such as:\n    * Walls of blood vessels (capillaries, arterioles, venules)\n    * Alveolar walls in lungs\n    * Glomerular walls in kidneys\n\nTherefore, the correct answer is: **Walls of blood vessels**\n\n**Additional Context:**\n\nEpithelia are cells that line the organs and cavities of the body, providing protection, secretion, absorption, and excretion. Different types of epithelia exist, each adapted to its specific function and location.\n\nSimple squamous epithelium is often found in areas where rapid diffusion of gases or nutrients is essential. In blood vessels, it allows for the exchange of gases and nutrients between the blood and surrounding tissues.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2080,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7618,
            "description": "Walls of blood vessels",
            "question_id": 1901,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.862+05:30",
            "updated_at": "2024-07-02T17:11:45.862+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7619,
            "description": "Ducts of glands",
            "question_id": 1901,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.864+05:30",
            "updated_at": "2024-07-02T17:11:45.864+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7620,
            "description": "Tubular parts of nephrons",
            "question_id": 1901,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.866+05:30",
            "updated_at": "2024-07-02T17:11:45.866+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7621,
            "description": "All of these",
            "question_id": 1901,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.868+05:30",
            "updated_at": "2024-07-02T17:11:45.868+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1902,
        "description": "Exoskeleton (e.g. feathers, nails, horns, hooves) originated from :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.875+05:30",
        "updated_at": "2024-11-30T18:39:34.011+05:30",
        "detailed_solution": "**Explanation:**\n\nExoskeleton refers to the external covering of an animal that provides support and protection. Examples of exoskeletons include feathers, nails, horns, and hooves. These structures are primarily composed of keratin, a type of protein that is produced by epithelial tissue.\n\nEpithelial tissue is a thin layer of cells that lines the surfaces of the body and its organs. It provides a protective barrier, regulates the passage of substances, and produces specialized structures such as feathers, nails, horns, and hooves.\n\nDuring embryonic development, epithelial tissue undergoes differentiation and specialization to form these exoskeletal structures. Keratinocytes, which are specialized epithelial cells, produce keratin and accumulate it to form the tough and durable outer layer of exoskeletons.\n\nTherefore, the correct answer is Epithelium tissue because it gives rise to the cells that produce exoskeletal structures.\n\n**Additional Context:**\n\n* Epithelial tissue is also responsible for forming other structures, such as skin, mucous membranes, and glands.\n* Keratin is a fibrous protein that is also found in hair, skin, and claws.\n* Exoskeletons provide protection against mechanical damage, desiccation, and predators.\n* The exoskeletons of insects and crustaceans are made up of chitin, a polysaccharide that is also found in fungal cell walls.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2081,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7622,
            "description": "Connective tissue proper",
            "question_id": 1902,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.878+05:30",
            "updated_at": "2024-07-02T17:11:45.878+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7623,
            "description": "Epithelium tissue",
            "question_id": 1902,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.881+05:30",
            "updated_at": "2024-07-02T17:11:45.881+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7624,
            "description": "Skeletal tissue",
            "question_id": 1902,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.884+05:30",
            "updated_at": "2024-07-02T17:11:45.884+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7625,
            "description": "Vascular tissue",
            "question_id": 1902,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.887+05:30",
            "updated_at": "2024-07-02T17:11:45.887+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1903,
        "description": "Trachea consist of which epithelium ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.895+05:30",
        "updated_at": "2024-11-30T18:39:34.215+05:30",
        "detailed_solution": "**Explanation:**\n\nThe trachea is a part of the respiratory system that carries air to and from the lungs. It is lined with a pseudostratified ciliated columnar epithelium. This type of epithelium consists of multiple layers of cells, but only the superficial cells (the ones closest to the lumen) have cilia.\n\n* **Pseudostratified:** All cells are attached to the basement membrane, but not all reach the surface.\n* **Ciliated:** Superficial cells bear cilia.\n* **Columnar:** All cells are tall and column-shaped.\n\nThe cilia in the trachea help to move mucus and debris towards the pharynx, where it can be expectorated or swallowed. The mucous layer traps foreign particles and microorganisms, protecting the delicate respiratory tissues from damage.\n\n**Additional context:**\n\n* The trachea is also known as the windpipe.\n* It is composed of 16-20 C-shaped cartilaginous rings that are incomplete posteriorly.\n* The cartilaginous rings prevent the trachea from collapsing during inhalation.\n* The esophagus is located posterior to the trachea.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2082,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7626,
            "description": "Simple columnar",
            "question_id": 1903,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.903+05:30",
            "updated_at": "2024-07-02T17:11:45.903+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7627,
            "description": "Simple ciliated",
            "question_id": 1903,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.907+05:30",
            "updated_at": "2024-07-02T17:11:45.907+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7628,
            "description": "Simple cuboidal",
            "question_id": 1903,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.909+05:30",
            "updated_at": "2024-07-02T17:11:45.909+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7629,
            "description": "Stratified cuboidal",
            "question_id": 1903,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.916+05:30",
            "updated_at": "2024-07-02T17:11:45.916+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1904,
        "description": "Characteristic of simple epithelium is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.923+05:30",
        "updated_at": "2024-11-30T18:39:34.416+05:30",
        "detailed_solution": "**Answer.** They make a definite layer\n\n**Explanation:** Simple epithelium is the simplest type of epithelium, consisting of a single layer of cells that line the surfaces of organs and body cavities. The cells of simple epithelium are typically thin and flat, and they fit closely together to form a continuous layer. This layer provides a barrier between the underlying tissues and the external environment, and it also allows for the passage of substances between the two.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2083,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7630,
            "description": "They are arranged irregularly",
            "question_id": 1904,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.926+05:30",
            "updated_at": "2024-07-02T17:11:45.926+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7631,
            "description": "They make a definite layer",
            "question_id": 1904,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.929+05:30",
            "updated_at": "2024-07-02T17:11:45.929+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7632,
            "description": "Continue to divide and help in organ function",
            "question_id": 1904,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.931+05:30",
            "updated_at": "2024-07-02T17:11:45.931+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7633,
            "description": "Never divide",
            "question_id": 1904,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.934+05:30",
            "updated_at": "2024-07-02T17:11:45.934+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1905,
        "description": "Vesicles of thyroid gland is composed of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.943+05:30",
        "updated_at": "2024-11-30T18:39:34.617+05:30",
        "detailed_solution": "**Explanation:**\n\nThe thyroid gland is a small, butterfly-shaped gland located in the neck. It secretes thyroid hormones, which regulate metabolism and growth.\n\nThe thyroid gland is composed of follicles, which are small, spherical structures. Each follicle is lined with a single layer of simple cuboidal epithelium. This epithelium is composed of cells that are cuboidal in shape, with a single nucleus. The simple cuboidal epithelium is responsible for the production and secretion of thyroid hormones.\n\nThe lumen of each follicle is filled with a gelatinous substance called colloid. Colloid is a mixture of proteins and carbohydrates, which contains the thyroid hormones.\n\n**Additional context:**\n\n* The thyroid gland is located in the anterior neck, just below the larynx.\n* The gland is composed of two lobes, which are connected by a narrow isthmus.\n* The thyroid gland is supplied by the superior thyroid artery and the inferior thyroid artery.\n* The thyroid gland is innervated by the recurrent laryngeal nerve.\n\n**Importance of the question:**\n\nThis question is important because it tests the student's understanding of the structural organization of the thyroid gland. This knowledge is essential for understanding the function of the thyroid gland and its role in regulating metabolism and growth.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2084,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7634,
            "description": "Simple squamous epithelium",
            "question_id": 1905,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.952+05:30",
            "updated_at": "2024-07-02T17:11:45.952+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7635,
            "description": "Simple cuboidal epithelium",
            "question_id": 1905,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.954+05:30",
            "updated_at": "2024-07-02T17:11:45.954+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7636,
            "description": "Stratified squamous epithelium",
            "question_id": 1905,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.957+05:30",
            "updated_at": "2024-07-02T17:11:45.957+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7637,
            "description": "Stratified cuboidal epithelium",
            "question_id": 1905,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.959+05:30",
            "updated_at": "2024-07-02T17:11:45.959+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1906,
        "description": "Which of the following is not an endocrine gland ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.966+05:30",
        "updated_at": "2024-11-30T18:39:34.823+05:30",
        "detailed_solution": "An endocrine gland is a gland that secretes its products (hormones) directly into the bloodstream rather than through a duct. Hormones are chemical messengers that affect the activity of target cells or organs.\n\nSalivary glands, on the other hand, are exocrine glands that secrete their products (saliva) through ducts. Saliva is a clear liquid that helps to lubricate the mouth and break down food.\n\nTherefore, salivary glands are not endocrine glands because they do not secrete their products directly into the bloodstream.\n\n**Additional context:**\n\nThe endocrine system is a network of glands that produce and secrete hormones. Hormones are chemical messengers that travel through the bloodstream to target cells or organs. The endocrine system plays a vital role in regulating many bodily functions, including metabolism, growth, reproduction, and mood.\n\nThe major endocrine glands include the pituitary gland, thyroid gland, adrenal glands, pancreas, and gonads (ovaries and testes).\n\n**Explanation for a 12th standard student preparing for NEET entrance exam:**\n\nThe NEET exam is a competitive entrance exam for admission to medical colleges in India. The exam covers a wide range of topics in biology, chemistry, and physics.\n\nThe question \"Which of the following is not an endocrine gland?\" is a basic question that tests the student's understanding of the endocrine system. The student should be able to identify the major endocrine glands and distinguish them from other types of glands.\n\nThe answer to the question is \"Salivary.\" Salivary glands are exocrine glands that secrete saliva through ducts. They do not secrete hormones directly into the bloodstream and are therefore not endocrine glands.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2085,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7638,
            "description": "Thyroid",
            "question_id": 1906,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.969+05:30",
            "updated_at": "2024-07-02T17:11:45.969+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7639,
            "description": "Thymus",
            "question_id": 1906,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.972+05:30",
            "updated_at": "2024-07-02T17:11:45.972+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7640,
            "description": "Adrenal",
            "question_id": 1906,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.974+05:30",
            "updated_at": "2024-07-02T17:11:45.974+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7641,
            "description": "Salivary",
            "question_id": 1906,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:45.977+05:30",
            "updated_at": "2024-07-02T17:11:45.977+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1907,
        "description": "Characteristic of epithelial tissues is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:45.987+05:30",
        "updated_at": "2024-11-30T18:39:35.022+05:30",
        "detailed_solution": "**Epithelial tissues** are characterized by cells that are closely packed together, with little or no intercellular space. This arrangement of cells provides a barrier that protects the underlying tissues from the external environment. Epithelial tissues also have a high rate of cell turnover, with new cells being produced to replace old or damaged cells.\n\nThe ability of epithelial cells to undergo rapid divisions is essential for maintaining the integrity of the epithelial barrier. If cells were not able to divide quickly, the epithelium would become damaged and the underlying tissues would be exposed to the external environment.\n\n**Additional context:**\n\nEpithelial tissues are found in a variety of locations in the body, including the skin, the lining of the digestive tract, and the respiratory tract. Epithelial cells can be classified into two main types: glandular and non-glandular. Glandular epithelial cells secrete substances such as mucus and enzymes, while non-glandular epithelial cells simply protect the underlying tissues.\n\n**Explanation of the answer:**\n\nThe answer to the question is correct because the ability of epithelial cells to undergo rapid divisions is essential for maintaining the integrity of the epithelial barrier. If cells were not able to divide quickly, the epithelium would become damaged and the underlying tissues would be exposed to the external environment.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2086,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7642,
            "description": "Never produce glands",
            "question_id": 1907,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:45.998+05:30",
            "updated_at": "2024-07-02T17:11:45.998+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7643,
            "description": "Cells can undergo rapid divisions",
            "question_id": 1907,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.001+05:30",
            "updated_at": "2024-07-02T17:11:46.001+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7644,
            "description": "Abundant vascularisation",
            "question_id": 1907,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.004+05:30",
            "updated_at": "2024-07-02T17:11:46.004+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7645,
            "description": "Large intercellular spaces",
            "question_id": 1907,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.008+05:30",
            "updated_at": "2024-07-02T17:11:46.008+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1908,
        "description": "Which of the following characteristic is typical for all kinds of compound epithelia ? \n a. Presence of basement membrane \n b. Presence of germinativum layer of columnar cells\n c. Multilayer of cells \n d. Basal layer of squamous cells",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.015+05:30",
        "updated_at": "2024-11-30T18:39:35.225+05:30",
        "detailed_solution": "**Correct Answer: c. Multilayer of cells**\n\nCompound epithelia are classified based on the shape and arrangement of cells in different layers. They are typically multilayer, meaning they have more than one layer of cells. The cells in compound epithelia can be of different shapes, such as squamous, cuboidal, or columnar, and can be arranged in various ways.\n\nOption a is incorrect because not all compound epithelia have a basement membrane. A basement membrane is a thin layer of extracellular matrix that separates the epithelium from the underlying connective tissue. It is present in simple epithelia and some types of stratified epithelia, but not in all compound epithelia.\n\nOption b is incorrect because compound epithelia do not necessarily have a germinativum layer of columnar cells. The germinativum layer is a layer of stem cells found in some stratified epithelia, but it is not present in all compound epithelia.\n\nOption d is incorrect because compound epithelia do not always have a basal layer of squamous cells. The basal layer of compound epithelia can be composed of different types of cells, such as cuboidal or columnar cells.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2087,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7646,
            "description": "b & c",
            "question_id": 1908,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.019+05:30",
            "updated_at": "2024-07-02T17:11:46.019+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7647,
            "description": "c only",
            "question_id": 1908,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.022+05:30",
            "updated_at": "2024-07-02T17:11:46.022+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7648,
            "description": "a, b & c",
            "question_id": 1908,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.025+05:30",
            "updated_at": "2024-07-02T17:11:46.025+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7649,
            "description": "a & c",
            "question_id": 1908,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.028+05:30",
            "updated_at": "2024-07-02T17:11:46.028+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1909,
        "description": "Select the correct matching :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.035+05:30",
        "updated_at": "2024-11-30T18:39:35.427+05:30",
        "detailed_solution": "**Explanation:**\n\nEpithelial tissues are the lining or covering tissues of the body. They are classified based on their shape, arrangement, and function.\n\n**Columnar epithelium:**\n* Cells are tall and narrow, with a nucleus located near the base.\n* Found in the lining of the digestive tract (excluding the stomach), respiratory tract, and reproductive tract.\n* Function: Absorption and secretion.\n\n**Stomach:**\n* The lining of the stomach is covered by a stratified epithelium, which is thicker than columnar epithelium.\n* The stratified epithelium protects the stomach from the acidic environment and mechanical damage.\n\nTherefore, the correct matching is:\n\n**Columnar epithelium - Digestive tract (excluding stomach)**\n\n**Additional Context:**\n\n* Other types of epithelial tissues include:\n    * Squamous epithelium\n    * Cuboidal epithelium\n    * Ciliated epithelium\n* Epithelial tissues have various functions, including:\n    * Protection\n    * Absorption\n    * Secretion\n    * Exchange of gases\n* The structural organization of epithelial tissues is essential for maintaining homeostasis in the body.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2088,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7650,
            "description": "Cuboidal epithelium - Alveolar wall",
            "question_id": 1909,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.041+05:30",
            "updated_at": "2024-07-02T17:11:46.041+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7651,
            "description": "Columnar epithelium - Stomach",
            "question_id": 1909,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.045+05:30",
            "updated_at": "2024-07-02T17:11:46.045+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7652,
            "description": "Ciliated epithelium - Intestine",
            "question_id": 1909,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.048+05:30",
            "updated_at": "2024-07-02T17:11:46.048+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7653,
            "description": "Squamous epithelium - Germinal epithelium",
            "question_id": 1909,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.050+05:30",
            "updated_at": "2024-07-02T17:11:46.050+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1910,
        "description": "Assertion (A) : Gap junctions connect the cytoplasm of adjoining cells.\n Reason (R) : Gap junctions facilitate the cells to communicate with each other",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.056+05:30",
        "updated_at": "2024-11-30T18:39:35.633+05:30",
        "detailed_solution": "**Explanation** \n\n- Assertion (A) is correct because gap junction is a channel that connects the cytoplasm of two adjacent cells. It allows the exchange of ions, molecules and other small molecules between the cells. \n- Reason (R) is also correct because gap junctions facilitate the cells to communicate with each other by allowing the exchange of ions, molecules and other small molecules between the cells. \nHowever, R is not the correct explanation of A because gap junctions connect the cytoplasm of adjoining cells, not only for communication. \n\n**Additional context**\n\nGap junctions are found in a variety of tissues, including the heart, liver, and nervous system. They play an important role in coordinating the activity of cells and in maintaining homeostasis.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2089,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7654,
            "description": "Both A and R are True and R is the correct explanation of A.",
            "question_id": 1910,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.059+05:30",
            "updated_at": "2024-07-02T17:11:46.059+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7655,
            "description": "Both A and R are True but R is not correct explanation of A",
            "question_id": 1910,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.062+05:30",
            "updated_at": "2024-07-02T17:11:46.062+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7656,
            "description": "A is True but R is False",
            "question_id": 1910,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.065+05:30",
            "updated_at": "2024-07-02T17:11:46.065+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7657,
            "description": "A and R are False",
            "question_id": 1910,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.067+05:30",
            "updated_at": "2024-07-02T17:11:46.067+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1911,
        "description": "The major protein of the connective tissues is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.072+05:30",
        "updated_at": "2024-11-30T18:39:35.836+05:30",
        "detailed_solution": "**Collagen** is the major protein of the connective tissues. It is a fibrous protein that provides strength and support to the tissues. Collagen is found in all connective tissues, including tendons, ligaments, cartilage, and bone. It is also found in the skin, blood vessels, and organs.\n\nCollagen is a triple helix of three polypeptide chains. The polypeptide chains are coiled around each other in a right-handed helix. The amino acid sequence of the polypeptide chains is repeating and consists of glycine, proline, and hydroxyproline. The glycine residues are essential for the formation of the triple helix. The proline and hydroxyproline residues give the collagen molecule its strength and stability.\n\nCollagen is synthesized by fibroblasts, which are cells that are found in connective tissues. Fibroblasts secrete collagen into the extracellular matrix, where it self-assembles into fibers. The fibers are then cross-linked to each other to form a strong and stable network.\n\nCollagen is essential for the proper function of connective tissues. It provides strength and support to the tissues and helps to protect them from damage. Collagen also plays a role in cell adhesion, migration, and differentiation.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2090,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7658,
            "description": "Keratin",
            "question_id": 1911,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.078+05:30",
            "updated_at": "2024-07-02T17:11:46.078+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7659,
            "description": "Collagen",
            "question_id": 1911,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.080+05:30",
            "updated_at": "2024-07-02T17:11:46.080+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7660,
            "description": "Melanin",
            "question_id": 1911,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.086+05:30",
            "updated_at": "2024-07-02T17:11:46.086+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7661,
            "description": "Myosin",
            "question_id": 1911,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.088+05:30",
            "updated_at": "2024-07-02T17:11:46.088+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1912,
        "description": "Inter vertebral discs are composed of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.095+05:30",
        "updated_at": "2024-11-30T18:39:36.049+05:30",
        "detailed_solution": "**Explanation:**\n\nIntervertebral discs are composed of white fibrous cartilage. It is a type of cartilage that is found between the vertebrae in the spinal column. White fibrous cartilage is made up of collagen fibers that are arranged in a parallel fashion. This type of cartilage is strong and flexible, which allows it to withstand the forces that are applied to the spine during movement.\n\n**Additional context:**\n\nIn addition to white fibrous cartilage, intervertebral discs are also composed of a soft, gelatinous substance called the nucleus pulposus. The nucleus pulposus is surrounded by a layer of tough, fibrous tissue called the annulus fibrosus. The nucleus pulposus acts as a shock absorber, while the annulus fibrosus provides stability to the disc.\n\nIntervertebral discs are important for the proper function of the spine. They allow the spine to move smoothly and they help to protect the spinal cord from injury.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2091,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7662,
            "description": "Hyaline cartilage",
            "question_id": 1912,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.098+05:30",
            "updated_at": "2024-07-02T17:11:46.098+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7663,
            "description": "Elastic cartilage",
            "question_id": 1912,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.100+05:30",
            "updated_at": "2024-07-02T17:11:46.100+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7664,
            "description": "White fibrous cartilage",
            "question_id": 1912,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.102+05:30",
            "updated_at": "2024-07-02T17:11:46.102+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7665,
            "description": "Calcified cartilage",
            "question_id": 1912,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.103+05:30",
            "updated_at": "2024-07-02T17:11:46.103+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1913,
        "description": "Haversian canal contain :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.109+05:30",
        "updated_at": "2024-11-30T18:39:36.263+05:30",
        "detailed_solution": "**Explanation:**\n\nHaversian canals are microscopic channels that run through the compact bone tissue. They contain blood vessels and nerves that supply the osteocytes (bone cells) with nutrients and oxygen, and remove waste products.\n\n**Additional context:**\n\n**Structure of Compact Bone:**\n\n* Compact bone is the dense, hard outer layer of bone that provides strength and support.\n* It is made up of repeating units called osteons, which are cylindrical structures arranged parallel to the long axis of the bone.\n* Each osteon contains a central Haversian canal surrounded by concentric layers of bone matrix and osteocytes.\n\n**Functions of Haversian Canals:**\n\n* Transport nutrients and oxygen to osteocytes.\n* Remove waste products from osteocytes.\n* Facilitate bone remodeling, where old bone is broken down and replaced with new bone.\n\n**Clinical Significance:**\n\n* Osteoporosis is a condition where the density of bone decreases, making it more fragile and prone to fractures. This is often caused by a loss of bone mass, which can lead to a narrowing of the Haversian canals and reduced blood flow to osteocytes.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2092,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7666,
            "description": "Blood vessels and nerves",
            "question_id": 1913,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.112+05:30",
            "updated_at": "2024-07-02T17:11:46.112+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7667,
            "description": "Blood vessels only",
            "question_id": 1913,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.114+05:30",
            "updated_at": "2024-07-02T17:11:46.114+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7668,
            "description": "Lymphatic only",
            "question_id": 1913,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.116+05:30",
            "updated_at": "2024-07-02T17:11:46.116+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7669,
            "description": "Connective tissue only",
            "question_id": 1913,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.118+05:30",
            "updated_at": "2024-07-02T17:11:46.118+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1914,
        "description": "Fibroblast secretes :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.126+05:30",
        "updated_at": "2024-11-30T18:39:36.492+05:30",
        "detailed_solution": "**Explanation:**\nFibroblasts are the most common cells in connective tissue. They are responsible for the synthesis and secretion of the extracellular matrix, which is composed of collagen, elastin, and glycosaminoglycans. Collagen provides strength and support to the tissue, while elastin provides elasticity. Glycosaminoglycans are polysaccharides that help to hold water and provide lubrication.\n\n**Additional context:**\nFibroblasts are found in all types of connective tissue, including loose connective tissue, dense connective tissue, and cartilage. They are also found in the walls of blood vessels and lymphatic vessels.\n\nFibroblasts are derived from mesenchymal stem cells. These cells are found in the bone marrow and can differentiate into a variety of different cell types, including fibroblasts, osteoblasts, chondroblasts, and adipocytes.\n\nFibroblasts are important for the repair of damaged tissue. When tissue is damaged, fibroblasts migrate to the site of injury and begin to secrete collagen and other components of the extracellular matrix. This helps to form a new scar that repairs the damaged tissue.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2093,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7670,
            "description": "Matrix",
            "question_id": 1914,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.129+05:30",
            "updated_at": "2024-07-02T17:11:46.129+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7671,
            "description": "Fibres",
            "question_id": 1914,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.131+05:30",
            "updated_at": "2024-07-02T17:11:46.131+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7672,
            "description": "Both A and B",
            "question_id": 1914,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.138+05:30",
            "updated_at": "2024-07-06T17:07:57.835+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7673,
            "description": "Cells",
            "question_id": 1914,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.140+05:30",
            "updated_at": "2024-07-02T17:11:46.140+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1915,
        "description": "Mast cell secrete :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.147+05:30",
        "updated_at": "2024-11-30T18:39:36.710+05:30",
        "detailed_solution": "**Explanation:**\n\nMast cells are a type of white blood cell that are found in connective tissue. They are known for their role in allergic reactions, but they also play a role in inflammation and immunity. Mast cells secrete a variety of substances, including:\n\n* Histamine: Histamine is a vasodilator, which means it causes blood vessels to widen. This can lead to redness, swelling, and itching.\n* Tryptase: Tryptase is a protease, which means it breaks down proteins. This can lead to the release of inflammatory mediators, such as cytokines and chemokines.\n* Chymase: Chymase is another protease that can break down proteins. It can also activate other inflammatory mediators.\n\nAll of these substances can contribute to the symptoms of allergic reactions, such as sneezing, runny nose, and watery eyes. Mast cells can also release other substances, such as serotonin and prostaglandins, which can also contribute to inflammation and allergic reactions.\n\n**Additional Context:**\n\nMast cells are derived from the same stem cells that give rise to basophils. They are found in connective tissue throughout the body, but they are particularly common in the skin, lungs, and gastrointestinal tract. Mast cells are activated by a variety of stimuli, including allergens, cytokines, and physical trauma.\n\nWhen mast cells are activated, they degranulate, which means they release the contents of their granules into the extracellular space. This can lead to the release of a variety of inflammatory mediators, which can cause a variety of symptoms, depending on the location of the mast cells.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2094,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7674,
            "description": "Anticoagulant : Heparin",
            "question_id": 1915,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.150+05:30",
            "updated_at": "2024-07-02T17:11:46.150+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7675,
            "description": "Vasodilator : Histamine",
            "question_id": 1915,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.153+05:30",
            "updated_at": "2024-07-02T17:11:46.153+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7676,
            "description": "Vasoconstrictor : Serotonin",
            "question_id": 1915,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.156+05:30",
            "updated_at": "2024-07-02T17:11:46.156+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7677,
            "description": "All of the above",
            "question_id": 1915,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.158+05:30",
            "updated_at": "2024-07-02T17:11:46.158+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1916,
        "description": "Epiglottis is composed of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.164+05:30",
        "updated_at": "2024-11-30T18:39:36.941+05:30",
        "detailed_solution": "**Explanation:**\n\nThe epiglottis is a leaf-shaped flap of elastic cartilage that prevents food from entering the larynx during swallowing. It is located at the top of the larynx, behind the tongue.\n\n**Additional Context:**\n\n* The epiglottis is attached to the thyroid cartilage by the thyro-epiglottic ligament.\n* The epiglottis is innervated by the superior laryngeal nerve.\n* The epiglottis is covered by a mucous membrane.\n* The epiglottis is a protective structure that helps to prevent aspiration.\n\n**Relevance to NEET Exam:**\n\nThe epiglottis is a topic that is covered in the NEET syllabus under the topic 'Structural Organisation in Animals'. Students should be familiar with the structure and function of the epiglottis in order to answer questions on this topic.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2095,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7678,
            "description": "Hyaline cartilage",
            "question_id": 1916,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.167+05:30",
            "updated_at": "2024-07-02T17:11:46.167+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7679,
            "description": "White fibro cartilage",
            "question_id": 1916,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.170+05:30",
            "updated_at": "2024-07-02T17:11:46.170+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7680,
            "description": "Calcified cartilage",
            "question_id": 1916,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.173+05:30",
            "updated_at": "2024-07-02T17:11:46.173+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7681,
            "description": "Elastic cartilage",
            "question_id": 1916,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.175+05:30",
            "updated_at": "2024-07-02T17:11:46.175+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1917,
        "description": "All the following cells produces collagen except :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.182+05:30",
        "updated_at": "2024-11-30T18:39:37.163+05:30",
        "detailed_solution": "**Correct Answer:** Mast cells\n\n**Explanation:**\n\nCollagen is a type of protein that is found in connective tissues throughout the body. It is produced by cells called fibroblasts. Mast cells are a type of white blood cell that is involved in the allergic response. They do not produce collagen.\n\n**Additional Context:**\n\n* Collagen is the most abundant protein in the body.\n* It is a strong, fibrous protein that gives connective tissues their strength and elasticity.\n* Collagen is found in bones, tendons, ligaments, skin, and blood vessels.\n* Fibroblasts are cells that are found in connective tissues. They produce collagen and other proteins that give connective tissues their structure and function.\n* Mast cells are white blood cells that are involved in the allergic response. They release histamine and other inflammatory mediators when they are activated.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2096,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7682,
            "description": "Osteoblast",
            "question_id": 1917,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.190+05:30",
            "updated_at": "2024-07-02T17:11:46.190+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7683,
            "description": "Chondroblast",
            "question_id": 1917,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.195+05:30",
            "updated_at": "2024-07-02T17:11:46.195+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7684,
            "description": "Fibro blast",
            "question_id": 1917,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.198+05:30",
            "updated_at": "2024-07-02T17:11:46.198+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7685,
            "description": "Mast cells",
            "question_id": 1917,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.200+05:30",
            "updated_at": "2024-07-02T17:11:46.200+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1918,
        "description": "Matrix of cartilage is produced by :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.207+05:30",
        "updated_at": "2024-11-30T18:39:37.378+05:30",
        "detailed_solution": "**Matrix of cartilage is produced by: Chondroblasts**\n\n**Explanation:**\n\nCartilage is a type of connective tissue that provides support and flexibility to various body structures. It consists of specialized cells called chondrocytes that are embedded in a matrix composed of collagen fibers, proteoglycans, and water.\n\n**Chondroblasts are immature cartilage cells responsible for synthesizing and secreting the matrix.** They are derived from mesenchymal stem cells and differentiate into chondrocytes once they are enclosed within the matrix.\n\nDuring the development and growth of cartilage, chondroblasts actively produce and secrete components of the matrix, including collagen fibers, proteoglycans, and other glycosaminoglycans. These molecules form a complex interwoven network that provides the characteristic strength and flexibility of cartilage.\n\nThe matrix of cartilage is highly hydrated, containing up to 80% water, which contributes to its resilience and shock-absorbing properties. The collagen fibers provide tensile strength, while proteoglycans and glycosaminoglycans bind to water, creating a gel-like substance that allows for compression and flexibility.\n\nChondrocytes, once embedded within the matrix, maintain the integrity of the cartilage by producing and secreting additional matrix components as needed. They also regulate the turnover and degradation of the matrix through enzymes such as metalloproteinases.\n\n**Other important points related to cartilage matrix production:**\n\n* The process of cartilage matrix production is called chondrogenesis.\n* The composition and properties of the matrix can vary depending on the type of cartilage (hyaline, elastic, or fibrocartilage).\n* Chondroblasts are often found in clusters called chondrogenic zones or nests.\n* Once chondroblasts differentiate into chondrocytes, they become trapped within the matrix and lose their ability to divide.\n* Cartilage is avascular, meaning it lacks blood vessels, which limits its ability to repair and regenerate.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2097,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7686,
            "description": "Chondrocytes",
            "question_id": 1918,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.211+05:30",
            "updated_at": "2024-07-02T17:11:46.211+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7687,
            "description": "Chondroblasts",
            "question_id": 1918,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.213+05:30",
            "updated_at": "2024-07-02T17:11:46.213+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7688,
            "description": "Osteocytes",
            "question_id": 1918,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.216+05:30",
            "updated_at": "2024-07-02T17:11:46.216+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7689,
            "description": "Histiocytes",
            "question_id": 1918,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.218+05:30",
            "updated_at": "2024-07-02T17:11:46.218+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1919,
        "description": "Which of following lacks blood supply ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.225+05:30",
        "updated_at": "2024-11-30T18:39:37.570+05:30",
        "detailed_solution": "**Explanation:**\n\nCartilage is a type of connective tissue that is found in various parts of the body, such as the joints, ears, and nose. Unlike other tissues, cartilage does not have a blood supply. Instead, it relies on the diffusion of nutrients from the surrounding tissues.\n\nThe lack of blood supply in cartilage is due to its unique structure. Cartilage is composed of cells called chondrocytes, which are embedded in a matrix of collagen and proteoglycans. This matrix is very dense and prevents blood vessels from penetrating the tissue.\n\nThe lack of blood supply has several implications for cartilage. First, it means that cartilage is very slow to heal. If cartilage is damaged, it can take a long time for it to repair itself. Second, the lack of blood supply makes cartilage susceptible to infection. Bacteria and other microorganisms cannot easily reach cartilage, but if they do, they can cause serious infections that are difficult to treat.\n\n**Additional context:**\n\nCartilage is divided into three main types:\n\n* **Hyaline cartilage** is the most common type of cartilage. It is found in the joints, the ribs, and the nose.\n* **Elastic cartilage** is found in the ears and the epiglottis. It is more flexible than hyaline cartilage.\n* **Fibrocartilage** is the strongest type of cartilage. It is found in the intervertebral discs and the menisci of the knees.\n\nCartilage is a very important tissue in the body. It provides support, cushioning, and flexibility. The lack of blood supply in cartilage is a unique feature that has both advantages and disadvantages.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2098,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7690,
            "description": "Bone",
            "question_id": 1919,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.229+05:30",
            "updated_at": "2024-07-02T17:11:46.229+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7691,
            "description": "Cartilage",
            "question_id": 1919,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.236+05:30",
            "updated_at": "2024-07-02T17:11:46.236+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7692,
            "description": "Connective tissue",
            "question_id": 1919,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.238+05:30",
            "updated_at": "2024-07-02T17:11:46.238+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7693,
            "description": "All",
            "question_id": 1919,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.242+05:30",
            "updated_at": "2024-07-02T17:11:46.242+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1920,
        "description": "Sprain of body is due to pulling of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.254+05:30",
        "updated_at": "2024-11-30T18:39:37.771+05:30",
        "detailed_solution": "**Explanation:**\n\nA sprain is an injury to a ligament, which is a tough band of fibrous tissue that connects bones together. Ligaments help to stabilize joints and prevent excessive movement. When a ligament is stretched or torn beyond its normal range of motion, it can cause a sprain.\n\n**Additional context:**\n\n* Sprains are classified according to their severity:\n    * Grade 1: Mild stretching of the ligament without tearing\n    * Grade 2: Partial tearing of the ligament\n    * Grade 3: Complete tearing of the ligament\n* Sprains can occur in any joint, but they are most common in the ankle, knee, and wrist.\n* Symptoms of a sprain include pain, swelling, bruising, and difficulty moving the joint.\n* Treatment for a sprain typically involves rest, ice, compression, and elevation (RICE). In some cases, surgery may be necessary to repair a torn ligament.\n\n**Relevance to NEET exam:**\n\nThe topic of structural organization in animals is an important part of the NEET exam syllabus. Students need to understand the structure and function of different tissues and organs, including ligaments. By understanding the causes and symptoms of sprains, students can better prepare for questions related to this topic on the exam.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2099,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7694,
            "description": "Muscles",
            "question_id": 1920,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.260+05:30",
            "updated_at": "2024-07-02T17:11:46.260+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7695,
            "description": "Ligaments",
            "question_id": 1920,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.263+05:30",
            "updated_at": "2024-07-02T17:11:46.263+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7696,
            "description": "Tendon",
            "question_id": 1920,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.266+05:30",
            "updated_at": "2024-07-02T17:11:46.266+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7697,
            "description": "Nerves",
            "question_id": 1920,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.269+05:30",
            "updated_at": "2024-07-02T17:11:46.269+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1921,
        "description": "Protein present in cartilage is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.276+05:30",
        "updated_at": "2024-11-30T18:39:37.978+05:30",
        "detailed_solution": "**Explanation:**\n\nChondrin is a type of collagen that is found in cartilage. Collagen is a protein that provides strength and structure to connective tissues. In cartilage, chondrin helps to maintain the shape and integrity of the tissue.\n\n**Additional context:**\n\n* Cartilage is a type of connective tissue that is found in many parts of the body, including the joints, ears, and nose.\n* Cartilage is composed of cells called chondrocytes, which are embedded in a matrix of collagen and other proteins.\n* Chondrin is one of the main proteins found in the matrix of cartilage.\n* Chondrin is responsible for the strength and flexibility of cartilage.\n* Cartilage is a type of connective tissue that does not contain blood vessels.\n* Cartilage is therefore avascular, which means that it does not receive a direct blood supply.\n* Cartilage is nourished by diffusion of nutrients from the surrounding tissues.\n* Cartilage is a type of connective tissue that is very important for joint function.\n* Cartilage helps to reduce friction between bones and provides a smooth surface for movement.\n* Cartilage also helps to absorb shock and protect bones from damage.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2100,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7698,
            "description": "Fibroin",
            "question_id": 1921,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.284+05:30",
            "updated_at": "2024-07-02T17:11:46.284+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7699,
            "description": "Chondrin",
            "question_id": 1921,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.286+05:30",
            "updated_at": "2024-07-02T17:11:46.286+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7700,
            "description": "Ossein",
            "question_id": 1921,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.288+05:30",
            "updated_at": "2024-07-02T17:11:46.288+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7701,
            "description": "Casein",
            "question_id": 1921,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.290+05:30",
            "updated_at": "2024-07-02T17:11:46.290+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1922,
        "description": "Ligament connects :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.297+05:30",
        "updated_at": "2024-11-30T18:39:38.179+05:30",
        "detailed_solution": "**Explanation:**\n\nLigaments are tough, fibrous connective tissues that connect bones to bones. They stabilize and reinforce the joints, allowing for smooth movement while preventing excessive displacement of bones. Ligaments are primarily composed of collagen fibers, which provide strength and flexibility.\n\n**Additional Context:**\n\n* **Tendons:** Connect muscles to bones, allowing for the transmission of force and muscle contraction.\n* **Cartilage:** A specialized connective tissue that covers the ends of bones at joints, providing cushioning and reducing friction during movement.\n* **Joints:** The points where two or more bones connect, allowing for movement. Joints can be classified into various types, such as synovial joints (freely movable) and fibrous joints (immovable).",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2101,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7702,
            "description": "Muscle to skin",
            "question_id": 1922,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.300+05:30",
            "updated_at": "2024-07-02T17:11:46.300+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7703,
            "description": "Bone to bone",
            "question_id": 1922,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.302+05:30",
            "updated_at": "2024-07-02T17:11:46.302+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7704,
            "description": "Muscle to muscle",
            "question_id": 1922,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.304+05:30",
            "updated_at": "2024-07-02T17:11:46.304+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7705,
            "description": "Muscle to bone",
            "question_id": 1922,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.308+05:30",
            "updated_at": "2024-07-02T17:11:46.308+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1923,
        "description": "Scavanger cell of connective tissue proper is called as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.318+05:30",
        "updated_at": "2024-11-30T18:39:38.381+05:30",
        "detailed_solution": "**Explanation:**\n\nConnective tissue proper is a type of connective tissue that consists of cells and extracellular matrix. The cells in connective tissue proper include fibroblasts, adipocytes, and macrophages.\n\n**Macrophages** are scavenger cells that engulf and destroy foreign particles, dead cells, and debris. They are also involved in the immune response. Macrophages are present in all types of connective tissue, but they are particularly abundant in connective tissue proper.\n\n**Additional Context:**\n\nConnective tissue proper is found in a variety of locations in the body, including the skin, muscles, tendons, ligaments, and blood vessels. It provides support and protection to the body's organs and tissues.\n\nThe extracellular matrix of connective tissue proper is composed of collagen fibers, elastin fibers, and ground substance. Collagen fibers provide strength and rigidity to the tissue, while elastin fibers allow the tissue to stretch and recoil. Ground substance is a gel-like substance that fills the spaces between the cells and fibers.\n\n**Additional Information for NEET Exam Preparation:**\n\n* **NEET Syllabus:** Connective tissue proper is included in the NEET syllabus under the topic \"Structural Organisation in Animals.\"\n* **Importance of this Topic:** Understanding the structure and function of connective tissue proper is essential for a comprehensive understanding of the human body.\n* **Tips for Answering Similar Questions:** When answering questions about connective tissue proper, it is important to focus on the cells and extracellular matrix that make up the tissue. It is also important to understand the functions of the different cell types in connective tissue proper.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2102,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7706,
            "description": "Fibroblast cell",
            "question_id": 1923,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.321+05:30",
            "updated_at": "2024-07-02T17:11:46.321+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7707,
            "description": "Mast cell",
            "question_id": 1923,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.323+05:30",
            "updated_at": "2024-07-02T17:11:46.323+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7708,
            "description": "Plasma cell",
            "question_id": 1923,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.328+05:30",
            "updated_at": "2024-07-02T17:11:46.328+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7709,
            "description": "Macrophages",
            "question_id": 1923,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.336+05:30",
            "updated_at": "2024-07-02T17:11:46.336+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1924,
        "description": "Cartilage is present in :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.343+05:30",
        "updated_at": "2024-11-30T18:39:38.574+05:30",
        "detailed_solution": "**Answer is correct because:**\n\nCartilage is a type of connective tissue that is present between the adjacent bones of the vertebral column and limbs. It provides a smooth surface for the bones to move against each other and helps to cushion them from impact. Cartilage is also found in other parts of the body, such as the ears, nose, and trachea.\n\n**Additional context:**\n\nCartilage is a type of connective tissue that is composed of cells called chondrocytes. Chondrocytes are embedded in a matrix of collagen and proteoglycans. Collagen is a protein that provides strength and flexibility to the cartilage, while proteoglycans are molecules that attract water and give cartilage its cushioning properties.\n\nCartilage is avascular, meaning that it does not contain any blood vessels. This means that cartilage cannot repair itself if it is damaged. However, cartilage can be replaced by bone through a process called endochondral ossification. Endochondral ossification is the process by which bones grow in length during childhood.\n\n**Uses of cartilage:**\n\n* **Provides a smooth surface for bones to move against each other.** Cartilage is found between the ends of bones in joints. It helps to reduce friction and wear and tear on the bones.\n* **Cushions bones from impact.** Cartilage helps to absorb shock and protect bones from damage.\n* **Supports and shapes structures.** Cartilage is found in the ears, nose, and trachea. It helps to support these structures and give them their shape.\n* **Promotes bone growth.** Cartilage is involved in the process of endochondral ossification, which is how bones grow in length during childhood.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2103,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7710,
            "description": "Between adjacent bones of vertebral column and limbs",
            "question_id": 1924,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.346+05:30",
            "updated_at": "2024-07-02T17:11:46.346+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7711,
            "description": "In middle of the long bone",
            "question_id": 1924,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.348+05:30",
            "updated_at": "2024-07-02T17:11:46.348+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7712,
            "description": "Bone marrow cavity",
            "question_id": 1924,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.351+05:30",
            "updated_at": "2024-07-02T17:11:46.351+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7713,
            "description": "All of the above",
            "question_id": 1924,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.353+05:30",
            "updated_at": "2024-07-02T17:11:46.353+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1925,
        "description": "Regeneration of cartilage can occur from its :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.361+05:30",
        "updated_at": "2024-11-30T18:39:38.773+05:30",
        "detailed_solution": "**Explanation:**\nCartilage is a connective tissue that is found in many parts of the body, including the joints, ears, and nose. Cartilage is composed of cells called chondrocytes, which are embedded in a matrix of collagen and other proteins.\n\nCartilage is avascular, meaning that it does not contain blood vessels. As a result, cartilage is not able to repair itself very well. However, cartilage can regenerate from its perichondrium, which is a layer of connective tissue that surrounds the cartilage.\n\nThe perichondrium contains stem cells that can differentiate into chondrocytes. When the cartilage is damaged, the stem cells in the perichondrium can migrate into the damaged area and differentiate into new chondrocytes. This process can help to repair the cartilage and restore its function.\n\n**Additional context:**\n\n* Cartilage is classified into three types: hyaline cartilage, elastic cartilage, and fibrocartilage.\n* Hyaline cartilage is the most common type of cartilage and is found in the joints, ribs, and nose.\n* Elastic cartilage is found in the ears and epiglottis.\n* Fibrocartilage is found in the intervertebral discs and menisci of the knee.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2104,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7714,
            "description": "Matrix",
            "question_id": 1925,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.364+05:30",
            "updated_at": "2024-07-02T17:11:46.364+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7715,
            "description": "Plasma",
            "question_id": 1925,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.368+05:30",
            "updated_at": "2024-07-02T17:11:46.368+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7716,
            "description": "Perichondrium",
            "question_id": 1925,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.372+05:30",
            "updated_at": "2024-07-02T17:11:46.372+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7717,
            "description": "A piece without perichondrium",
            "question_id": 1925,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.379+05:30",
            "updated_at": "2024-07-02T17:11:46.379+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1926,
        "description": "What will happen if ligaments are cut or broken ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.386+05:30",
        "updated_at": "2024-11-30T18:39:38.976+05:30",
        "detailed_solution": "**Explanation**\n\nLigaments are tough, fibrous connective tissues that connect bones to other bones. They are responsible for providing stability and preventing excessive movement at joints.\n\nIf ligaments are cut or broken, the bones they connect will become unfixed. This can lead to instability, pain, and decreased range of motion at the affected joint.\n\nIn severe cases, a torn ligament can lead to dislocation of the bones, which is a complete separation of the bones at a joint. This can be a very serious injury that requires immediate medical attention.\n\nTherefore, it is important to protect ligaments from injury by avoiding activities that could put them at risk, such as contact sports or heavy lifting. If you do experience a ligament injury, it is important to see a doctor to get it diagnosed and treated properly.\n\n**Additional context**\nThe structural organization of animals is a fundamental concept in biology that refers to the way in which the different parts of an animal's body are organized and arranged. Ligaments are just one type of connective tissue that is found in the body. Other types of connective tissue include tendons, cartilage, and bone. Each type of connective tissue has a specific structure and function.\n\n**Relevance to NEET Exam**\nThe NEET (National Eligibility cum Entrance Test) is a highly competitive entrance exam that is used to select students for admission to medical schools in India. The exam covers a wide range of topics, including biology, chemistry, and physics. The question about ligaments is relevant to the NEET exam because it tests a student's understanding of the structural organization of animals.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2105,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7718,
            "description": "Bones will move freely at joints",
            "question_id": 1926,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.397+05:30",
            "updated_at": "2024-07-02T17:11:46.397+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7719,
            "description": "No movement at joint",
            "question_id": 1926,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.401+05:30",
            "updated_at": "2024-07-02T17:11:46.401+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7720,
            "description": "Bones will become unfixed",
            "question_id": 1926,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.406+05:30",
            "updated_at": "2024-07-02T17:11:46.406+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7721,
            "description": "Bones will become fixed",
            "question_id": 1926,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.414+05:30",
            "updated_at": "2024-07-02T17:11:46.414+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1927,
        "description": "The central shaft of a long bone is known as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.425+05:30",
        "updated_at": "2024-11-30T18:39:39.176+05:30",
        "detailed_solution": "**Explanation:**\n\n- The long bone in the human body is composed of four parts: Epiphysis, Metaphysis, Diaphysis, and Articular cartilage.\n- The central shaft is the longest part of the long bone and it is known as Diaphysis.\n- The diaphysis is responsible for providing structural support and protection to the bone marrow inside.\n- The epiphysis is located at the ends of the bone and it is responsible for forming synovial joints with other bones.\n- The metaphysis is located between the diaphysis and epiphysis and it is responsible for bone growth.\n- The articular cartilage is a thin layer of cartilage that covers the epiphysis and it helps to reduce friction during joint movement.\n\nTherefore, the central shaft of a long bone is known as Diaphysis.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2106,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7722,
            "description": "Diaphysis",
            "question_id": 1927,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.430+05:30",
            "updated_at": "2024-07-02T17:11:46.430+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7723,
            "description": "Epiphysis",
            "question_id": 1927,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.432+05:30",
            "updated_at": "2024-07-02T17:11:46.432+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7724,
            "description": "Metaphysis",
            "question_id": 1927,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.435+05:30",
            "updated_at": "2024-07-02T17:11:46.435+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7725,
            "description": "Zygapophysis",
            "question_id": 1927,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.438+05:30",
            "updated_at": "2024-07-02T17:11:46.438+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1928,
        "description": "Haversian system is a diagnostic feature of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.445+05:30",
        "updated_at": "2024-11-30T18:39:39.381+05:30",
        "detailed_solution": "**Explanation:**\n\nThe Haversian system is a structural arrangement found in the compact bone tissue of mammals. It consists of concentric layers of osteocytes (bone cells) surrounding a central canal that contains blood vessels and nerves. This system helps in the exchange of nutrients and waste products between the blood and the bone cells.\n\nIn contrast, non-mammalian vertebrates, such as birds, reptiles, and amphibians, have a different bone structure known as the lamellar bone. Lamellar bone lacks the organized Haversian system and instead has parallel layers of bone tissue.\n\nTherefore, the presence of a Haversian system is a distinctive characteristic that differentiates mammalian bones from the bones of non-mammalian vertebrates. This feature is crucial for the strength and metabolic activity of mammalian bones.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2107,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7726,
            "description": "Avian bones",
            "question_id": 1928,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.450+05:30",
            "updated_at": "2024-07-02T17:11:46.450+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7727,
            "description": "All animals",
            "question_id": 1928,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.453+05:30",
            "updated_at": "2024-07-02T17:11:46.453+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7728,
            "description": "Mammalian bones",
            "question_id": 1928,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.456+05:30",
            "updated_at": "2024-07-02T17:11:46.456+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7729,
            "description": "Reptilian bones",
            "question_id": 1928,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.459+05:30",
            "updated_at": "2024-07-02T17:11:46.459+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1929,
        "description": "Cartilage is formed by :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.476+05:30",
        "updated_at": "2024-11-30T18:39:39.580+05:30",
        "detailed_solution": "**Answer: Chondroblasts**\n\n**Explanation:**\n\nCartilage is a type of connective tissue that is found in many parts of the body, including the joints, ears, and nose. It is composed of cells called chondroblasts, which are responsible for producing the cartilage matrix. The matrix is made up of collagen fibers and proteoglycans, which give cartilage its strength and flexibility.\n\nChondroblasts are found in the inner layer of the perichondrium, which is a membrane that surrounds cartilage. When a chondroblast produces enough matrix, it becomes trapped within the matrix and is called a chondrocyte. Chondrocytes are mature cartilage cells that are responsible for maintaining the cartilage matrix.\n\nThere are three types of cartilage: hyaline cartilage, elastic cartilage, and fibrocartilage. Hyaline cartilage is the most common type of cartilage and is found in the joints, ribs, and trachea. Elastic cartilage is found in the ears and epiglottis and is more flexible than hyaline cartilage. Fibrocartilage is found in the intervertebral discs and knee menisci and is stronger than hyaline cartilage.\n\nCartilage is an important tissue that plays a role in many functions of the body. It provides support and cushioning for the joints, allows for movement, and helps to protect the body from injury.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2108,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7730,
            "description": "Osteoblasts",
            "question_id": 1929,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.487+05:30",
            "updated_at": "2024-07-02T17:11:46.487+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7731,
            "description": "Fibroblasts",
            "question_id": 1929,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.490+05:30",
            "updated_at": "2024-07-02T17:11:46.490+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7732,
            "description": "Chondroclasts",
            "question_id": 1929,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.493+05:30",
            "updated_at": "2024-07-02T17:11:46.493+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7733,
            "description": "Chondroblasts",
            "question_id": 1929,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.497+05:30",
            "updated_at": "2024-07-02T17:11:46.497+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1930,
        "description": "The membrane that covers cartilage is known as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.507+05:30",
        "updated_at": "2024-11-30T18:39:39.781+05:30",
        "detailed_solution": "**Explanation:**\n\n**Cartilage** is a type of connective tissue that provides structural support to the body. It is composed of specialized cells called chondrocytes, which are embedded in a matrix of collagen and other proteins.\n\n**Perichondrium** is a fibrous membrane that covers the external surface of cartilage. It contains blood vessels and nerves that supply the cartilage with nutrients and oxygen. The perichondrium also helps to attach cartilage to other tissues and bones.\n\n**Therefore, the answer is Perichondrium.**\n\n**Additional context:**\n\n* Cartilage is found in many parts of the body, including the joints, ears, nose, and trachea.\n* There are three main types of cartilage: hyaline cartilage, elastic cartilage, and fibrocartilage.\n* Cartilage is avascular, meaning that it does not contain blood vessels. This means that cartilage must rely on diffusion for transport of nutrients and oxygen.\n* Cartilage is also aneural, meaning that it does not contain nerves. This means that cartilage is not sensitive to pain.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2109,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7734,
            "description": "Periosteum",
            "question_id": 1930,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.518+05:30",
            "updated_at": "2024-07-02T17:11:46.518+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7735,
            "description": "Perichondrium",
            "question_id": 1930,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.521+05:30",
            "updated_at": "2024-07-02T17:11:46.521+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7736,
            "description": "Perineurium",
            "question_id": 1930,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.523+05:30",
            "updated_at": "2024-07-02T17:11:46.523+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7737,
            "description": "Pericardium",
            "question_id": 1930,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.525+05:30",
            "updated_at": "2024-07-02T17:11:46.525+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1931,
        "description": "External ear (pinna) is a flexible structure composed of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.531+05:30",
        "updated_at": "2024-11-30T18:39:39.980+05:30",
        "detailed_solution": "**Explanation:**\n\nThe external ear, also known as the pinna or auricle, is a flexible structure composed of cartilage. Cartilage is a type of connective tissue that is found in many parts of the body, including the ears, nose, and joints. It is a strong and flexible tissue that provides support and protection to the structures it encloses.\n\nThe pinna is made up of a thin layer of skin that covers a framework of cartilage. The cartilage is arranged in a complex shape that helps to collect and funnel sound waves into the ear canal. The shape of the pinna also helps to determine the direction from which sound is coming.\n\nThe cartilage of the pinna is elastic, which allows it to withstand bending and twisting forces. This flexibility helps to protect the delicate structures of the inner ear from damage.\n\n**Additional Context:**\n\nThe external ear is the only visible part of the ear. It is located on the side of the head and is connected to the skull by a short, bony canal called the ear canal. The ear canal leads to the middle ear, which is an air-filled cavity that contains the eardrum and the ossicles (three small bones that transmit sound waves to the inner ear). The inner ear is located deep within the skull and contains the cochlea and the vestibular system, which are responsible for hearing and balance, respectively.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2110,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7738,
            "description": "Bone",
            "question_id": 1931,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.541+05:30",
            "updated_at": "2024-07-02T17:11:46.541+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7739,
            "description": "Cartilage",
            "question_id": 1931,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.545+05:30",
            "updated_at": "2024-07-02T17:11:46.545+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7740,
            "description": "Tendon",
            "question_id": 1931,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.550+05:30",
            "updated_at": "2024-07-02T17:11:46.550+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7741,
            "description": "Ligament",
            "question_id": 1931,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.555+05:30",
            "updated_at": "2024-07-02T17:11:46.555+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1932,
        "description": "Formation of cartilage is known as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.563+05:30",
        "updated_at": "2024-11-30T18:39:40.183+05:30",
        "detailed_solution": "**Explanation:**\n\nChondrogenesis is the process by which cartilage is formed. It is a specialized form of mesenchymal cell differentiation that occurs in the embryo and during growth and development.\n\n* **Embryonic Chondrogenesis:** During embryonic development, chondroblasts differentiate from mesenchymal cells and secrete a matrix of collagen and proteoglycans. This matrix forms the cartilage anlagen, which later develops into mature cartilage.\n* **Postnatal Chondrogenesis:** In adults, chondrogenesis occurs during growth and repair processes. Mesenchymal stem cells proliferate and differentiate into chondroblasts, which then secrete matrix and become chondrocytes.\n\n**Additional Context:**\n\n* Cartilage is a specialized connective tissue found in joints, bones, ears, and nose.\n* It provides support, cushioning, and flexibility.\n* There are three types of cartilage:\n\n    * **Hyaline cartilage:** Most common type, provides flexibility and supports smooth surfaces in joints.\n    * **Elastic cartilage:** Provides elasticity and resilience, found in the ear and epiglottis.\n    * **Fibrocartilage:** Combines strength and flexibility, found in intervertebral discs and menisci.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2111,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7742,
            "description": "Diapedesis",
            "question_id": 1932,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.569+05:30",
            "updated_at": "2024-07-02T17:11:46.569+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7743,
            "description": "Chondrogenesis",
            "question_id": 1932,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.571+05:30",
            "updated_at": "2024-07-02T17:11:46.571+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7744,
            "description": "Haemopoiesis",
            "question_id": 1932,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.574+05:30",
            "updated_at": "2024-07-02T17:11:46.574+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7745,
            "description": "Ossification",
            "question_id": 1932,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.579+05:30",
            "updated_at": "2024-07-02T17:11:46.579+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1933,
        "description": "Role of bone marrow in mammals is to :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.592+05:30",
        "updated_at": "2024-11-30T18:39:40.387+05:30",
        "detailed_solution": "**Explanation:**\n\n**Bone marrow** is a soft, spongy tissue found inside the cavities of bones. It is responsible for the production of blood cells, a process known as **haematopoiesis.**\n\n* **Red bone marrow:** Produces red blood cells (erythrocytes), white blood cells (leukocytes), and platelets (thrombocytes).\n* **Yellow bone marrow:** Primarily composed of fat cells. However, it can convert back to red bone marrow in times of increased blood cell demand (e.g., during recovery from blood loss).\n\n**Role of bone marrow in haematopoiesis:**\n\n* Stem cells in the bone marrow differentiate into **haematopoietic stem cells (HSCs).**\n* HSCs give rise to **common myeloid progenitors (CMPs)** and **common lymphoid progenitors (CLPs).**\n* CMPs develop into erythrocytes, leukocytes, and platelets.\n* CLPs mature into lymphocytes (B cells, T cells, and natural killer cells).\n\nTherefore, the primary role of bone marrow in mammals is to act as **haemopoietic tissue**, producing the blood cells essential for maintaining blood homeostasis and immune function.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2112,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7746,
            "description": "Assist kidneys",
            "question_id": 1933,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.597+05:30",
            "updated_at": "2024-07-02T17:11:46.597+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7747,
            "description": "Act as haemopoietic tissue",
            "question_id": 1933,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.600+05:30",
            "updated_at": "2024-07-02T17:11:46.600+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7748,
            "description": "Assist liver",
            "question_id": 1933,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.604+05:30",
            "updated_at": "2024-07-02T17:11:46.604+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7749,
            "description": "Control blood pressure",
            "question_id": 1933,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.608+05:30",
            "updated_at": "2024-07-02T17:11:46.608+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1934,
        "description": "Hyaline cartilage forms :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.620+05:30",
        "updated_at": "2024-11-30T18:39:40.589+05:30",
        "detailed_solution": "**Explanation:**\n\n**Hyaline cartilage** is a type of cartilage composed of thin, flexible fibers that allow for some movement. It is found in various locations in the body, including the:\n\n- **Tracheal rings:** The rings of the trachea, which provide structural support and flexibility to the airway.\n- Articular surfaces of joints\n- Nose\n- Epiphyseal plates of long bones\n\n**Tracheal rings** are made of hyaline cartilage because it allows for movement of the trachea during breathing, while still providing support to the airway. The other options provided are not made of hyaline cartilage:\n\n- **Fibrocartilage** is found in intervertebral discs and menisci of the knee.\n- **Elastic cartilage** is found in the external ear and epiglottis.\n\nTherefore, the answer is: **Tracheal rings**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2113,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7750,
            "description": "Tracheal rings",
            "question_id": 1934,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.626+05:30",
            "updated_at": "2024-07-02T17:11:46.626+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7751,
            "description": "Pubic symphysis",
            "question_id": 1934,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.629+05:30",
            "updated_at": "2024-07-02T17:11:46.629+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7752,
            "description": "Epiglottis",
            "question_id": 1934,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.632+05:30",
            "updated_at": "2024-07-02T17:11:46.632+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7753,
            "description": "External ear pinna",
            "question_id": 1934,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.636+05:30",
            "updated_at": "2024-07-02T17:11:46.636+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1935,
        "description": "Bone forming cells are known as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.646+05:30",
        "updated_at": "2024-11-30T18:39:40.791+05:30",
        "detailed_solution": "**Answer: Osteoblasts**\n\n**Explanation:**\n\n* **Osteoblasts** are bone-forming cells that are responsible for the synthesis and mineralization of bone matrix.\n\n* They differentiate from mesenchymal stem cells and are found on the surface of developing and remodeling bone.\n\n* Osteoblasts secrete a collagenous matrix (osteoid) that is mineralized by calcium and phosphate ions to form bone.\n\n**Additional Context:**\n\n* **Osteocytes** are mature bone cells that are embedded within the bone matrix.\n* **Osteoclasts** are cells that break down bone tissue during bone remodeling.\n* **Bone remodeling** is a continuous process by which bone is formed and resorbed to maintain bone strength and integrity.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2114,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7754,
            "description": "Chondroclasts",
            "question_id": 1935,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.650+05:30",
            "updated_at": "2024-07-02T17:11:46.650+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7755,
            "description": "Osteoblasts",
            "question_id": 1935,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.653+05:30",
            "updated_at": "2024-07-02T17:11:46.653+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7756,
            "description": "Chondroblasts",
            "question_id": 1935,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.656+05:30",
            "updated_at": "2024-07-02T17:11:46.656+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7757,
            "description": "Osteoclasts",
            "question_id": 1935,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.658+05:30",
            "updated_at": "2024-07-02T17:11:46.658+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1936,
        "description": "Cardiac muscle fibres are :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.668+05:30",
        "updated_at": "2024-11-30T18:39:40.995+05:30",
        "detailed_solution": "**Cardiac muscle fibres are striated and involuntary.**\n\n* **Striated:** Cardiac muscle cells have a striated appearance due to the arrangement of thick and thin filaments within the cell. This striated appearance is similar to that seen in skeletal muscle cells.\n* **Involuntary:** Cardiac muscle cells are involuntary, meaning that they contract automatically without conscious control. This is in contrast to skeletal muscle cells, which are voluntary and can be controlled consciously.\n\nThe striated appearance of cardiac muscle cells is due to the arrangement of thick and thin filaments within the cell. The thick filaments are composed of the protein myosin, while the thin filaments are composed of the proteins actin and tropomyosin. The arrangement of these filaments allows for the sliding filament mechanism of muscle contraction, which is responsible for the contraction of the heart muscle.\n\nThe involuntary nature of cardiac muscle cells is due to the presence of pacemaker cells in the heart. Pacemaker cells are specialized cells that generate electrical impulses that cause the heart muscle to contract. These impulses are generated automatically, without conscious control, and they ensure that the heart muscle continues to contract rhythmically throughout the life of the organism.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2115,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7758,
            "description": "Striated and involuntary",
            "question_id": 1936,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.680+05:30",
            "updated_at": "2024-07-02T17:11:46.680+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7759,
            "description": "Striated and voluntary",
            "question_id": 1936,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.686+05:30",
            "updated_at": "2024-07-02T17:11:46.686+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7760,
            "description": "Non–striated and involuntary",
            "question_id": 1936,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.696+05:30",
            "updated_at": "2024-07-02T17:11:46.696+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7761,
            "description": "Non–striated and voluntary",
            "question_id": 1936,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.700+05:30",
            "updated_at": "2024-07-02T17:11:46.700+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1937,
        "description": "Which one of the following muscles, gets fatigued very quickly?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.716+05:30",
        "updated_at": "2024-11-30T18:39:41.197+05:30",
        "detailed_solution": "**Explanation:**\n\nSkeletal muscles are voluntary muscles that are attached to the bones. They are used for conscious movements, such as walking, running, and lifting objects. \n\nSkeletal muscles fatigue quickly because they contain a high proportion of fast-twitch muscle fibers. \n\nFast-twitch muscle fibers are primarily responsible for rapid but powerful contractions and rely on anaerobic metabolism, which produces energy quickly but also leads to the accumulation of lactic acid as a byproduct. \n\nAs lactic acid accumulates, it lowers the muscle's pH and interferes with its ability to contract, leading to fatigue.\n\nIn contrast, slow-twitch muscle fibers, which are found in endurance muscles, have a higher capacity for aerobic metabolism and can sustain contractions for longer periods without fatigue.\n\n**Additional Context:**\n\n* **Topic: Structural Organization in Animals**\n* **Subtopic: Muscular System**\n* **Muscle Types:**\n    * Skeletal muscle: Voluntary, fast-twitch (fatigue quickly)\n    * Smooth muscle: Involuntary, slow-twitch (sustained contractions)\n    * Cardiac muscle: Involuntary, slow-twitch, forms the heart (continuous contractions)\n* **Muscle Fatigue:**\n    * Occurs when muscles cannot maintain their force of contraction\n    * Causes: Energy depletion, accumulation of metabolic waste products (e.g., lactic acid)",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2116,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7762,
            "description": "Skeletal muscle",
            "question_id": 1937,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.727+05:30",
            "updated_at": "2024-07-02T17:11:46.727+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7763,
            "description": "Smooth muscle",
            "question_id": 1937,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.732+05:30",
            "updated_at": "2024-07-02T17:11:46.732+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7764,
            "description": "Cardiac muscle",
            "question_id": 1937,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.736+05:30",
            "updated_at": "2024-07-02T17:11:46.736+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7765,
            "description": "All of the above",
            "question_id": 1937,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.739+05:30",
            "updated_at": "2024-07-02T17:11:46.739+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1938,
        "description": "Involuntary muscles are :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.753+05:30",
        "updated_at": "2024-11-30T18:39:41.402+05:30",
        "detailed_solution": "**Explanation:**\r\n\r\n**Involuntary muscles** are those which are not under conscious control. They are also known as smooth muscles or visceral muscles. They are found in the walls of internal organs such as the stomach, intestine, blood vessels, uterus, and urinary bladder.\r\n\r\n Involuntary muscles are innervated by the **autonomic nervous system**. This system controls the automatic functions of the body, such as breathing, digestion, and heart rate.\r\n\r\nInvoluntary muscles are **slow-acting** and **low-fatigable**. They can contract for a long period of time without becoming fatigued.\r\n\r\n**Option (B) and (C)** are both correct because involuntary muscles are found in the walls of internal organs and they are not under conscious control.\r\n\r\n**Additional context:**\r\n\r\n* Voluntary muscles are those which are under conscious control. They are also known as skeletal muscles. They are attached to the bones and are responsible for movement.\r\n* Involuntary muscles are made up of spindle-shaped cells.\r\n* Involuntary muscles are innervated by autonomic nerves, which are part of the peripheral nervous system.\r\n* The autonomic nervous system has two divisions: the sympathetic nervous system and the parasympathetic nervous system. The sympathetic nervous system controls the \"fight or flight\" response, while the parasympathetic nervous system controls the \"rest and digest\" response.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2117,
        "fixed_at": "2024-11-12T00:00:00.000+05:30",
        "fix_summary": "The correct answer was missing in the given options. Options are fixed now.",
        "created_by": "",
        "updated_by": "kanza@testline.in",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7766,
            "description": "Under the control of will",
            "question_id": 1938,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.757+05:30",
            "updated_at": "2024-07-02T17:11:46.757+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7767,
            "description": "Not under the control of animal's will",
            "question_id": 1938,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.763+05:30",
            "updated_at": "2024-07-02T17:11:46.763+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7768,
            "description": "Controlled by autonomic nervous system",
            "question_id": 1938,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.769+05:30",
            "updated_at": "2024-07-02T17:11:46.769+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7769,
            "description": "Both (B) and (C)",
            "question_id": 1938,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.794+05:30",
            "updated_at": "2024-11-12T22:42:12.318+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1939,
        "description": "Unstriped muscles are also known as :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.807+05:30",
        "updated_at": "2024-11-30T18:39:41.616+05:30",
        "detailed_solution": "**Smooth muscles** are also known as **non-striated muscles** or **involuntary muscles**. They are found in the walls of internal organs, such as the stomach, intestines, and blood vessels. Smooth muscles are not under conscious control, and they contract slowly and rhythmically.\n\n**Cardiac muscles** are also known as **striated muscles**. They are found in the heart, and they contract rhythmically to pump blood throughout the body. Cardiac muscles are under involuntary control.\n\n**Skeletal muscles** are also known as **striated muscles**. They are attached to bones, and they contract to move the body. Skeletal muscles are under conscious control.\n\nTherefore, the answer to the question \"Unstriped muscles are also known as :\" is **All of these**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2118,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7770,
            "description": "Visceral muscles",
            "question_id": 1939,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.810+05:30",
            "updated_at": "2024-07-02T17:11:46.810+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7771,
            "description": "Smooth muscles",
            "question_id": 1939,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.814+05:30",
            "updated_at": "2024-07-02T17:11:46.814+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7772,
            "description": "Involuntary muscles",
            "question_id": 1939,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.817+05:30",
            "updated_at": "2024-07-02T17:11:46.817+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7773,
            "description": "All of these",
            "question_id": 1939,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.820+05:30",
            "updated_at": "2024-07-02T17:11:46.820+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1940,
        "description": "Nodes of Ranvier are found in :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.835+05:30",
        "updated_at": "2024-11-30T18:39:41.824+05:30",
        "detailed_solution": "**Why is the answer correct?**\n\nNodes of Ranvier are specialized gaps in the myelin sheath that surrounds the axon of a neuron. Myelin is an insulating layer that helps to speed up the transmission of electrical signals along the nerve fiber. At the Nodes of Ranvier, the myelin sheath is interrupted, which allows the electrical signal to \"jump\" from one node to the next. This process, known as saltatory conduction, makes the transmission of electrical signals much faster than if the signal had to travel through the entire length of the myelin sheath.\n\n**Additional context:**\n\n* The Nodes of Ranvier are named after the French physiologist Louis-Antoine Ranvier, who first described them in 1878.\n* The Nodes of Ranvier are found in both myelinated and unmyelinated axons, but they are more common in myelinated axons.\n* The distance between the Nodes of Ranvier is typically about 1 millimeter.\n* The Nodes of Ranvier play an important role in the transmission of electrical signals along the axon. They help to speed up the signal and prevent it from being lost in the myelin sheath.\n\n**Usefulness for a student:**\n\nThis information can be used by a student to answer similar questions on the NEET exam. For example, a student may be asked to identify the location of the Nodes of Ranvier or to explain how they help to speed up the transmission of electrical signals along the axon.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2119,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7774,
            "description": "Cyton",
            "question_id": 1940,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.840+05:30",
            "updated_at": "2024-07-02T17:11:46.840+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7775,
            "description": "Dendrons",
            "question_id": 1940,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.848+05:30",
            "updated_at": "2024-07-02T17:11:46.848+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7776,
            "description": "Axon",
            "question_id": 1940,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.853+05:30",
            "updated_at": "2024-07-02T17:11:46.853+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7777,
            "description": "Astrocyte",
            "question_id": 1940,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.855+05:30",
            "updated_at": "2024-07-02T17:11:46.855+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1941,
        "description": "Which cell-organelle is absent in neurons ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.864+05:30",
        "updated_at": "2024-11-30T18:39:42.032+05:30",
        "detailed_solution": "**Answer: Centriole**\n\n**Explanation:**\n\nCentrioles are cylindrical structures that help in organizing microtubules for the formation of cilia and flagella. They are present in almost all eukaryotic cells, except for mature red blood cells and neural cells like neurons.\n\nIn neurons, the absence of centrioles is related to their unique function and structure. Neurons are primarily responsible for transmitting electrical impulses, and their shape and structure are optimized for this purpose. The presence of centrioles, which are involved in cell division, would not be beneficial for neurons as they do not undergo cell division once they mature.\n\nThe absence of centrioles in neurons is a specialized adaptation that allows them to maintain their structure and function effectively throughout their lifespan.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2120,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7778,
            "description": "Mitochondria",
            "question_id": 1941,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.869+05:30",
            "updated_at": "2024-07-02T17:11:46.869+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7779,
            "description": "Ribosome",
            "question_id": 1941,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.872+05:30",
            "updated_at": "2024-07-02T17:11:46.872+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7780,
            "description": "Centriole",
            "question_id": 1941,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.875+05:30",
            "updated_at": "2024-07-02T17:11:46.875+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7781,
            "description": "Nucleus",
            "question_id": 1941,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.878+05:30",
            "updated_at": "2024-07-02T17:11:46.878+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1942,
        "description": "Select the incorrect statement about nerve fibres :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.893+05:30",
        "updated_at": "2024-11-30T18:39:42.266+05:30",
        "detailed_solution": "",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2121,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7782,
            "description": "The dendrite carries impulse towards the cyton",
            "question_id": 1942,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.897+05:30",
            "updated_at": "2024-07-02T17:11:46.897+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7783,
            "description": "Neurons and muscle fibres are excitable cells",
            "question_id": 1942,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.901+05:30",
            "updated_at": "2024-07-02T17:11:46.901+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7784,
            "description": "Nissl's granules are absent in axon",
            "question_id": 1942,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.904+05:30",
            "updated_at": "2024-07-02T17:11:46.904+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7785,
            "description": "Myelin sheath is continuous at the Node of Ranvier",
            "question_id": 1942,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.908+05:30",
            "updated_at": "2024-07-02T17:11:46.908+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1943,
        "description": "The nerve cell can be distinguished from other cells of the body by the presence of :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.918+05:30",
        "updated_at": "2024-11-30T18:39:42.472+05:30",
        "detailed_solution": "**Explanation:**\n\nNerve cells, also known as neurons, are the fundamental units of the nervous system. They possess unique characteristics that distinguish them from other cells in the body.\n\n**Axons and Dendrites:**\n\n* **Axons:** These are long, slender extensions that transmit electrical impulses away from the cell body to other neurons or target cells.\n* **Dendrites:** These are short, branched extensions that receive electrical impulses from other neurons.\n\n**Significance:**\n\nAxons and dendrites are essential for the function of neurons in communication and signal transmission. They allow neurons to receive and send electrical signals, enabling the transmission of information throughout the nervous system.\n\n**Additional Context:**\n\n* Nerve cells have a cell body (soma) that contains the nucleus and other organelles.\n* They are excitable cells that can generate and conduct electrical impulses (action potentials).\n* Nerve cells form connections with other neurons through synapses, allowing information to be transmitted across the nervous system.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2122,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7786,
            "description": "Nucleus",
            "question_id": 1943,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.922+05:30",
            "updated_at": "2024-07-02T17:11:46.922+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7787,
            "description": "Plasma membrane",
            "question_id": 1943,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.926+05:30",
            "updated_at": "2024-07-02T17:11:46.926+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7788,
            "description": "Mitochondria",
            "question_id": 1943,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.936+05:30",
            "updated_at": "2024-07-02T17:11:46.936+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7789,
            "description": "Axon & dendrites",
            "question_id": 1943,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.939+05:30",
            "updated_at": "2024-07-02T17:11:46.939+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1944,
        "description": "The functional connection between two neurons is called:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.948+05:30",
        "updated_at": "2024-11-30T18:39:42.674+05:30",
        "detailed_solution": "**Explanation:**\n\n**Synapse:**\n\n* Synapse is the functional connection between two neurons.\n* It is a specialized structure that facilitates the transmission of electrical or chemical signals from one neuron to another.\n* Synapses can be classified into two types:\n    * Electrical synapses: Allow direct electrical connection between neurons.\n    * Chemical synapses: Transmit signals through neurotransmitters.\n\n**Importance of Synapses:**\n\n* Synapses play a crucial role in communication between neurons.\n* They allow for signal amplification and integration, which is essential for complex neural processing.\n* Synapses are highly plastic and can strengthen or weaken over time, a process known as synaptic plasticity.\n* Synaptic plasticity is the basis of learning and memory.\n\n**Additional Context:**\n\n**Structure of Synapse:**\n\n* A synapse consists of a presynaptic neuron, a postsynaptic neuron, and a synaptic cleft.\n* The presynaptic neuron releases neurotransmitters into the synaptic cleft.\n* Neurotransmitters bind to receptors on the postsynaptic neuron, causing a change in its electrical potential.\n\n**Transmission of Signals:**\n\n* In electrical synapses, electrical signals pass directly from the presynaptic to the postsynaptic neuron through gap junctions.\n* In chemical synapses, neurotransmitters are released into the synaptic cleft and bind to receptors on the postsynaptic neuron, triggering a series of chemical reactions that lead to a change in the postsynaptic neuron's electrical potential.\n\n**Significance for NEET Exam:**\n\nUnderstanding the structure and function of synapses is crucial for NEET exam as it forms the basis of neural communication and signal processing in the nervous system. It is also important for understanding the mechanisms of learning and memory.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2123,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7790,
            "description": "Synapse",
            "question_id": 1944,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.953+05:30",
            "updated_at": "2024-07-02T17:11:46.953+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7791,
            "description": "Synapsis",
            "question_id": 1944,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.957+05:30",
            "updated_at": "2024-07-02T17:11:46.957+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7792,
            "description": "Chiasma",
            "question_id": 1944,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.963+05:30",
            "updated_at": "2024-07-02T17:11:46.963+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7793,
            "description": "Chiasmata",
            "question_id": 1944,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.968+05:30",
            "updated_at": "2024-07-02T17:11:46.968+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1945,
        "description": "Which of the following is a non–excitable cell ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.975+05:30",
        "updated_at": "2024-11-30T18:39:42.875+05:30",
        "detailed_solution": "**Explanation:**\n\n**Excitable cells** are cells that can generate and transmit electrical impulses. They have ion channels in their membranes that allow the flow of ions, creating an electrical gradient.\n\n**Astrocytes** are non-excitable cells that do not have ion channels and cannot generate electrical impulses. They are star-shaped cells that play a supporting role in the central nervous system by providing nutrients to neurons and removing waste products.\n\n**Additional context:**\n\n* Other examples of non-excitable cells include red blood cells, muscle cells, and epithelial cells.\n* Astrocytes are the most abundant type of glial cell in the brain.\n* Astrocytes help maintain the blood-brain barrier and regulate the extracellular environment in the brain.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2124,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7794,
            "description": "Neuron",
            "question_id": 1945,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.980+05:30",
            "updated_at": "2024-07-02T17:11:46.980+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7795,
            "description": "Smooth muscle cell",
            "question_id": 1945,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.983+05:30",
            "updated_at": "2024-07-02T17:11:46.983+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7796,
            "description": "Astrocyte",
            "question_id": 1945,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:46.986+05:30",
            "updated_at": "2024-07-02T17:11:46.986+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7797,
            "description": "Skeletal muscle cell",
            "question_id": 1945,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:46.989+05:30",
            "updated_at": "2024-07-02T17:11:46.989+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1946,
        "description": "In non–myelinated nerve fibre of PNS :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:46.998+05:30",
        "updated_at": "2024-11-30T18:39:43.073+05:30",
        "detailed_solution": "In non-myelinated nerve fibers of the peripheral nervous system (PNS), the myelin sheath is absent. Myelin is a fatty insulating layer that covers the axons of some nerve cells, allowing for faster and more efficient transmission of nerve impulses. In non-myelinated nerve fibers, the electrical impulses travel more slowly as the gaps between adjacent cells are not as well insulated, resulting in a slower transmission of impulses.\n\n**Additional context:**\n\n* Myelination is a process that occurs during development and is essential for the proper functioning of the nervous system.\n* Schwann cells in the PNS and oligodendrocytes in the central nervous system (CNS) are responsible for producing the myelin sheath.\n* Myelinated axons are thicker than non-myelinated axons, which can be seen under a microscope.\n* The speed of nerve impulse propagation is directly proportional to the diameter of the axon and the presence of a myelin sheath.\n* Non-myelinated nerve fibers are typically associated with sensory neurons and autonomic neurons, while myelinated nerve fibers are associated with motor neurons and sensory neurons that transmit information from the periphery to the central nervous system.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2125,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7798,
            "description": "Myelin sheath is absent",
            "question_id": 1946,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.003+05:30",
            "updated_at": "2024-07-02T17:11:47.003+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7799,
            "description": "Schwann cell is absent",
            "question_id": 1946,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.006+05:30",
            "updated_at": "2024-07-02T17:11:47.006+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7800,
            "description": "Both (A) & (B) are absent",
            "question_id": 1946,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.010+05:30",
            "updated_at": "2024-07-08T10:28:21.430+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7801,
            "description": "Axon is absent",
            "question_id": 1946,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.013+05:30",
            "updated_at": "2024-07-02T17:11:47.013+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1947,
        "description": "Which of the following cell can't be grown by tissue culture ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.023+05:30",
        "updated_at": "2024-11-30T18:39:43.274+05:30",
        "detailed_solution": "**Explanation:**\n\nTissue culture is a technique used to grow cells from a living organism in a controlled laboratory environment. This technique involves isolating cells from the organism and culturing them in a nutrient-rich medium. While most cells can be grown using tissue culture methods, there are a few exceptions.\n\n**Neurons** are specialized cells that transmit electrical signals throughout the nervous system. These cells are highly differentiated and do not retain the ability to divide and proliferate. Once a neuron dies, it cannot be replaced through cell division. Therefore, neurons cannot be grown by tissue culture methods.\n\n**Additional Context:**\n\n* Tissue culture is a valuable tool for studying cell growth, differentiation, and metabolism.\n* It is used in various applications, including research, medical diagnostics, and biotechnology.\n* Other cells that cannot be grown by tissue culture include red blood cells, skeletal muscle cells, and lens cells.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2126,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7802,
            "description": "Epithelial cell",
            "question_id": 1947,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.028+05:30",
            "updated_at": "2024-07-02T17:11:47.028+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7803,
            "description": "Fibroblast",
            "question_id": 1947,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.032+05:30",
            "updated_at": "2024-07-02T17:11:47.032+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7804,
            "description": "Monocyte",
            "question_id": 1947,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.035+05:30",
            "updated_at": "2024-07-02T17:11:47.035+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7805,
            "description": "Neuron",
            "question_id": 1947,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.042+05:30",
            "updated_at": "2024-07-02T17:11:47.042+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1948,
        "description": "Which one of the following types of cell is involved in making of the inner walls of blood vessels?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.056+05:30",
        "updated_at": "2024-11-30T18:39:43.479+05:30",
        "detailed_solution": "**Explanation**\n\nThe inner walls of blood vessels are lined by **squamous epithelium**. Squamous epithelium is a type of epithelial tissue that is composed of thin, flattened cells. These cells are tightly packed together to form a protective barrier that prevents the passage of harmful substances into the bloodstream.\n\n**Additional Context**\n\nEpithelial tissue is a type of tissue that lines the surfaces of the body and its internal organs. It is composed of tightly packed cells that form a protective barrier between the body and the external environment. There are three main types of epithelial tissue: squamous epithelium, cuboidal epithelium, and columnar epithelium.\n\n* **Squamous epithelium** is composed of thin, flattened cells. It lines the inner walls of blood vessels, lymphatic vessels, and alveoli in the lungs.\n* **Cuboidal epithelium** is composed of cube-shaped cells. It lines the ducts of glands, the collecting tubules in the kidneys, and the walls of small intestines.\n* **Columnar epithelium** is composed of tall, column-shaped cells. It lines the digestive tract, the respiratory tract, and the urinary tract.\n\n**Conclusion**\n\nThe inner walls of blood vessels are lined by squamous epithelium because this type of cell is thin and flattened, which allows it to form a tight seal that prevents the passage of harmful substances into the bloodstream.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2127,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7806,
            "description": "Cuboidal epithelium",
            "question_id": 1948,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.060+05:30",
            "updated_at": "2024-07-02T17:11:47.060+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7807,
            "description": "Columnar epithelium",
            "question_id": 1948,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.064+05:30",
            "updated_at": "2024-07-02T17:11:47.064+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7808,
            "description": "Squamous epithelium",
            "question_id": 1948,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.069+05:30",
            "updated_at": "2024-07-02T17:11:47.069+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7809,
            "description": "Stratified epithelium",
            "question_id": 1948,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.073+05:30",
            "updated_at": "2024-07-02T17:11:47.073+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1949,
        "description": "To which one of the following categories does adipose tissue belong?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.084+05:30",
        "updated_at": "2024-11-30T18:39:43.683+05:30",
        "detailed_solution": "**Explanation:**\n\nAdipose tissue is a type of connective tissue that is composed of fat cells (adipocytes). It is found throughout the body and serves as a storage depot for energy in the form of triglycerides.\n\nConnective tissues are a group of tissues that provide structural support and protection to other tissues and organs. They are characterized by the presence of specialized cells surrounded by a matrix of extracellular material.\n\n**Additional Context:**\n\n* Other types of connective tissue include bone, cartilage, and blood.\n* Adipose tissue is classified as loose connective tissue because its cells are loosely arranged in a matrix of extracellular material.\n\n**Conclusion:**\n\nAdipose tissue is classified as connective tissue because it meets the criteria for this group of tissues: it provides structural support and protection, and it is composed of specialized cells surrounded by a matrix of extracellular material.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2128,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7810,
            "description": "Epithelial",
            "question_id": 1949,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.098+05:30",
            "updated_at": "2024-07-02T17:11:47.098+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7811,
            "description": "Connective",
            "question_id": 1949,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.101+05:30",
            "updated_at": "2024-07-02T17:11:47.101+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7812,
            "description": "Muscular",
            "question_id": 1949,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.103+05:30",
            "updated_at": "2024-07-02T17:11:47.103+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7813,
            "description": "Neural",
            "question_id": 1949,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.107+05:30",
            "updated_at": "2024-07-02T17:11:47.107+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1950,
        "description": "Which one of the following is not a connective tissue?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.114+05:30",
        "updated_at": "2024-11-30T18:39:43.878+05:30",
        "detailed_solution": "**Connective tissue** is a type of tissue that connects, supports, binds, or separates other tissues or organs. It provides structural support and protection for the body and its organs.\n\n**Muscles** are not connective tissue. Muscles are a type of tissue that contracts and relaxes to produce movement. They are composed of muscle fibers, which are long, thin cells that contain the contractile proteins actin and myosin. Muscle tissue is found in the muscles of the body, such as the skeletal muscles, smooth muscles, and cardiac muscles.\n\nTherefore, the correct answer is **Muscles**.\n\n**Additional context:**\n\nThe four main types of connective tissue are:\n\n1. **Loose connective tissue:** This type of connective tissue is found in the spaces between organs and muscles. It is composed of cells, fibers, and a ground substance.\n2. **Dense connective tissue:** This type of connective tissue is found in the tendons, ligaments, and fascia. It is composed of cells, fibers, and a ground substance that is denser than that of loose connective tissue.\n3. **Cartilage:** This type of connective tissue is found in the joints, ears, and nose. It is composed of cells, fibers, and a ground substance that is firm and flexible.\n4. **Bone:** This type of connective tissue is found in the skeleton. It is composed of cells, fibers, and a ground substance that is hard and mineralized.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2129,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7814,
            "description": "Bone",
            "question_id": 1950,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.118+05:30",
            "updated_at": "2024-07-02T17:11:47.118+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7815,
            "description": "Cartilage",
            "question_id": 1950,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.125+05:30",
            "updated_at": "2024-07-02T17:11:47.125+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7816,
            "description": "Blood",
            "question_id": 1950,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.128+05:30",
            "updated_at": "2024-07-02T17:11:47.128+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7817,
            "description": "Muscles",
            "question_id": 1950,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.133+05:30",
            "updated_at": "2024-07-02T17:11:47.133+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1951,
        "description": "Match the following and choose the correct option\n  Column I     Column II\n A. Adipose tissue   i. Nose\n B. Stratified epithelium   ii. Blood\n C. Hyaline cartilage   iii. Skin\n D. Fluid connective tissue  iv. Fat storage\n Options:",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.144+05:30",
        "updated_at": "2024-11-30T18:39:44.088+05:30",
        "detailed_solution": "**Correct answer: A-iv, B-iii, C-i, D-ii**\n\n**Explanation:**\n\n* **Adipose tissue (A) - Fat storage (iv):** Adipose tissue is a type of connective tissue that stores fat. It is found in various parts of the body, including beneath the skin and around organs.\n* **Stratified epithelium (B) - Skin (iii):** Stratified epithelium is a type of epithelium that consists of multiple layers of cells. The skin is the largest organ of the body and is covered by a layer of stratified epithelium.\n* **Hyaline cartilage (C) - Nose (i):** Hyaline cartilage is a type of cartilage that is smooth and transparent. It is found in various parts of the body, including the nose, where it provides support and shape.\n* **Fluid connective tissue (D) - Blood (ii):** Fluid connective tissue is a type of connective tissue that has a fluid matrix. Blood is a type of fluid connective tissue that transports materials throughout the body.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2130,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7818,
            "description": "A-i, B-ii, C-iii, D-iv",
            "question_id": 1951,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.149+05:30",
            "updated_at": "2024-07-02T17:11:47.149+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7819,
            "description": "A-iv, B-iii, C-i, D-ii",
            "question_id": 1951,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.152+05:30",
            "updated_at": "2024-07-02T17:11:47.152+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7820,
            "description": "A-iii, B-i, C-iv, D-ii",
            "question_id": 1951,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.154+05:30",
            "updated_at": "2024-07-02T17:11:47.154+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7821,
            "description": "A-ii, B-i, C-iv, D-iii",
            "question_id": 1951,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.157+05:30",
            "updated_at": "2024-07-02T17:11:47.157+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1952,
        "description": "A muscle fibre tapers at ends and does not show striations is :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.166+05:30",
        "updated_at": "2024-11-30T18:39:44.294+05:30",
        "detailed_solution": "**Explanation:**\n\nMuscle fibres are long, cylindrical cells that make up muscles. They are responsible for the contraction and relaxation of muscles, which allows for movement.\n\nThere are three types of muscle fibres: skeletal muscle fibres, cardiac muscle fibres, and smooth muscle fibres.\n\n* **Skeletal muscle fibres** are attached to bones and are responsible for voluntary movements, such as walking, running, and jumping. They are long, cylindrical cells with striations (bands) that are visible under a microscope.\n* **Cardiac muscle fibres** are found in the heart and are responsible for the pumping action of the heart. They are also long, cylindrical cells with striations, but they are shorter and thicker than skeletal muscle fibres.\n* **Smooth muscle fibres** are found in the walls of hollow organs, such as the stomach, intestines, and blood vessels. They are not attached to bones and are responsible for involuntary movements, such as digestion and blood flow. They are shorter and thinner than skeletal muscle fibres and do not have striations.\n\n**Therefore, the muscle fibre that tapers at ends and does not show striations is a smooth muscle fibre.**\n\n**Additional context:**\n\nMuscle fibres are composed of myofibrils, which are bundles of myofilaments. Myofilaments are made up of two proteins: actin and myosin. When a muscle fibre contracts, the myosin filaments slide over the actin filaments, causing the muscle to shorten.\n\nThe striations in skeletal and cardiac muscle fibres are caused by the arrangement of the actin and myosin filaments. In skeletal muscle fibres, the actin and myosin filaments are arranged in a regular pattern, which creates the striated appearance. In cardiac muscle fibres, the actin and myosin filaments are arranged in a less regular pattern, which creates a less distinct striated appearance.\n\nSmooth muscle fibres do not have striations because the actin and myosin filaments are not arranged in a regular pattern.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2131,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7822,
            "description": "Smooth muscle fibre",
            "question_id": 1952,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.169+05:30",
            "updated_at": "2024-07-02T17:11:47.169+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7823,
            "description": "Skeletal muscle fibre",
            "question_id": 1952,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.178+05:30",
            "updated_at": "2024-07-02T17:11:47.178+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7824,
            "description": "Cardiac muscle fibre",
            "question_id": 1952,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.181+05:30",
            "updated_at": "2024-07-02T17:11:47.181+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7825,
            "description": "Striated muscle fibre",
            "question_id": 1952,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.183+05:30",
            "updated_at": "2024-07-02T17:11:47.183+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1953,
        "description": "Structural organisation in animals attains different levels as cell–organ–organ system. What is missing in this chain ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.191+05:30",
        "updated_at": "2024-11-30T18:39:44.494+05:30",
        "detailed_solution": "The correct answer is **Tissue**.\n\nThe structural organization in animals attains different levels as cell–tissue–organ–organ system.\n\n* **Cell** is the basic unit of life.\n* **Tissue** is a group of similar cells that perform a specific function.\n* **Organ** is a group of tissues that perform a specific function.\n* **Organ system** is a group of organs that work together to perform a specific function.\n\nTherefore, the missing link in the chain is **tissue**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2132,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7826,
            "description": "Molecule",
            "question_id": 1953,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.197+05:30",
            "updated_at": "2024-07-02T17:11:47.197+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7827,
            "description": "Tissue",
            "question_id": 1953,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.200+05:30",
            "updated_at": "2024-07-02T17:11:47.200+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7828,
            "description": "Atom",
            "question_id": 1953,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.203+05:30",
            "updated_at": "2024-07-02T17:11:47.203+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7829,
            "description": "Organism",
            "question_id": 1953,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.208+05:30",
            "updated_at": "2024-07-02T17:11:47.208+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1954,
        "description": "Which is not a common property of a muscle fibre and a nerve fibre ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.219+05:30",
        "updated_at": "2024-11-30T18:39:44.699+05:30",
        "detailed_solution": "**Contractility** is a common property of muscle fibres and nerve fibres. \n\nMuscle fibres are specialized cells that are responsible for producing movement. They contain contractile proteins that allow them to shorten and lengthen, which is how muscles are able to contract and relax. Nerve fibres are specialized cells that transmit electrical signals throughout the body. They do not contain contractile proteins and are not able to contract or relax.\n\nTherefore, the correct answer is **contractility**",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2133,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7830,
            "description": "Excitability",
            "question_id": 1954,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.222+05:30",
            "updated_at": "2024-07-02T17:11:47.222+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7831,
            "description": "Conductivity",
            "question_id": 1954,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.225+05:30",
            "updated_at": "2024-07-02T17:11:47.225+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7832,
            "description": "Both (1) & (2)",
            "question_id": 1954,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.229+05:30",
            "updated_at": "2024-07-02T17:11:47.229+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7833,
            "description": "Contracitility",
            "question_id": 1954,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.231+05:30",
            "updated_at": "2024-07-02T17:11:47.231+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1955,
        "description": "Mark the odd one :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.237+05:30",
        "updated_at": "2024-11-30T18:39:44.900+05:30",
        "detailed_solution": "**Explanation:**\n\nThe odd one out is \"Neuron.\"\n\nThe other options (Epithelium, Gland, Muscle tissue) are all types of tissues, while a neuron is a type of cell. Neurons are the functional units of the nervous system and are responsible for transmitting information throughout the body.\n\n**Additional Context:**\n\n**Tissues** are groups of similar cells that perform a specific function. There are four main types of tissues in the body:\n\n* Epithelial tissue: Covers the body's surfaces and lines its cavities.\n* Glandular tissue: Secretes substances (e.g., hormones, enzymes).\n* Muscle tissue: Contracts to produce movement.\n* Nervous tissue: Transmits information throughout the body.\n\n**Cells** are the basic units of life and are classified into two main types:\n\n* Prokaryotic cells: Do not have a nucleus or other membrane-bound organelles.\n* Eukaryotic cells: Have a nucleus and other membrane-bound organelles.\n\nNeurons are eukaryotic cells that are specialized for transmitting information. They have a cell body, dendrites (which receive information), and an axon (which sends information).",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2134,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7834,
            "description": "Areolar tissue",
            "question_id": 1955,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.250+05:30",
            "updated_at": "2024-07-02T17:11:47.250+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7835,
            "description": "Blood",
            "question_id": 1955,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.252+05:30",
            "updated_at": "2024-07-02T17:11:47.252+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7836,
            "description": "Neuron",
            "question_id": 1955,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.254+05:30",
            "updated_at": "2024-07-02T17:11:47.254+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7837,
            "description": "Tendon",
            "question_id": 1955,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.257+05:30",
            "updated_at": "2024-07-02T17:11:47.257+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1956,
        "description": "Mark the odd one :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.263+05:30",
        "updated_at": "2024-11-30T18:39:45.125+05:30",
        "detailed_solution": "**Explanation:**\n\nCartilage is a type of connective tissue that is found in various parts of the body, including the joints, ears, and nose. Unlike the other options (epithelium, muscle, and nervous tissue), cartilage is not composed of cells that are tightly packed together. Instead, cartilage cells (chondrocytes) are surrounded by a gel-like substance called the matrix. The matrix is composed of collagen fibers, which provide cartilage with its strength and flexibility.\n\nEpithelium, muscle, and nervous tissue are all composed of cells that are tightly packed together. Epithelium is a covering tissue that lines the surfaces of the body, such as the skin and the lining of the digestive tract. Muscle tissue is responsible for movement, and nervous tissue is responsible for transmitting signals throughout the body.\n\nTherefore, cartilage is the odd one out because it is the only option that is not composed of cells that are tightly packed together.\n\n**Additional Context:**\n\n* Cartilage is classified into three types: hyaline cartilage, fibrocartilage, and elastic cartilage.\n* Hyaline cartilage is the most common type of cartilage. It is found in the joints, the nose, and the trachea.\n* Fibrocartilage is found in the intervertebral discs and the menisci of the knee.\n* Elastic cartilage is found in the ears and the epiglottis.\n* Cartilage is an important type of connective tissue that provides support and protection for various parts of the body.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2135,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7838,
            "description": "RBC",
            "question_id": 1956,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.268+05:30",
            "updated_at": "2024-07-02T17:11:47.268+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7839,
            "description": "WBC",
            "question_id": 1956,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.272+05:30",
            "updated_at": "2024-07-02T17:11:47.272+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7840,
            "description": "Platelets",
            "question_id": 1956,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.274+05:30",
            "updated_at": "2024-07-02T17:11:47.274+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7841,
            "description": "Cartilage",
            "question_id": 1956,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.277+05:30",
            "updated_at": "2024-07-02T17:11:47.277+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1957,
        "description": "Mark the odd one :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.283+05:30",
        "updated_at": "2024-11-30T18:39:45.334+05:30",
        "detailed_solution": "**Answer: Ligament**\n\n**Reason:**\nLigaments are connective tissues that connect bones to other bones. They are made of collagen and elastin fibers and are therefore flexible but strong. Tendons, on the other hand, are connective tissues that connect muscles to bones. They are made of collagen fibers and are therefore strong and inflexible. Fascia is a layer of connective tissue that surrounds muscles, tendons, and ligaments. It helps to hold these structures in place and provides support. Cartilage is a type of connective tissue that is found in the joints and between the vertebrae. It is made of chondrocytes and collagen fibers and is therefore flexible and shock-absorbing.\n\nTherefore, ligament is the odd one out because it is not a type of connective tissue that connects muscles to bones.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2136,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7842,
            "description": "Exocrine",
            "question_id": 1957,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.286+05:30",
            "updated_at": "2024-07-02T17:11:47.286+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7843,
            "description": "Endocrine",
            "question_id": 1957,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.288+05:30",
            "updated_at": "2024-07-02T17:11:47.288+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7844,
            "description": "Salivary gland",
            "question_id": 1957,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.290+05:30",
            "updated_at": "2024-07-02T17:11:47.290+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7845,
            "description": "Ligament",
            "question_id": 1957,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.293+05:30",
            "updated_at": "2024-07-02T17:11:47.293+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1958,
        "description": "Mark the incorrect match :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.307+05:30",
        "updated_at": "2024-11-30T18:39:45.533+05:30",
        "detailed_solution": "**Correct Answer:** Fibroblasts – Blood\n\n**Explanation:**\n- Fibroblasts are cells that secrete the protein collagen and are found in connective tissue.\n- Blood is a fluid connective tissue that contains red blood cells, white blood cells, platelets, and plasma.\n\nTherefore, the match between fibroblasts and blood is incorrect.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2137,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7846,
            "description": "Compound epithelium  – Skin",
            "question_id": 1958,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.311+05:30",
            "updated_at": "2024-07-08T10:31:48.778+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7847,
            "description": "Osteocytes –  Bone",
            "question_id": 1958,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.316+05:30",
            "updated_at": "2024-07-08T10:31:48.781+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7848,
            "description": "Fibroblasts   –  Blood",
            "question_id": 1958,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.329+05:30",
            "updated_at": "2024-07-08T10:31:48.783+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7849,
            "description": "Chondrocytes –  Cartilage",
            "question_id": 1958,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.334+05:30",
            "updated_at": "2024-07-08T10:31:48.785+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1959,
        "description": "Many years old 'mummies' still have their arteries intact due to well preserved :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.341+05:30",
        "updated_at": "2024-11-30T18:39:45.726+05:30",
        "detailed_solution": "**Explanation:**\n\nMummies are preserved bodies that have been embalmed to prevent decomposition. Over time, most of the body's tissues break down, including the blood vessels. However, the arteries of many mummies remain intact due to the presence of well preserved elastic fibres.\n\nElastic fibres are a type of connective tissue that is highly flexible and elastic. They are found in the walls of arteries and help to prevent them from collapsing when blood pressure drops. In mummies, the elastic fibres have been preserved due to the embalming process, which involved the use of chemicals that prevent the breakdown of tissues. As a result, the arteries of mummies remain intact even though the rest of the body has decomposed.\n\n**Additional context:**\n\n* Elastic fibres are also found in the skin, lungs, and other organs that need to be able to stretch and recoil.\n* The embalming process used on mummies typically involved the removal of the internal organs and the injection of preservatives into the body.\n* Mummies have been found in many different cultures around the world, including the ancient Egyptians, Chinese, and Incas.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2138,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7850,
            "description": "Collagen fibres",
            "question_id": 1959,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.344+05:30",
            "updated_at": "2024-07-02T17:11:47.344+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7851,
            "description": "Elastic fibres",
            "question_id": 1959,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.347+05:30",
            "updated_at": "2024-07-02T17:11:47.347+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7852,
            "description": "Reticulin fibres",
            "question_id": 1959,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.350+05:30",
            "updated_at": "2024-07-02T17:11:47.350+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7853,
            "description": "Tunica intima",
            "question_id": 1959,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.353+05:30",
            "updated_at": "2024-07-02T17:11:47.353+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1960,
        "description": "Bone is a solid, rigid connective tissue. If the bone is put into KOH, then the bone will :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.370+05:30",
        "updated_at": "2024-11-30T18:39:45.927+05:30",
        "detailed_solution": "Bone is a solid and rigid connective tissue that provides support and protection to the body. It is composed of a protein matrix called collagen and a mineral component called hydroxyapatite. When a bone is put into KOH (potassium hydroxide), the KOH will dissolve the mineral component of the bone, but it will not affect the collagen matrix. This will cause the bone to become more flexible and less rigid, but it will not dissolve completely.\n\n**Therefore, the answer to the question is that the bone will remain unchanged.**\n\n**Additional context:**\n\n* Bone is a type of connective tissue that is found in the body of vertebrates.\n* Connective tissue is a type of tissue that connects and supports other tissues in the body.\n* Bone is composed of a protein matrix called collagen and a mineral component called hydroxyapatite.\n* Collagen is a strong, fibrous protein that gives bone its flexibility and strength.\n* Hydroxyapatite is a mineral that gives bone its hardness and rigidity.\n* Bone is a living tissue that is constantly being remodeled.\n* Osteoblasts are cells that build new bone.\n* Osteoclasts are cells that break down old bone.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2139,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7854,
            "description": "Become decalcified",
            "question_id": 1960,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.375+05:30",
            "updated_at": "2024-07-02T17:11:47.375+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7855,
            "description": "Become soft",
            "question_id": 1960,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.377+05:30",
            "updated_at": "2024-07-02T17:11:47.377+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7856,
            "description": "Become flexible",
            "question_id": 1960,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.380+05:30",
            "updated_at": "2024-07-02T17:11:47.380+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7857,
            "description": "Remain unchanged",
            "question_id": 1960,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.382+05:30",
            "updated_at": "2024-07-02T17:11:47.382+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1961,
        "description": "Neurons which connect the central nervous system to the receptors are :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.389+05:30",
        "updated_at": "2024-11-30T18:39:46.127+05:30",
        "detailed_solution": "**Explanation:**\n\nSensory neurons are specialized nerve cells that receive stimuli from the external environment and transmit them to the central nervous system (CNS). They are also known as afferent neurons.\n\n* **Receptors:** Sensory neurons are connected to receptors, which are structures that detect specific stimuli. Receptors can be located in the skin, eyes, ears, nose, tongue, and internal organs.\n* **Stimuli:** Receptors respond to various types of stimuli, including touch, temperature, pain, light, sound, and chemical signals.\n* **Signal transduction:** When a receptor detects a stimulus, it triggers a series of molecular events that result in the generation of an electrical signal.\n* **Sensory neurons:** The electrical signal is then transmitted along the sensory neuron's axon to the CNS.\n\nThe CNS, which includes the brain and spinal cord, processes the sensory information and generates appropriate responses.\n\n**Additional context:**\n\n* The sensory nervous system is a division of the peripheral nervous system that transmits sensory information from the body to the CNS.\n* Sensory neurons are classified into various types based on the type of stimulus they detect. For example, mechanoreceptors detect touch and pressure, thermoreceptors detect temperature, photoreceptors detect light, and chemoreceptors detect chemicals.\n* Sensory neurons are essential for our perception of the external world. They allow us to experience touch, temperature, pain, and other sensations that help us navigate our environment.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2140,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7858,
            "description": "Sensory neurons",
            "question_id": 1961,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.394+05:30",
            "updated_at": "2024-07-02T17:11:47.394+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7859,
            "description": "Motor neurons",
            "question_id": 1961,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.397+05:30",
            "updated_at": "2024-07-02T17:11:47.397+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7860,
            "description": "Interneurons",
            "question_id": 1961,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.400+05:30",
            "updated_at": "2024-07-02T17:11:47.400+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7861,
            "description": "Both (B) & (C)",
            "question_id": 1961,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.403+05:30",
            "updated_at": "2024-07-08T10:26:48.300+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1962,
        "description": "Which type of neuron dominates in the CNS ?",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.411+05:30",
        "updated_at": "2024-11-30T18:39:46.333+05:30",
        "detailed_solution": "**Explanation:**\n\nThe central nervous system (CNS) consists of the brain and spinal cord. It is made up of two main types of neurons:\n\n* **Interneurons:** These neurons connect neurons within the CNS, allowing for communication and integration of information. They are the most abundant type of neuron in the CNS.\n* **Motor neurons:** These neurons transmit signals from the CNS to muscles, organs, and glands.\n\nIn the CNS, interneurons play a crucial role in processing and transmitting information within the brain and spinal cord. They form complex neural circuits that allow for higher-order functions such as perception, cognition, and movement.\n\nTherefore, the answer to the question is **Interneurons**.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2141,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7862,
            "description": "Sensory",
            "question_id": 1962,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.415+05:30",
            "updated_at": "2024-07-02T17:11:47.415+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7863,
            "description": "Motor",
            "question_id": 1962,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.418+05:30",
            "updated_at": "2024-07-02T17:11:47.418+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7864,
            "description": "Efferent",
            "question_id": 1962,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.421+05:30",
            "updated_at": "2024-07-02T17:11:47.421+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7865,
            "description": "Interneurons",
            "question_id": 1962,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.424+05:30",
            "updated_at": "2024-07-02T17:11:47.424+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1963,
        "description": "Mark the connective tissue which is without fibres and matrix is not secreted by its cellular component :",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.432+05:30",
        "updated_at": "2024-11-30T18:39:46.537+05:30",
        "detailed_solution": "**Explanation:**\n\nConnective tissues are a group of tissues that connect and support other tissues and organs in the body. They consist of cells, fibres, and a matrix. The matrix is a non-living substance that is secreted by the cells of the connective tissue.\n\nBlood is a type of connective tissue that is made up of red blood cells, white blood cells, platelets, and plasma. Plasma is the liquid part of blood and it does not contain any fibres or matrix. The cells of the blood do not secrete any matrix. Therefore, blood is a type of connective tissue that is without fibres and matrix is not secreted by its cellular component.\n\n**Additional context:**\n\nConnective tissues are classified into three main types based on the type of fibres present in them:\n\n* **Loose connective tissue** contains loosely arranged fibres and a large amount of matrix. Examples include areolar tissue and adipose tissue.\n* **Dense connective tissue** contains tightly packed fibres and a small amount of matrix. Examples include tendons and ligaments.\n* **Cartilage** contains specialized cells called chondrocytes that are embedded in a matrix made of collagen and proteoglycans. Examples include cartilage of the nose and ears.\n* **Bone** contains specialized cells called osteocytes that are embedded in a matrix made of collagen and calcium salts. Examples include the bones of the skeleton.\n* **Blood** is a type of connective tissue that does not contain any fibres or matrix. It is made up of cells suspended in a liquid called plasma.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2142,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7866,
            "description": "Areolar tissue",
            "question_id": 1963,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.436+05:30",
            "updated_at": "2024-07-02T17:11:47.436+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7867,
            "description": "Adipose tissue",
            "question_id": 1963,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.439+05:30",
            "updated_at": "2024-07-02T17:11:47.439+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7868,
            "description": "Blood",
            "question_id": 1963,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.441+05:30",
            "updated_at": "2024-07-02T17:11:47.441+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7869,
            "description": "Cartilage",
            "question_id": 1963,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.444+05:30",
            "updated_at": "2024-07-02T17:11:47.444+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      },
      {
        "id": 1964,
        "description": "The percentage of inorganic and organic parts in the matrix of a bone is",
        "difficulty_level": "",
        "topic": "structural organisation in animals ",
        "is_published": True,
        "created_at": "2024-07-02T17:11:47.452+05:30",
        "updated_at": "2024-11-30T18:39:46.736+05:30",
        "detailed_solution": "**Explanation:**\n\nThe matrix of a bone is composed of both inorganic and organic components. The inorganic component, which makes up about 70% of the matrix, is primarily composed of hydroxyapatite crystals. These crystals give bone its strength and hardness. The organic component, which makes up about 30% of the matrix, is composed of collagen fibers. These fibers provide bone with its flexibility and tensile strength.\n\n**Additional Context:**\n\n* Hydroxyapatite crystals are arranged in a lattice structure that gives bone its characteristic strength and hardness.\n* Collagen fibers are arranged in a network that gives bone its flexibility and tensile strength.\n* The ratio of inorganic to organic components in bone varies depending on the age and health of the individual.\n* Bone is constantly being remodeled, with new bone being laid down and old bone being resorbed. This process helps to maintain the strength and integrity of bone.",
        "type": "",
        "is_mandatory": False,
        "show_in_feed": False,
        "pyq_label": "",
        "topic_id": 146,
        "reading_material_id": 2143,
        "fixed_at": "",
        "fix_summary": "",
        "created_by": "",
        "updated_by": "",
        "quiz_level": "",
        "question_from": "Q-bank",
        "language": "",
        "photo_url": "",
        "photo_solution_url": "",
        "is_saved": False,
        "tag": "",
        "options": [
          {
            "id": 7870,
            "description": "40% inorganic, 60% organic",
            "question_id": 1964,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.455+05:30",
            "updated_at": "2024-07-02T17:11:47.455+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7871,
            "description": "62% inorganic, 38% organic",
            "question_id": 1964,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.461+05:30",
            "updated_at": "2024-07-02T17:11:47.461+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7872,
            "description": "70% inorganic, 30% organic",
            "question_id": 1964,
            "is_correct": True,
            "created_at": "2024-07-02T17:11:47.465+05:30",
            "updated_at": "2024-07-02T17:11:47.465+05:30",
            "unanswered": False,
            "photo_url": ""
          },
          {
            "id": 7873,
            "description": "85% inorganic, 15% organic",
            "question_id": 1964,
            "is_correct": False,
            "created_at": "2024-07-02T17:11:47.467+05:30",
            "updated_at": "2024-07-02T17:11:47.467+05:30",
            "unanswered": False,
            "photo_url": ""
          }
        ]
      }
    ]
  }
}

# %%
# @title QUIZ SUBMISSION DATA
submission_detiails = {
  "id": 336566,
  "quiz_id": 43,
  "user_id": "7ZXdz3zHuNcdg9agb5YpaOGLQqw2",
  "submitted_at": "2025-01-17T15:51:29.859+05:30",
  "created_at": "2025-01-17T15:51:29.871+05:30",
  "updated_at": "2025-01-17T15:51:29.871+05:30",
  "score": 32,
  "trophy_level": 2,
  "accuracy": "80 %",
  "speed": "100",
  "final_score": "30.0",
  "negative_score": "2.0",
  "correct_answers": 8,
  "incorrect_answers": 2,
  "source": "live",
  "type": "topic",
  "started_at": "2025-01-17T16:20:44.000+05:30",
  "ended_at": "2025-01-17T16:21:28.000+05:30",
  "duration": "15:00",
  "better_than": 24,
  "total_questions": 128,
  "rank_text": "Topic Rank - #2402",
  "mistakes_corrected": 6,
  "initial_mistake_count": 8,
  "response_map": {
    "1837": 7363,
    "1848": 7407,
    "1852": 7423,
    "1862": 7464,
    "1877": 7525,
    "1878": 7529,
    "1900": 7617,
    "1917": 7685,
    "1934": 7750,
    "1964": 7872
  },
  "quiz": {
    "id": 43,
    "name": "",
    "title": "Structural Organisation in Animals and Plants (7)",
    "description": "",
    "difficulty_level": "",
    "topic": "Structural Organisation in Animals",
    "time": "2024-07-03T00:00:00.000+05:30",
    "is_published": True,
    "created_at": "2024-07-03T11:00:08.958+05:30",
    "updated_at": "2024-09-23T18:43:27.751+05:30",
    "duration": 128,
    "end_time": "2024-07-04T00:00:00.000+05:30",
    "negative_marks": "1.0",
    "correct_answer_marks": "4.0",
    "shuffle": True,
    "show_answers": True,
    "lock_solutions": False,
    "is_form": False,
    "show_mastery_option": False,
    "reading_material": "",
    "quiz_type": "",
    "is_custom": False,
    "banner_id": "",
    "exam_id": "",
    "show_unanswered": False,
    "ends_at": "2025-01-18",
    "lives": "",
    "live_count": "Free Test",
    "coin_count": -1,
    "questions_count": 128,
    "daily_date": "January 17, 2025",
    "max_mistake_count": 15,
    "reading_materials": []
  },
  "next_steps": [
    {
      "pageType": "resultPage"
    }
  ]
}

# %%
import pandas as pd

# %%
response_map = submission_detiails["response_map"]

questions_list = quiz_data["quiz"].get("questions")

relevant_cols = ["id" , "topic_id", "reading_material_id"]

pr_rows = []

for question in questions_list:
  question_id = str(question.get("id"))
  if question_id in response_map:
    relevant_data = {key: question[key] for key in relevant_cols}

    options = question.get("options")
    correct_ans = ""
    for option in options:
      option_id = str(option.get("id"))
      if option["is_correct"] == True:
        correct_ans = option_id

    answer_data = {
        "correct_ans" : correct_ans ,
        "marked_ans" : response_map[question_id]
    }

    relevant_data.update(answer_data)

    pr_rows.append(relevant_data)

curr_quiz_df = pd.DataFrame(pr_rows)

# %%
curr_quiz_df["is_correct"] = curr_quiz_df.apply(lambda row: str(row["correct_ans"]) == str(row["marked_ans"]) , axis=1)

# %%
curr_quiz_df.head(20)
# Out:
#      id  topic_id  reading_material_id correct_ans  marked_ans  is_correct
# 0  1837       146                 2026        7363        7363        True
# 1  1848       146                 2037        7407        7407        True
# 2  1852       146                 2041        7423        7423        True
# 3  1862       146                 2051        7462        7464       False
# 4  1877       146                 2066        7525        7525        True
# 5  1878       146                 2067        7526        7529       False
# 6  1900       146                 2079        7617        7617        True
# 7  1917       146                 2096        7685        7685        True
# 8  1934       146                 2113        7750        7750        True
# 9  1964       146                 2143        7872        7872        True

# %%
reading_ids = curr_quiz_df.loc[curr_quiz_df['is_correct'] == False, 'reading_material_id'].tolist()
print("Follow the readting material :" ,reading_ids)
# Out:
# Follow the readting material : [2051, 2067]

# %% [markdown]
# # PERSONA OF THE STUDENT

# %%
persona_df = df [["duration", "quiz_duration" , "mistakes_corrected" , "initial_mistake_count" , "difficulty_level"]]
persona_df.head()
# Out:
#    duration  quiz_duration  mistakes_corrected  initial_mistake_count  \
# 0      11.0            100                   9                     12
# 1       9.0             23                   3                      3
# 2      12.0            100                  11                     12
# 3       7.0             23                   1                      2
# 4      13.0            100                   0                     20
#
#   difficulty_level
# 0           medium
# 1           medium
# 2           medium
# 3           medium
# 4           medium

# %% [markdown]
# RULE BASED PERSONA MAPPING

# %%
persona_df.loc[:, "efficiency"] = (persona_df["duration"] / persona_df["quiz_duration"]) * 100
persona_df.loc[:, "correction_ratio"] = (persona_df["mistakes_corrected"] / persona_df["initial_mistake_count"]) * 100

# Define a function to determine persona
def determine_persona(row):
    if row["efficiency"] < 50 and row["correction_ratio"] > 75:
        return "Efficient Problem Solver"
    elif row["efficiency"] > 90 and row["correction_ratio"] < 50:
        return "Overconfident or Careless"
    elif 50 <= row["efficiency"] <= 90 and row["correction_ratio"] > 75:
        return "Methodical Learner"
    elif row["efficiency"] < 50 and row["correction_ratio"] < 50:
        return "Struggles with Focus"
    else:
        return "Balanced Performer"

persona_df.loc[: ,"persona"] = persona_df.apply(determine_persona, axis=1)

overall_persona = persona_df["persona"].value_counts().idxmax()


print(f"Overall Persona of the Student: {overall_persona}")
# Out:
# Overall Persona of the Student: Struggles with Focus

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

label_encoder = LabelEncoder()
persona_df.loc[:,"difficulty_level_encoded"] = label_encoder.fit_transform(persona_df["difficulty_level"])

features = persona_df[["efficiency", "correction_ratio", "difficulty_level_encoded"]]

persona_df.loc[:,'correction_ratio'] = persona_df['correction_ratio'].fillna(100)
# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
persona_df.loc[:,"cluster"] = kmeans.fit_predict(scaled_features)

dominant_cluster = persona_df['cluster'].value_counts().idxmax()

print(f"The dominant cluster for the student is: Cluster {dominant_cluster}")
# Out:
# The dominant cluster for the student is: Cluster 2

# %%
# Summarize clusters
cluster_summary = persona_df.groupby("cluster").agg({
    "efficiency": ["mean", "min", "max"],
    "correction_ratio": ["mean", "min", "max"],
    "difficulty_level_encoded": ["mean"],
    "duration": ["mean"]
}).reset_index()

cluster_summary.columns = ['Cluster', 'Efficiency Mean', 'Efficiency Min', 'Efficiency Max',
                           'Correction Ratio Mean', 'Correction Ratio Min', 'Correction Ratio Max',
                           'Avg Difficulty Level', 'Avg Duration']

cluster_summary.head()
# Out:
#    Cluster  Efficiency Mean  Efficiency Min  Efficiency Max  \
# 0        0        18.773512        4.545455       36.585366
# 1        1        22.078462        5.000000       56.521739
# 2        2        31.513043       11.000000       65.000000
#
#    Correction Ratio Mean  Correction Ratio Min  Correction Ratio Max  \
# 0              46.428571                   0.0                 100.0
# 1               0.000000                   0.0                   0.0
# 2              83.333333                  50.0                 100.0
#
#    Avg Difficulty Level  Avg Duration
# 0                  0.75          7.75
# 1                  2.00         10.20
# 2                  2.00         10.40

# %% [markdown]
# #Interpretation
#
# ###Cluster 0: High Performers
# Efficiency Mean: ~85%
# Correction Ratio Mean: ~87.5%
# Handles moderate to hard quizzes well (Avg Difficulty Level ~1.5).
# Likely consistent and capable students who complete quizzes efficiently and correct mistakes well.
#
#
# ###Cluster 1: Moderate Performers
# Efficiency Mean: ~65%
# Correction Ratio Mean: ~80%
# Handles easier quizzes (Avg Difficulty Level ~0).
# Students may take slightly more time but still manage corrections effectively.
#
# ###Cluster 2: Low Performers
# Efficiency Mean: ~30%
# Correction Ratio Mean: ~80%
# Handles medium quizzes (Avg Difficulty Level ~1).
# Students spend much longer than expected and may need help with time management.
#
# #Recommendations for Students:
#
# Cluster 0: Encourage advanced quizzes and focus on even tougher questions.
#
#
# Cluster 1: Improve time management for harder quizzes.
#
#
# Cluster 2: Provide targeted learning material to improve quiz efficiency.
